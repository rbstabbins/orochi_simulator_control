# %% [markdown]
# A notebook for capturing calibration data for the cameras of the OROCHI Simualtor of the Kameda Lab.
#
# Sixth round of experiments after procedure upgrade adding 8th camera, and switching some camera positions, and setting to switch from 30 FPS to 1 FPS for exposures longer than 500 ms.
#
# Using a gain of 4.27 dB to raise apparent full well to 20000 e-, and sensitivity to 4.88 e-/DN.
# Reducing Blacklevel to 8 DN from 128 DN, to increase sensitive range.

# %% [markdown]
# # Process Overview
#
# The objective of this notebook is to process uniformly illuminated and dark images (across the sampling area) and characterise each camera of the OROCHI simulator, or OROS, in terms of:
# - Read Noise
# - Saturation Capacity
# - Gain (Sensitivity)
# - Linearity
# - Dark Signal
# - SNR
# - FPN
#
# The goal is to demonstrate that the performance of OROS is comparable to that expected of the OROCHI Flight Model.

# %% [markdown]
# For each of the SCT99 and SCT5 targets, we:
# - for each channel:
#     - load the list of exposures
#     - for each exposure,
#         - load image 1
#         - load image 2
#         - load the dark frame
#         - get mean of image 1 - dark
#         - get the noise of image 1 - dark
#         - get the noise of image 1 - image 2
#     - get the read noise
#     - get shot noise
#     - get sensitivity
#     - get full well
#     - evaluate linearity
#     - plot mean vs exposure
#     - plot temporal dark noise vs exposure
#     - plot sensitivity vs mean
#     - plot noise vs mean (PTC)
#     - plot noise vs mean (electron PTC)
#     - plot linearity vs mean
#     - plot dark signal vs exposure
#     - plot SNR vs mean
#     - plot SNR vs exposure
#
# For each of these, we will also plot the expected data, based on the datasheet of the OROCHI simulator (OROS), and the expected performance of the OROCHI Flight Model.

# %% [markdown]
# As we'd like to repeat this for each camera, we will write each of these steps into functions, contained in the notebook here, such that the analysis can be iterated and automated.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Expected Performance of OROS and OROCHI
#
# ## OROCHI Simulator (OROS)
#
# The OROCHI Simulator cameras each use the Sony IMX249LLJ CMOS sensor, in the TIS (The Imaging Source) DMK 33GX249 camera unit https://www.theimagingsource.com/en-us/product/industrial/33g/dmk33gx249/.
# This is a 2.35MP monochrome sensor, with 5.86µm pixel pitch.
#
# The datasheet for the sensor does not offer detailled information,
# https://s1-dl.theimagingsource.com/api/2.5/packages/publication/sensor-sony/imx249llj/6a48775d-a298-532c-b1ec-5b4c0262b7c4/imx249llj_1.0.en_US.pdf
# however 3rd parties do provide further characteristics:
# https://www.baumer.com/medias/__secure__/EMVA_VCXG-24M_CID010002_External.pdf?mediaPK=9021140598814
# https://www.framos.com/en/products/imx249llj-c-17041
#
# The most detailed specifications are given by Baumer, recorded empirically using the EMVA1288 Standard method.
#
# The revelant results are as follows:
#
# Sense Node Gain: 26.5 µV/e- (850 mV saturation voltage from Sony Datasheet, implies 32075 e- saturation capacity) \
# Overall system sensitivity: 7.979 e−/DN \
# Temporal dark noise: 0.82 DN (6.13 e−) \
# SNRmax: 179 (45.1 dB, 7.5 bit) \
# Dynamic range: 4535 (73.1 dB, 12.1 bit) \
# Nonlinearity: LE 0.37% (LEmin -0.41%, LEmax 0.32%) \
# Read Noise: 7.07 e− \
# Saturation Capacity: 32059 e− \
# Dark Current: 8.8 e-/s @ ~32°C
#
# Note this was collected with a Gain of 1.0 (i.e. 0.0 dB) and a blacklevel of 39 DN.

# %% [markdown]
# ## OROCHI Flight Model
#
# The OROCHI Flight Model cameras each use the On-Semiconductor KAI-08051 CCD Interline Transfer sensor.
# The datasheet (https://www.mouser.com/datasheet/2/308/KAI-08051-D-599880.pdf) gives detailled information on the performance:
#
# Sense Node Gain: 39 µV/e- \
# Overall system sensitivity: 4.88 e-/DN (Full Well over Max DN for 12-bit mode, 1.22 e-/DN for 14-bit mode) \
# Temporal dark noise: 0.82 DN (6.13 e−) \
# SNRmax: 141.4 (43.0 dB, 7.1 bit) \
# Dynamic range: 2000 (66 dB, 11 bit) \
# Nonlinearity: LE 1%  \
# Read Noise: 10 e− (2.05 DN, for 12-bit mode, 8.2 DN for 14-bit mode) \
# Full Well: 20000 e− \
# Dark Signal: ~2 e-/s
#
# OROCHI will be operated in 14-bit mode. However, the effective dynamic range is 2000, equivalent to 11 bits. So we expect to be ablke to approximate OROCHI well with the maximum 12-bit operatiuon of OROS, and so comparisons here are drawn against OROCHI under the assumption of 12-bit operation.
# Note also that the OROCHI sensor dark signal is expected to be as low as 7 e-/s at a reference temperature of 40°C, with a doubling coefficient of 7°C, hence at the reference temerapture of 30°C we expect very low dark signal contributions. Note also that this may be resolvable in OROCHI 14-bit mode, but would be harder to precisely measure in 12-bit mode.

# %% [markdown]
# # Comparison
#
# ## Full Well
#
# The Full Well $n_{FW}$ of OROS is greater than OROCHI: 32049 vs 20000 electrons.
# This has implications on the maximum achievable SNR (below).
#
# ## SNR-Max
# The key impact of the Full Well is on the maximum possible SNR, approximated by:
#
# ${SNR}_{max} = n_{FW} / \sqrt{n_{FW}}$
#
# where $\sqrt{n_{FW}}$ is the shot-noise at Full Well.
# Hence we expect OROS to achieve a greater ${SNR}_{max}$ of 179 vs 141.
#
# This performance increase would mean that OROS observations would overestimate the performance of OROCHI.
# However, we can avoid this by ensuring the detection does not exceed 20000 electron Full Well of OROCHI.
#
# ## Sensitivity and System Gain
#
# The overall system sensitivty of OROS is just more than half that of OROCHI, giving 7.979 e- for each DN, in comparison to 4.88 e-.
# The implication is that each DN represents a different number of electrons for the two systems, so in the range of interest, the sensitivity of OROS is lower.
#
# We can mitigate this by adjusting the gain settings of the OROS channels, by the following amount:
#
# $20*\log(7.979/4.88) = 4.27$ dB
#
# Applying this gain to OROS should achieve an equivalent sensitivity to OROCHI.
# However, it will also increase the read noise, but it should not effect the shot noise, as this is introduce pre-gain.
#
# It will, however, effect the max SNR achievable, as the full-well capacity will have been scaled to ~6567 DN, much greater than the 4096 DN maximum 12-bit value of OROS.
#
# Conicidently, the apparent full-well (or *saturation capacity*) will now be approximately 20,000 electrons, matching that of OROCHI.
#
# ## Read Noise
#
# The read noise sets the lower limit of detectability.
# With a gain of 0 dB, the read noise of OROS was expected to be 7.07 e-, that would have equated to a DN rms level of 0.88 DN.
# With a new sensitivity of 4.88 e-/DN, we can expect a read noise of 1.45 DN.
# As we do not expect to analyse regions of the image in the read-limited regime of the detector, we do not expect this to be an issue.
# However, if the read noise consists of signficant post-amplifier noise sources, then we will expect this value to be amplifed. We deduce if there is signifcant post-amplifier noise by comparing the observed read noise to the expectation value.
#
# ## Dynamic Range
#
# With a gain of 0 dB, OROS had a dynamic range of 73.15 dB, requiring 4535 steps to represent, of which 4096 could be represented by the 12-bit detector.
# With a gain of 4.27 dB, we expect the new dynamic range to be 69 dB, requiring 2829 steps to represent, of which we can represent 4096.
# Note that this still exceeds that of OROCHI, which has 66 dB dynamic range, requiring 2000 steps.
#
# ## Linearity
#
# OROS has an expected linearity that is higher than OROCHI, with an expected error of <0.4 % in comparison to an expected error of 1%.
# However, we still must verify if this holds over the complete detector range.
# As we are applying gain, and thus operating the sense-node far below the saturation region, we expect to attain high linearity for all values.
#
# ## Note
#
# We are predominantly concerned with ensuring all pixels exceed a certin electron count, such that a minimum exposed SNR of 100 is achieved in all channels.
# At the new gain settings, we expect to achieve an SNR of 100, requring 10000 electrons, at a level of 2049 DN.
# We will evaluate empirically the true SNR 100 threshold, in terms of electron count and DN level to verify this.
#
# We have found that adjusting the blacklevel of the camera does not apply an offset voltage, but rather just changes the lowest allowed DN value in an image. This doe snot help resolve or avoid underflow. We assume that the camera has been set up with sufficient fixed offset that allows for characterisation of dark and bias frames.

# %% [markdown]
# # PCT99
#
# Here we process the PTC (Photon Transfer Curve) data for each channel in turn.

# %%
from pathlib import Path
import orochi_sim_proc as osp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

colours = plt.get_cmap("tab10")

def process_ptc(subject, dark):
    channels = sorted(list(Path('..', 'data', subject).glob('[!.]*')))

    # gain
    g = 10.0**(4.3 / 20)

    # full well
    fw_exp_os = 32049.0 # expected full well (e-) for OROS
    fw_exp_os_g = fw_exp_os / g # expected full well (e-) for OROS with gain
    fw_exp_of = 20000.0 # expected full well (e-) for OROCHI
    # read noise
    rn_exp_os = 7.07 # expected read noise (e-) for Oro-S
    rn_exp_os_g = rn_exp_os # expected read noise (e-) for Oro-S with gain
    rn_exp_of = 10.0 # expected read noise (e-) for OROCHI
    # sensitivity
    k_exp_os = 7.979 # expected sensitivity in 12-bit mode for Oro-S - Baumer EMVA Study
    k_exp_os_g = k_exp_os / g # expected sensitivity in 12-bit mode for Oro-S with gain
    k_exp_of = fw_exp_of / 2**12 # expected sensitivity in 12-bit mode for OROCHI
    # read noise
    rn_dn_exp_os = rn_exp_os / k_exp_os # expected read noise (DN) for OROS
    rn_dn_exp_os_g = rn_dn_exp_os * g # expected read noise (DN) for OROS with gain
    rn_dn_exp_of = rn_exp_of / k_exp_of # expected read noise (DN) for OROCHI
    # SNR
    snr_exp_os = fw_exp_os / np.sqrt(fw_exp_os) # expected peak SNR for OROS
    snr_exp_os_g = fw_exp_os_g / np.sqrt(fw_exp_os_g) # expected peak SNR for OROS
    snr_exp_of = fw_exp_of / np.sqrt(fw_exp_of) # expected peak SNR for OROCHI
    snr_min = 100 # minimum acceptable SNR
    # Dynamic Range
    dr_exp_os = 20.0*np.log10(fw_exp_os/rn_exp_os)
    dr_exp_os_g = 20.0*np.log10(fw_exp_os_g/rn_exp_os_g)
    dr_exp_of = 20.0*np.log10(fw_exp_of/rn_exp_of)
    # dark current (e-/s) at ~30°C
    dc_exp_os = 8.8
    dc_exp_os_g = 8.8
    dc_exp_of = 2.6

    # expected response for each channel of OROCHI at Mars:
    response_exp_of = {
        400:   33909.120210,
        475:   34660.711142,
        550:  34660.683017,
        650:   31148.687877,
        725:   19333.888021,
        850:   6106.064279,
        950:   3166.538335
    }

    fig_exp, ax_exp = osp.grid_plot() # init the exposure grid plot
    cntr_exp = ax_exp[8] # centre plot for overlaying the exposures

    fig_lin, ax_lin = osp.grid_plot() # init the linearity plot
    cntr_lin = ax_lin[8] # centre plot for overlaying the linearity
    lin_min = 0
    lin_max = 2**12
    
    fig_var_dn, ax_var_dn = osp.grid_plot() # init the dark variance DN plot
    cntr_var_dn = ax_var_dn[8] # centre plot for overlaying the dark varianct DN
    var_dn_min = 1E-5
    var_dn_max = 100
    
    fig_kadc, ax_kadc = osp.grid_plot() # init the K ADC plot
    cntr_kadc = ax_kadc[8] # centre plot for overlaying the K ADC
    kadc_min = 0
    kadc_max = 2**12

    fig_ptc_dn, ax_ptc_dn = osp.grid_plot() # init the ptc DN plot
    cntr_ptc_dn = ax_ptc_dn[8] # centre plot for overlaying the PTC DN
    ptc_dn_min = 1E-1
    ptc_dn_max = 2**13
    
    fig_ptc, ax_ptc = osp.grid_plot() # init the ptc grid plot
    cntr_ptc = ax_ptc[8] # centre plot for overlaying the PTC
    ptc_e_min = 1E0
    ptc_e_max = 1E5

    fig_d_exp, ax_d_exp = osp.grid_plot() # init the dark signal plot
    cntr_d_exp = ax_d_exp[8] # centre plot for overlaying the dark signal
    d_exp_min = 0.0
    d_exp_max = 60

    

    # fig_dsnu_exp, ax_dsnu_exp = osp.grid_plot() # init the DSNU plot
    # cntr_dsnu_exp = ax_dsnu_exp[8] # centre plot for overlaying the DSNU

    fig_snr, ax_snr = osp.grid_plot() # init the SNR plot
    cntr_snr = ax_snr[8] # centre plot for overlaying the SNR
    snr_dn_min = 0
    snr_dn_max = 2**12

    fig_snr_exp, ax_snr_exp = osp.grid_plot() # init the SNR plot
    cntr_snr_exp = ax_snr_exp[8] # centre plot for overlaying the SNR

    cameras = ['OROS-OTS', 'OROS', 'OROCHI']
    k_adcs = [k_exp_os, k_exp_os_g, k_exp_of]
    full_wells = [fw_exp_os, fw_exp_os_g, fw_exp_of]
    read_noises = [rn_exp_os, rn_exp_os_g, rn_exp_of]
    dark_currents = [dc_exp_os, dc_exp_os_g, dc_exp_of]
    drs = [dr_exp_os, dr_exp_os_g, dr_exp_of]
    lin_mins = [-0.41, -0.41, 0.0]
    lin_maxs = [0.32, 0.32, 0.0]
    t_exp_mins = [0,0,0]
    t_exp_maxs = [0,0,0]
    expected_responses = [0,0,0]
    responses = [0,0,0]

    # colours = plt.rcParams['axes.prop_cycle'].by_key()['color']
    colours = plt.get_cmap("tab10")

    for channel_path in channels:
        channel = channel_path.name        
        print('--------------------------------------------')
        print(f'Processing {subject}/{channel}')
        # load the calibration target images, and compute the full well, linear sensitivity and read noise
        dtc_data, read_noise, dark_current = osp.load_dtc_frames(dark, channel)
        pct_data, full_well, k_adc, read_noise, lin_min, lin_max, offset, response = osp.load_ptc_frames(subject, channel, read_noise=read_noise)

        # pct_data.sort_values('exposure', inplace=True)
        num = int(channel.split('_')[0]) # get camera number
        wvl = int(channel.split('_')[1]) # get camera wavelength        
        chnl_str = f'Camera {num}: {wvl} nm' # create channel string
        
        colour = colours(num) # get colour for channel

        # plot Mean vs Exposure
        pct_data.plot.scatter('exposure', 'mean', title=chnl_str, color=colour, ax=ax_exp[num]) #, logx=True, logy=True)
        pct_data.plot.scatter('exposure', 'mean', title='All Channels', color=colour, ax=cntr_exp) #, logx=True, logy=True)
        # fitted values
        ax_exp[num].plot(pct_data['exposure'], pct_data['exposure']*response + offset, linestyle='solid', color=colour, label='Fit')
        cntr_exp.plot(pct_data['exposure'], pct_data['exposure']*response + offset, linestyle='solid', color=colour, label='Fit')
        # expected response of OROCHI
        ax_exp[num].plot(pct_data['exposure'], pct_data['exposure']*response_exp_of[wvl], linestyle='solid', color='k', label='OROCHI')
        cntr_exp.plot(pct_data['exposure'], pct_data['exposure']*response_exp_of[wvl], linestyle='dashdot', color=colour, label='OROCHI')  
        ax_exp[num].set_yscale('log')
        ax_exp[num].set_xscale('log')
        ax_exp[num].set_ylabel('Mean (DN)')
        ax_exp[num].set_xlabel('Exposure (s)')
        cntr_exp.set_ylabel('Mean (DN)')
        cntr_exp.set_xlabel('Exposure (s)')
        ax_exp[num].set_ylim(0,2**12)
        cntr_exp.set_ylim(0,2**12)

        # plot temporal dark variance against Exposure
        # data
        ax_var_dn[num].loglog(dtc_data['exposure'], dtc_data['std_rs'], '.', label=chnl_str, color=colour)            
        cntr_var_dn.loglog(dtc_data['exposure'], dtc_data['std_rs'], '.', label='All Channels', color=colour)            
        # fit
        ax_var_dn[num].axhline(read_noise, linestyle='solid', color=colour, label='Fit')
        cntr_var_dn.axhline(read_noise, linestyle='solid', color=colour, label='Fit')        
        fit_std_rs = np.sqrt(read_noise**2 + (dark_current * dtc_data['exposure'] / k_adc))
        ax_var_dn[num].loglog(dtc_data['exposure'], fit_std_rs, linestyle='solid', color=colour, label='Fit')
        cntr_var_dn.loglog(dtc_data['exposure'], fit_std_rs, linestyle='solid', color=colour, label='Fit')
        # expected
        oros_g_exp_std_rs = np.sqrt(rn_dn_exp_os_g**2 + (dc_exp_os_g * dtc_data['exposure'] / k_exp_os_g))        
        oros_exp_std_rs = np.sqrt(rn_dn_exp_os**2 + (dc_exp_os * dtc_data['exposure'] / k_exp_os))
        of_exp_std_rs = np.sqrt(rn_dn_exp_of**2 + (dc_exp_of * dtc_data['exposure'] / k_exp_of))        
        ax_var_dn[num].axhline(rn_dn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
        ax_var_dn[num].loglog(dtc_data['exposure'], oros_g_exp_std_rs, linestyle='dashed', color='k', label='OROS (g)')
        # labels
        ax_var_dn[num].set_title(chnl_str)
        ax_var_dn[num].set_ylabel('Temporal Dark Noise (DN)')
        ax_var_dn[num].set_xlabel('Exposure (s)')

        # plot Noise (Total, FPN-removed, Shot) vs Mean and FW and Read Noise and expectations
        # data
        pct_data.plot('mean', ['std_t','std_rs', 'std_s'], style=['.','x', '+'], logx=True, logy=True, color=colour, title=chnl_str, ax=ax_ptc_dn[num] ,legend=False)
        pct_data.plot('mean', ['std_t','std_rs', 'std_s'], style=['.','x', '+'], logx=True, logy=True, color=colour, title='All Channels', ax=cntr_ptc_dn, legend=False)
        # fitted read noise                        
        ax_ptc_dn[num].axhline(read_noise, linestyle='solid', color=colour, label='RN')                
        cntr_ptc_dn.axhline(read_noise, linestyle='solid', color=colour, label='RN')        
        # expected read noise
        ax_ptc_dn[num].axhline(rn_dn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
        # fitted full well        
        ax_ptc_dn[num].axvline(full_well, linestyle='solid', color=colour, label='FW')        
        cntr_ptc_dn.axvline(full_well, linestyle='solid', color=colour, label='FW')
        # expected full well
        ax_ptc_dn[num].axvline((fw_exp_os_g/k_exp_os_g), linestyle='dashed', color='k', label='OROS (g)')        
        # fitted gain
        ax_ptc_dn[num].plot(pct_data['mean'], np.sqrt(pct_data['mean']/k_adc), linestyle='solid', color=colour, label='$K_{ADC}$')
        ax_ptc_dn[num].plot(pct_data['mean'], np.sqrt(pct_data['mean']/k_exp_os_g), linestyle='dashed', color='k', label='OROS (g)')
        ptc_dn_min, ptc_dn_max = ax_ptc_dn[num].get_xlim()
        cntr_ptc_dn.plot([ptc_dn_min, ptc_dn_max], np.sqrt(np.array([ptc_dn_min, ptc_dn_max])/k_adc), linestyle='solid', color=colour, label='$K_{ADC}$ Expected')
        # expected gain
        # ax_ptc_dn[num].legend()
        ax_ptc_dn[num].set_ylabel('Noise (DN)')
        ax_ptc_dn[num].set_xlabel('Mean Signal (DN)')
        cntr_ptc_dn.set_ylabel('Noise (DN)')
        cntr_ptc_dn.set_xlabel('Mean Signal (DN)')

        # plot sensitivity for all channels
        # data
        ax_kadc[num].plot(pct_data['mean'], pct_data['k_adc'], '.', label=chnl_str, color=colour)            
        cntr_kadc.plot(pct_data['mean'], pct_data['k_adc'], '.', label='All Channels', color=colour)            
        ax_kadc[num].set_ylim(0, 2.0 * k_exp_of)        
        cntr_kadc.set_ylim(0, 2.0 * k_exp_of)        
        ax_kadc[num].set_title(chnl_str)
        cntr_kadc.set_title('All Channels')
        # fitted sensitivity
        ax_kadc[num].plot(pct_data['mean'], k_adc+(0.0*pct_data['mean']), color=colour)  # overplot the mean k_adc for the channel 
        ax_kadc[num].plot(pct_data['mean'], k_exp_os_g+(0.0*pct_data['mean']), color='k', linestyle='dashed',label='OROS (g)') # overplot expectation
        cntr_kadc.plot(pct_data['mean'], k_adc+(0.0*pct_data['mean']), color=colour)  # overplot the mean k_adc for the channel 

        ax_kadc[num].set_ylabel('Sensitivity (e-/DN)')
        ax_kadc[num].set_xlabel('Mean Signal (DN)')
        cntr_kadc.set_ylabel('Sensitivity (e-/DN)')
        cntr_kadc.set_xlabel('Mean Signal (s)')

        # plot linearity for all channels
        # data
        ax_lin[num].plot(pct_data['exposure'], pct_data['linearity'], linestyle='dotted', marker='o', label=chnl_str, color=colour)            
        cntr_lin.plot(pct_data['mean'], pct_data['linearity'], linestyle='dotted', marker='o',label='All Channels', color=colour)    
        ax_lin[num].set_ylabel('Linearity (%)')
        ax_lin[num].set_xlabel('Exposure (s)')
        cntr_lin.axhline(lin_min, linestyle='solid', color=colour, label='Min') # overplot expectation
        cntr_lin.axhline(lin_max, linestyle='solid', color=colour, label='Max') # overplot expectation
        cntr_lin.set_ylabel('Linearity (%)')
        cntr_lin.set_xlabel('Mean Signal (DN)')
        ax_lin[num].set_ylim(lin_min,lin_max)
        ax_lin[num].set_title(chnl_str)
        cntr_lin.set_title('All Channels')

        # plot Electron Signal and Noise        
        pct_data.plot.scatter('e-','e-_noise', logx=True, logy=True, marker='+', title=chnl_str, color=colour, ax=ax_ptc[num], legend=False)
        pct_data.plot.scatter('e-','e-_noise', logx=True, logy=True, marker='+', title='All Channels', color=colour, ax=cntr_ptc, legend=False)
        # fitted read noise        
        ax_ptc[num].axhline(k_adc*read_noise, linestyle='solid', color=colour, label='RN')        
        ax_ptc[num].axhline(rn_dn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')        
        cntr_ptc.axhline(k_adc*read_noise, linestyle='solid', color=colour, label='RN')
        # fitted full well        
        ax_ptc[num].axvline(full_well*k_adc, linestyle='solid', color=colour, label='FW')        
        ax_ptc[num].axvline(fw_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')        
        cntr_ptc.axvline(full_well*k_adc, linestyle='solid', color=colour, label='FW')
        # expected shot response
        ax_ptc[num].plot(pct_data['e-'], np.sqrt(pct_data['e-']), linestyle='solid', color=colour, label='Shot Limit')
        ax_ptc[num].plot(pct_data['e-'], np.sqrt(pct_data['e-']), linestyle='dashed', color='k', label='OROS (g)')
        cntr_ptc.plot(pct_data['e-'], np.sqrt(pct_data['e-']), linestyle='solid', color=colour, label='Shot Limit')
        ax_ptc[num].set_ylabel('Noise (e-)')
        ax_ptc[num].set_xlabel('Mean Signal (e-)')
        cntr_ptc.set_ylabel('Noise (e-)')
        cntr_ptc.set_xlabel('Mean Signal (e-)')

        # plot Dark Signal vs Exposure
        ax_d_exp[num].plot(dtc_data['exposure'], dtc_data['mean'], '.', label=chnl_str, color=colour)            
        cntr_d_exp.plot(dtc_data['exposure'], dtc_data['mean'], '.', label='All Channels', color=colour)            
        ax_d_exp[num].set_title(chnl_str)
        cntr_d_exp.set_title('All Channels')
        exp_dark = dark_current * dtc_data['exposure']
        ax_d_exp[num].plot(dtc_data['exposure'], exp_dark, linestyle='solid', color=colour, label='exp')                
        cntr_d_exp.plot(dtc_data['exposure'], exp_dark, linestyle='solid', color=colour, label='exp')
        ax_d_exp[num].plot(dtc_data['exposure'], (dc_exp_os_g/k_exp_os_g)*dtc_data['exposure'], linestyle='dashed', color='k', label='OROS (g)')
        ax_d_exp[num].set_ylabel('Dark Signal (DN)')
        ax_d_exp[num].set_xlabel('Exposure (s)')
        cntr_d_exp.set_ylabel('Dark Signal (DN)')
        cntr_d_exp.set_xlabel('Exposure (s)')
    

        # plot SNR vs Mean for all channels
        pct_data.plot('mean',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=ax_snr[num], title=chnl_str, legend=False)    
        ax_snr[num].plot(pct_data['mean'], np.sqrt(k_adc*pct_data['mean']), linestyle='solid', color=colour, label='SNR-fit')
        pct_data.plot('mean',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=cntr_snr, title='All Channels', legend=False)         
        ax_snr[num].set_ylabel('SNR')
        ax_snr[num].set_xlabel('Mean Signal (DN)')
        cntr_snr.set_ylabel('SNR')
        cntr_snr.set_xlabel('Mean Signal (DN)')

        # SNR max
        snr_max = np.sqrt(full_well*k_adc)
        snr_min = 100.0
        ax_snr[num].plot(pct_data['mean'], snr_max+(0.0*pct_data['mean']), color=colour, linestyle='solid', label='SNR-max')        
        ax_snr[num].plot(pct_data['mean'], snr_min+(0.0*pct_data['mean']), color=colour, linestyle='solid', label='Min. accept.')
        ax_snr[num].plot(pct_data['mean'], snr_exp_os_g+(0.0*pct_data['mean']), color='k', linestyle='dashed', label='OROS (g)')

        # shade acceptable DN range
        dn_min = (snr_min**2)/k_adc
        dn_max = (snr_max**2)/k_adc
        ax_snr[num].fill_betweenx([0,200], dn_min, dn_max, color=colour, alpha=0.1)
        cntr_snr.fill_betweenx([0,200], dn_min, dn_max, color=colour, alpha=0.1)

        cntr_snr.plot(pct_data['mean'], np.sqrt(full_well*k_adc)+(0.0*pct_data['mean']), color=colour, linestyle='solid', label='SNR-max')        


        # plot SNR vs Exposure for all channels
        pct_data.plot('exposure',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=ax_snr_exp[num], title=chnl_str, legend=False)    
        ax_snr_exp[num].plot(pct_data['exposure'], np.sqrt(k_adc*pct_data['mean']), color=colour, linestyle='solid', label='SNR-fit')
        pct_data.plot('exposure',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=cntr_snr_exp, title='All Channels', legend=False)         
        ax_snr_exp[num].set_ylabel('SNR')
        ax_snr_exp[num].set_xlabel('Exposure (s)')
        cntr_snr_exp.set_ylabel('SNR')
        cntr_snr_exp.set_xlabel('Exposure (s)')

        # SNR max
        snr_max = np.sqrt(full_well*k_adc)
        snr_min = 100.0
        ax_snr_exp[num].plot(pct_data['exposure'], snr_max+(0.0*pct_data['exposure']), color=colour, linestyle='solid', label='SNR-max')        
        ax_snr_exp[num].plot(pct_data['exposure'], snr_min+(0.0*pct_data['exposure']), color=colour, linestyle='solid', label='Min. accept.')
        ax_snr_exp[num].plot(pct_data['exposure'], snr_exp_os_g+(0.0*pct_data['mean']), color='k', linestyle='dashed', label='OROS (g)')

        # # shade acceptable DN range
        # fit exposure - mean DN in linear range
        range = (pct_data['mean'] < full_well*0.9) & (pct_data['mean'] > full_well*0.1)
        fit = np.polyfit(pct_data['exposure'][range], pct_data['mean'][range], 1)        
        k_exp = fit[0]
        texp_min = (snr_min**2)/k_adc/k_exp
        texp_max = (snr_max**2)/k_adc/k_exp
        ax_snr_exp[num].fill_betweenx([0,200], texp_min, texp_max, color=colour, alpha=0.1)
        cntr_snr_exp.fill_betweenx([0,200], texp_min, texp_max, color=colour, alpha=0.1)

        cntr_snr_exp.plot(pct_data['exposure'], np.sqrt(full_well*k_adc)+(0.0*pct_data['exposure']), color=colour, label='SNR-max')    
   
        # add extracted full well, gain and read-noise to the plots

        cameras.append(chnl_str)
        k_adcs.append(k_adc)
        full_wells.append(full_well*k_adc)
        read_noises.append(read_noise*k_adc)
        dark_currents.append(dark_current*k_adc)
        drs.append(20.0*np.log10(full_well/read_noise))
        lin_mins.append(lin_min)
        lin_maxs.append(lin_max)
        t_exp_mins.append(texp_min)
        t_exp_maxs.append(texp_max)
        expected_responses.append(response_exp_of[wvl])
        responses.append(response)
        print('--------------------------------------------')
        # print electron full well      
    osp.show_grid(fig_exp, ax_exp)    
    cntr_var_dn.axhline(y=rn_dn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
    cntr_var_dn.axhline(y=rn_dn_exp_os, linestyle='dotted', color='k', label='OROS')
    cntr_var_dn.axhline(y=rn_dn_exp_of, linestyle='solid', color='k', label='OROCHI')
    cntr_var_dn.loglog(dtc_data['exposure'], oros_g_exp_std_rs, linestyle='dashed', color='k', label='OROS (g)')
    cntr_var_dn.loglog(dtc_data['exposure'], oros_exp_std_rs, linestyle='dotted', color='k', label='OROS')
    cntr_var_dn.loglog(dtc_data['exposure'], of_exp_std_rs, linestyle='solid', color='k', label='OROCHI')
    cntr_var_dn.set_title('All Channels')
    cntr_var_dn.set_ylabel('Temporal Dark Noise (DN)')
    cntr_var_dn.set_xlabel('Exposure (s)')
    osp.show_grid(fig_var_dn, ax_var_dn) 
    cntr_ptc_dn.axhline(y=rn_dn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc_dn.axhline(y=rn_dn_exp_os, linestyle='dotted', color='k', label='OROS')
    cntr_ptc_dn.axhline(y=rn_dn_exp_of, linestyle='solid', color='k', label='OROCHI')
    cntr_ptc_dn.axvline(x=(fw_exp_os_g/k_exp_os_g), linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc_dn.axvline(x=(fw_exp_os/k_exp_os), linestyle='dotted', color='k', label='OROS')
    cntr_ptc_dn.axvline(x=(fw_exp_of/k_exp_of), linestyle='solid', color='k', label='OROCHI')
    ptc_dn_min, ptc_dn_max = cntr_ptc_dn.get_xlim()
    cntr_ptc_dn.plot([ptc_dn_min, ptc_dn_max], np.sqrt(np.array([ptc_dn_min, ptc_dn_max])/k_exp_os_g), linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc_dn.plot([ptc_dn_min, ptc_dn_max], np.sqrt(np.array([ptc_dn_min, ptc_dn_max])/k_exp_os), linestyle='dotted', color='k', label='OROS')
    cntr_ptc_dn.plot([ptc_dn_min, ptc_dn_max], np.sqrt(np.array([ptc_dn_min, ptc_dn_max])/k_exp_of), linestyle='solid', color='k', label='OROCHI')    
    osp.show_grid(fig_ptc_dn, ax_ptc_dn) 
    # expected sensitivity
    cntr_kadc.axhline(y=k_exp_os_g, color='k', linestyle='dashed',label='OROS (g)') # overplot expectation
    cntr_kadc.axhline(y=k_exp_os, color='k', linestyle='dotted',label='OROS') # overplot expectation
    cntr_kadc.axhline(y=k_exp_of, color='k', linestyle='solid',label='OROCHI') # overplot expectation
    osp.show_grid(fig_kadc, ax_kadc)

    cntr_lin.set_ylim(-5,+5)
    osp.show_grid(fig_lin, ax_lin)
    cntr_ptc.axhline(y=rn_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc.axhline(y=rn_exp_os, linestyle='dotted', color='k', label='OROS')
    cntr_ptc.axhline(y=rn_exp_of, linestyle='solid', color='k', label='OROCHI')
    cntr_ptc.axvline(x=fw_exp_os_g, linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc.axvline(x=fw_exp_os, linestyle='dotted', color='k', label='OROS')
    cntr_ptc.axvline(x=fw_exp_of, linestyle='solid', color='k', label='OROCHI')
    # note for the electron plot, there is no sensitivity dependence to the PTC   
    ptc_e_min, ptc_e_max = cntr_ptc.get_xlim()
    cntr_ptc.plot([ptc_e_min, ptc_e_max], np.sqrt(np.array([ptc_e_min, ptc_e_max])), linestyle='dashed', color='k', label='OROS (g)')
    cntr_ptc.plot([ptc_e_min, ptc_e_max], np.sqrt(np.array([ptc_e_min, ptc_e_max])), linestyle='dotted', color='k', label='OROS')
    cntr_ptc.plot([ptc_e_min, ptc_e_max], np.sqrt(np.array([ptc_e_min, ptc_e_max])), linestyle='solid', color='k', label='OROCHI')
    osp.show_grid(fig_ptc, ax_ptc)
    d_exp_min, d_exp_max = cntr_d_exp.get_xlim()
    cntr_d_exp.plot([d_exp_min, d_exp_max], (dc_exp_os_g/k_exp_os_g)*np.array([d_exp_min, d_exp_max]), linestyle='dashed', color='k', label='OROS (g)')
    cntr_d_exp.plot([d_exp_min, d_exp_max], (dc_exp_os/k_exp_os)*np.array([d_exp_min, d_exp_max]), linestyle='dotted', color='k', label='OROS')
    cntr_d_exp.plot([d_exp_min, d_exp_max], (dc_exp_of/k_exp_of)*np.array([d_exp_min, d_exp_max]), linestyle='solid', color='k', label='OROCHI')
    osp.show_grid(fig_d_exp, ax_d_exp)
    cntr_snr.plot([snr_dn_min, snr_dn_max], [snr_min, snr_min], color='k', linestyle='solid', label='Min. accept.')
    cntr_snr.axhline(snr_min, color='k', linestyle='solid', label='Min. accept.')
    cntr_snr.axhline(snr_exp_os_g, color='k', linestyle='dashed', label='OROS (g)')
    cntr_snr.axhline(snr_exp_os, color='k', linestyle='dotted', label='OROS')
    cntr_snr.axhline(snr_exp_of, color='k', linestyle='solid', label='OROCHI')
    osp.show_grid(fig_snr, ax_snr)
    cntr_snr_exp.axhline(snr_min, color='k', linestyle='solid', label='Min. accept.')
    cntr_snr_exp.axhline(snr_exp_os_g, color='k', linestyle='dashed', label='OROS (g)')
    cntr_snr_exp.axhline(snr_exp_os, color='k', linestyle='dotted', label='OROS')
    cntr_snr_exp.axhline(snr_exp_of, color='k', linestyle='solid', label='OROCHI')
    osp.show_grid(fig_snr_exp, ax_snr_exp)

    print(snr_exp_of)

    results = pd.DataFrame({'camera': cameras, 'k_adc': k_adcs, 'full_well': full_wells, 'read_noise': read_noises, 'dark_current': dark_currents,'DR': drs, 'lin_min': lin_mins, 'lin_max': lin_maxs, 't_exp_min': t_exp_mins, 't_exp_max': t_exp_maxs, 'expected_response': expected_responses, 'response': responses})
    return results

# %%
subject = 'SCT99_280623'
dark = 'dark_280623'
process_ptc(subject, dark)
# Out:
# --------------------------------------------
# Processing SCT99_280623/0_850
# Loaded 1 images (850_10095570us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_10095570us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1132285us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1132285us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_12114684us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_12114684us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1358742us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1358742us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14537621us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14537621us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1630491us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1630491us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17445146us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17445146us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1956589us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1956589us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20934175us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20934175us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2347907us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2347907us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_25121010us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_25121010us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2817488us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2817488us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_30145212us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_30145212us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3380986us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3380986us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_36174254us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_36174254us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_379200us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_379200us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4057183us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4057183us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42975014us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42975014us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_43409105us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_43409105us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_455040us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_455040us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4868620us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4868620us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_546048us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_546048us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5842344us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5842344us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_655258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_655258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_7010813us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_7010813us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_786309us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_786309us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8412975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8412975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_943571us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_943571us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1109us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_11869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_124us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1331us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_13448us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13448us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13448us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_13583us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13583us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13583us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_13721us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13721us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13721us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_13859us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13859us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13859us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_13999us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13999us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_13999us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14141us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14141us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14141us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14284us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14284us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14284us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14428us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14428us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14428us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14574us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14574us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14574us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14721us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14721us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14721us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14869us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_149us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15020us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15020us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15020us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15171us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15171us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15171us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15325us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15325us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15325us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15479us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15479us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15479us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15636us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15636us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15636us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15794us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15794us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15794us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_15953us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15953us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_15953us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1597us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16114us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16114us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16114us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16277us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16277us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16277us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16442us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16442us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16442us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16608us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16608us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16608us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16775us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16775us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16775us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_16945us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16945us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_16945us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17092us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17116us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17116us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17116us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17289us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17289us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17289us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17464us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17464us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17464us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17640us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17640us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17640us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17818us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17818us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17818us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17998us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17998us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17998us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_179us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_18180us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18180us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18180us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_18364us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18364us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18364us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_18549us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18549us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18549us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_18736us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18736us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18736us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_18926us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18926us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_18926us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_19117us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19117us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19117us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1917us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_19310us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19310us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19310us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_19505us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19505us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19505us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_19702us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19702us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19702us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_19901us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19901us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_19901us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_20102us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20102us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20102us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_20305us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20305us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20305us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_20510us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_215us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_2300us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_2760us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_310us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_3313us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_372us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_3975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_446us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_4770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_5724us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_60us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_642us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_6869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_72us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_8243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_86us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_924us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_9891us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_d_drk) for: 0 (850 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_2167/1687379406.py:148: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax_exp[num].set_ylim(0,2**12)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99_280623/1_475
# Loaded 1 images (475_10095570us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10095570us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1132285us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1132285us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_12114684us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_12114684us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1358742us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1358742us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14537621us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14537621us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1630491us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1630491us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17445146us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17445146us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1956589us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1956589us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20934175us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20934175us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2347907us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2347907us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_25121010us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_25121010us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2817488us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2817488us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_30145212us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_30145212us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_316000us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_316000us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3380986us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3380986us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_36174254us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_36174254us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_379200us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_379200us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4057183us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4057183us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42975014us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42975014us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_43409105us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_43409105us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_455040us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_455040us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4868620us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4868620us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_546048us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_546048us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5842344us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5842344us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_655258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_655258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_7010813us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_7010813us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_786309us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_786309us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8412975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8412975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_943571us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_943571us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10005us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10005us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10005us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10106us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10106us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10106us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10208us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10208us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10208us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10311us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10311us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10311us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10416us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10416us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10416us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10521us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10521us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10521us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10627us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10627us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10627us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10734us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10734us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10734us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10843us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10843us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10843us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_10952us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10952us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10952us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11063us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11063us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11063us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11175us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11175us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11175us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11288us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11288us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11288us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11402us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11402us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11402us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11517us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11517us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11517us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11633us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11633us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11633us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11751us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11751us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11751us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8434us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8434us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8434us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8519us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8519us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8519us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8605us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8605us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8605us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8692us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8692us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8692us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8780us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8780us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8780us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8868us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8868us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8868us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8958us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8958us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8958us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9048us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9048us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9048us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9140us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9140us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9140us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9232us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9232us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9232us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9325us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9325us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9325us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9420us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9420us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9420us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9515us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9515us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9515us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9611us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9611us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9611us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9708us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9708us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9708us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9806us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9806us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9806us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9891us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9905us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9905us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9905us_d_drk) for: 1 (475 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_2167/1687379406.py:148: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax_exp[num].set_ylim(0,2**12)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99_280623/2_400
# Loaded 1 images (400_10095570us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_10095570us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_104us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_104us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_105828us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_105828us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1109us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1109us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1132285us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1132285us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_11869us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_11869us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_12114684us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_12114684us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_124us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_124us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_126993us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_126993us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1331us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1331us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1358742us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1358742us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_14243us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_14243us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_14537621us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_14537621us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_149us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_149us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_152392us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_152392us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1597us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1597us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1630491us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1630491us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_17092us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_17092us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_17445146us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_17445146us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_179us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_179us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_182870us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_182870us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1917us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1917us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1956589us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_1956589us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_20510us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_20510us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_20934175us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_20934175us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_215us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_215us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_219444us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_219444us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2300us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2300us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2347907us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2347907us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_24612us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_24612us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_25121010us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_25121010us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_258us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_258us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_263333us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_263333us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2760us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2760us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2817488us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_2817488us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_29535us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_29535us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_30145212us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_30145212us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_310us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_310us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_316000us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_316000us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_3313us_1_calibration) for: 2 (400 nm)
# Loaded 1 images (400_3313us_2_calibration) for: 2 (400 nm)
# Loaded 1 images (400_3380986us_1_calibration) for: 2 (400 nm)
# ...
# Loaded 1 images (550_446us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_455040us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_455040us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4868620us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4868620us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_51036us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_51036us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_546048us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_546048us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5724us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5724us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5842344us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5842344us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_655258us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_655258us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_6869us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_6869us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_7010813us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_7010813us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_786309us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_786309us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8412975us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8412975us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_88190us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_88190us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_943571us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_943571us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1109us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1109us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1109us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_124us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_124us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_124us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1331us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1331us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1331us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_149us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_149us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_149us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1597us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1597us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1597us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_179us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_179us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_179us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1917us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1917us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1917us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_215us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_215us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_215us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2300us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2300us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2300us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_258us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_258us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_258us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2713us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2713us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2713us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2741us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2741us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2741us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2760us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2760us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2760us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2768us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2768us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2768us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2796us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2796us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2796us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2824us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2824us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2824us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2853us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2853us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2853us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2882us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2882us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2882us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2911us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2911us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2911us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2940us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2940us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2940us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2970us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2970us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2970us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3000us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3000us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3000us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3030us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3030us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3030us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3061us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3061us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3061us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3092us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3092us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3092us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_310us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_310us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_310us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3123us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3123us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3123us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3155us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3155us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3155us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3186us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3186us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3186us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3219us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3219us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3219us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3251us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3251us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3251us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3284us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3284us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3284us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3313us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3313us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3313us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3317us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3317us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3317us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3351us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3351us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3351us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3385us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3385us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3385us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3419us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3419us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3419us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3453us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3453us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3453us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3488us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3488us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3488us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3523us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3523us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3523us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3559us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3559us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3559us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3595us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3595us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3595us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3631us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3631us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3631us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3668us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3668us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3668us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3705us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3705us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3705us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_372us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_372us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_372us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3742us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3742us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3742us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3780us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3780us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3780us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3818us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3818us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3818us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3857us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3857us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3857us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3896us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3896us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3896us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3935us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3935us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3935us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3975us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3975us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3975us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_446us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_446us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_446us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_535us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_60us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_642us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_72us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_86us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_924us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_d_drk) for: 7 (550 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_2167/1687379406.py:148: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax_exp[num].set_ylim(0,2**12)
# --------------------------------------------
# 141.4213562373095
#               camera     k_adc     full_well  read_noise  dark_current  \
# 0           OROS-OTS  7.979000  32049.000000    7.070000      8.800000
# 1               OROS  4.863495  19535.048020    7.070000      8.800000
# 2             OROCHI  4.882812  20000.000000   10.000000      2.600000
# 3   Camera 0: 850 nm  4.721805  18405.660734    3.758884      5.311617
# 4   Camera 1: 475 nm  4.674000  17998.355522    3.336413      5.305533
# 5   Camera 2: 400 nm  4.665231  17733.908356    3.080479      7.034127
# 6   Camera 3: 550 nm  4.680986  18124.694904    3.486170      6.846533
# 7   Camera 4: 725 nm  4.834636  19070.991750    3.508512      6.127601
# 8   Camera 5: 950 nm  4.731675  18626.204951    1.997766      6.826723
# 9   Camera 6: 650 nm  4.755967  18302.717997    3.583046      6.108425
# 10  Camera 7: 550 nm  4.783957  18575.510549    3.178260      6.276954
#
#            DR   lin_min   lin_max  t_exp_min  t_exp_max  expected_response  \
# 0   73.127901 -0.410000  0.320000   0.000000   0.000000           0.000000
# 1   68.827901 -0.410000  0.320000   0.000000   0.000000           0.000000
# 2   66.020600  0.000000  0.000000   0.000000   0.000000           0.000000
# 3   73.797851 -1.656751  0.847853   0.008756   0.016115        6106.064279
# 4   74.639060 -1.571356  1.036513   0.005543   0.009976       34660.711142
# 5   75.203725 -0.841997  0.219240   0.025752   0.045668       33909.120210
# 6   74.318442 -3.007502  1.904929   0.001685   0.003053       34660.683017
# 7   74.705006 -3.732465  3.496318   0.000979   0.001866       19333.888021
# 8   79.391594 -1.109457  0.281491   0.045563   0.084867        3166.538335
# 9   74.165264 -1.396626  1.040260   0.003381   0.006188       31148.687877
# 10  75.335027 -2.978870  1.916240   0.001745   0.003242       34660.683017
#
#         response
# 0   0.000000e+00
# 1   0.000000e+00
# 2   0.000000e+00
# 3   2.431091e+05
# 4   3.889582e+05
# 5   8.404397e+04
# 6   1.281540e+06
# 7   2.183454e+06
# 8   4.701417e+04
# 9   6.252611e+05
# 10  1.203023e+06

# %%
subject = 'SCT5_280623'
dark = 'dark_280623'
process_ptc(subject, dark)
# Out:
# --------------------------------------------
# Processing SCT5_280623/0_850
# Loaded 1 images (850_10095570us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_10095570us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1132285us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1132285us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_12114684us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_12114684us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1358742us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1358742us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14537621us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14537621us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1630491us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1630491us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17445146us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17445146us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1956589us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1956589us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20934175us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20934175us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2347907us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2347907us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_25121010us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_25121010us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2817488us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2817488us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_30145212us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_30145212us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3380986us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3380986us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_36174254us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_36174254us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_379200us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_379200us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4057183us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4057183us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42975014us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42975014us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_43409105us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_43409105us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_455040us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_455040us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4868620us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4868620us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_546048us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_546048us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5842344us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5842344us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_655258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_655258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_7010813us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_7010813us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_786309us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_786309us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8412975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8412975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_943571us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_943571us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_104us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_105828us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_105828us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1109us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1109us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_11869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_11869us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_124us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_124us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_126993us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_126993us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1331us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1331us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_14243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_14243us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_149us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_149us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_152392us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_152392us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1597us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1597us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_17092us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_17092us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_179us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_179us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_182870us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_182870us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_1917us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_1917us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_20510us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_20510us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_215us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_215us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_219444us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_219444us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_2300us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2300us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_231408us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_231408us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_231408us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_233745us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_233745us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_233745us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_236106us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_236106us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_236106us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_238491us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_238491us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_238491us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_240900us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_240900us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_240900us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_243334us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_243334us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_243334us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_245792us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_245792us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_245792us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_24612us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_24612us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_248274us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_248274us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_248274us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_250782us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_250782us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_250782us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_253315us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_253315us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_253315us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_255874us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_255874us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_255874us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_258459us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258459us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258459us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_258us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_258us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_261069us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_261069us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_261069us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_263333us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263333us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_263706us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263706us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_263706us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_266370us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_266370us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_266370us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_269061us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_269061us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_269061us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_271779us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_271779us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_271779us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_274524us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_274524us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_274524us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_2760us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_2760us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_277297us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_277297us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_277297us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_280098us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_280098us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_280098us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_282927us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_282927us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_282927us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_285785us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_285785us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_285785us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_288672us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_288672us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_288672us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_291587us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_291587us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_291587us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_294533us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_294533us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_294533us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_29535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_29535us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_297508us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_297508us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_297508us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_300513us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_300513us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_300513us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_303548us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_303548us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_303548us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_306615us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_306615us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_306615us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_309712us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_309712us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_309712us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_310us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_310us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_312840us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_312840us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_312840us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_316000us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_316000us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_3313us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3313us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_35442us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_35442us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_372us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_372us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_3975us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_3975us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_42530us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_42530us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_446us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_446us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_4770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_4770us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_51036us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_51036us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_535us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_535us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_5724us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_5724us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_60us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_60us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_61243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_61243us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_642us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_642us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_6869us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_6869us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_72us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_72us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_73492us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_73492us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_770us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_770us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_8243us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_8243us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_86us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_86us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_88190us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_88190us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_924us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_924us_d_drk) for: 0 (850 nm)
# Loaded 1 images (850_9891us_1_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_2_calibration) for: 0 (850 nm)
# Loaded 1 images (850_9891us_d_drk) for: 0 (850 nm)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_2167/1687379406.py:148: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax_exp[num].set_ylim(0,2**12)
# --------------------------------------------
# --------------------------------------------
# Processing SCT5_280623/1_475
# Loaded 1 images (475_10095570us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_10095570us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1132285us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1132285us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_12114684us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_12114684us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1358742us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1358742us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14537621us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14537621us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1630491us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1630491us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17445146us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17445146us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1956589us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1956589us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20934175us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20934175us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2347907us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2347907us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_25121010us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_25121010us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2817488us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2817488us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_30145212us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_30145212us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_316000us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_316000us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3380986us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3380986us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_36174254us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_36174254us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_379200us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_379200us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4057183us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4057183us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42975014us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42975014us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_43409105us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_43409105us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_455040us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_455040us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4868620us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4868620us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_546048us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_546048us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5842344us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5842344us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_655258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_655258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_7010813us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_7010813us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_786309us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_786309us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8412975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8412975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_943571us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_943571us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_104us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_105828us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_105828us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1109us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_11869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_11869us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_124us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_126993us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_126993us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1331us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_14243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_14243us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_149us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_152392us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_152392us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1597us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_17092us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_17092us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_170930us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_170930us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_170930us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_172657us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_172657us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_172657us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_174401us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_174401us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_174401us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_176163us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_176163us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_176163us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_177942us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_177942us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_177942us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_179739us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179739us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179739us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_179us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_181555us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_181555us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_181555us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_182870us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_182870us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_183389us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_183389us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_183389us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_185241us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_185241us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_185241us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_187112us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_187112us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_187112us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_189002us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_189002us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_189002us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_190912us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_190912us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_190912us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_1917us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_192840us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_192840us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_192840us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_194788us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_194788us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_194788us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_196755us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_196755us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_196755us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_198743us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_198743us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_198743us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_200750us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_200750us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_200750us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_202778us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_202778us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_202778us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_204826us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_204826us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_204826us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_20510us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_20510us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_206895us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_206895us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_206895us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_208985us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_208985us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_208985us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_211096us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_211096us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_211096us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_213228us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_213228us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_213228us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_215382us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215382us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215382us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_215us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_217558us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_217558us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_217558us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_219444us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219444us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_219755us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219755us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_219755us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_221975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_221975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_221975us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_224217us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_224217us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_224217us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_226482us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_226482us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_226482us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_228770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_228770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_228770us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2300us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_231081us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_231081us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_231081us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_233415us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_233415us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_233415us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_235772us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_235772us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_235772us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_238154us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_238154us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_238154us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_240560us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_240560us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_240560us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_242989us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_242989us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_242989us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_245444us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_245444us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_245444us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_24612us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_24612us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_247923us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_247923us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_247923us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_250427us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_250427us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_250427us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_252957us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_252957us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_252957us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_255512us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_255512us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_255512us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_258093us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258093us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258093us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_258us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_260700us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_260700us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_260700us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_263333us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_263333us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_2760us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_29535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_29535us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_310us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3313us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_35442us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_35442us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_372us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_3975us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_42530us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_42530us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_446us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_4770us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_51036us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_51036us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_535us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_5724us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_60us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_61243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_61243us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_642us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_6869us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_72us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_73492us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_73492us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_770us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_8243us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_86us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_88190us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_88190us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_924us_d_drk) for: 1 (475 nm)
# Loaded 1 images (475_9891us_1_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_2_calibration) for: 1 (475 nm)
# Loaded 1 images (475_9891us_d_drk) for: 1 (475 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...
# Loaded 1 images (550_6869us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_6869us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_7010813us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_7010813us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_786309us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_786309us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8412975us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8412975us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_88190us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_88190us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_943571us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_943571us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_104us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1109us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1109us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1109us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_11869us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_11869us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_11869us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_124us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_124us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_124us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1331us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1331us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1331us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_14243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_14243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_14243us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_149us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_149us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_149us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1597us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1597us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1597us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_17092us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_17092us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_17092us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_179us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_179us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_179us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_1917us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1917us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_1917us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_20510us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_20510us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_20510us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_215us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_215us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_215us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2300us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2300us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2300us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_24612us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_24612us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_24612us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_258us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_258us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_258us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_2760us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2760us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_2760us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_29535us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_29535us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_29535us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_310us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_310us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_310us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3313us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3313us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3313us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_35442us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_35442us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_35442us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_372us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_372us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_372us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_3975us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3975us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_3975us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_42530us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_42530us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_42530us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_446us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_446us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_446us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_4770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_4770us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_51036us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_51036us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_51036us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_535us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_535us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_53818us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_53818us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_53818us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_54362us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_54362us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_54362us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_54911us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_54911us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_54911us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_55465us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_55465us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_55465us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_56026us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_56026us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_56026us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_56592us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_56592us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_56592us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_57163us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_57163us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_57163us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_5724us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5724us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_5724us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_57741us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_57741us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_57741us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_58324us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_58324us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_58324us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_58913us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_58913us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_58913us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_59508us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_59508us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_59508us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_60109us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60109us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60109us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_60716us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60716us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60716us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_60us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_60us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_61243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61243us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_61330us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61330us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61330us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_61949us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61949us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_61949us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_62575us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_62575us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_62575us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_63207us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_63207us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_63207us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_63845us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_63845us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_63845us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_642us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_642us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_64490us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_64490us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_64490us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_65142us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_65142us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_65142us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_65800us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_65800us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_65800us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_66464us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_66464us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_66464us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_67136us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_67136us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_67136us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_67814us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_67814us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_67814us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_68499us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_68499us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_68499us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_6869us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_6869us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_6869us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_69191us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_69191us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_69191us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_69890us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_69890us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_69890us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_70596us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_70596us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_70596us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_71309us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_71309us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_71309us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_72029us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72029us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72029us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_72757us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72757us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72757us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_72us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_72us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_73492us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_73492us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_770us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_770us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_8243us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_8243us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_86us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_86us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_924us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_924us_d_drk) for: 7 (550 nm)
# Loaded 1 images (550_9891us_1_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_2_calibration) for: 7 (550 nm)
# Loaded 1 images (550_9891us_d_drk) for: 7 (550 nm)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_2167/1687379406.py:148: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax_exp[num].set_ylim(0,2**12)
# --------------------------------------------
# 141.4213562373095
#               camera     k_adc     full_well  read_noise  dark_current  \
# 0           OROS-OTS  7.979000  32049.000000    7.070000      8.800000
# 1               OROS  4.863495  19535.048020    7.070000      8.800000
# 2             OROCHI  4.882812  20000.000000   10.000000      2.600000
# 3   Camera 0: 850 nm  4.724703  17892.501704    3.761191      5.314877
# 4   Camera 1: 475 nm  4.707715  17776.925537    3.360480      5.343803
# 5   Camera 2: 400 nm  4.697719  17404.923843    3.101931      7.083113
# 6   Camera 3: 550 nm  4.754685  18018.261838    3.541058      6.954327
# 7   Camera 4: 725 nm  4.879353  18088.808913    3.540963      6.184277
# 8   Camera 5: 950 nm  4.694633  18110.938653    1.982127      6.773281
# 9   Camera 6: 650 nm  4.735171  17707.475230    3.567379      6.081715
# 10  Camera 7: 550 nm  4.681269  17564.669838    3.110039      6.142219
#
#            DR   lin_min   lin_max  t_exp_min  t_exp_max  expected_response  \
# 0   73.127901 -0.410000  0.320000   0.000000   0.000000           0.000000
# 1   68.827901 -0.410000  0.320000   0.000000   0.000000           0.000000
# 2   66.020600  0.000000  0.000000   0.000000   0.000000           0.000000
# 3   73.546914 -0.877523  0.224123   0.150361   0.269033        6106.064279
# 4   74.469108 -0.623731  0.222233   0.111660   0.198498       34660.711142
# 5   74.980799 -0.688389  0.342204   0.521330   0.907370       33909.120210
# 6   74.131597 -0.480083  0.464428   0.032657   0.058842       34660.683017
# 7   74.165771 -0.584011  0.360722   0.017517   0.031687       19333.888021
# 8   79.216190 -0.829189  0.281218   0.750596   1.359399        3166.538335
# 9   73.916149 -0.748863  0.321724   0.063563   0.112555       31148.687877
# 10  75.037484 -0.376475  0.571703   0.035251   0.061918       34660.683017
#
#          response
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3    14214.380795
# 4    19160.313848
# 5     4116.154602
# 6    64770.121282
# 7   117556.603576
# 8     2864.584445
# 9    33457.007820
# 10   60871.120875
