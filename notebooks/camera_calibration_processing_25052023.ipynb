# %% [markdown]
# A notebook for processing calibration data for the cameras of the OROCHI Simualtor of the Kameda Lab.
#
# Processing of data captured on 25/05/2023 - repeated at 12-bit resolution, with a gain of 4.27 dB and blacklevel of 8 DN.

# %% [markdown]
# # Process Overview
#
# The objective of this notebook is to process uniformly illuminated and dark images (across the sampling area) and characterise each camera of the OROCHI simulator, in terms of:
# - Linearity
# - Read Noise
# - Gain
# - FPN
# - Dark Signal
#
# The goal is to validate the linearity, full-well and read-noise of the cameras,and establish the range of the camera response we need to operate in order to match the signal-to-noise ratio expected of the OROCHI Flight Model.
#
# To do this, we will process images of the 99% Reflectance Spectralon Calibration Target (SCT99) and the 5% Reflectance Spectral Calibration Target (SCT5), and images without illumination, at exposures that range from the minimum possible with the cameras (~5 µs) up to a maximum, defined such that all pixels of the image are saturated (DN=255).

# %% [markdown]
# For each of the SCT99 and SCT5 targets, we:
# - for each channel:
#     - load the list of exposures
#     - for each exposure,
#         - load image 1
#         - load image 2
#         - load the dark frame
#         - get mean of image 1 - dark
#         - get the noise of image 1 - dark
#         - get the noise of image 1 - image 2
#     - get the read noise
#     - get shot noise
#     - get sensitivity
#     - get full well
#     - evaluate linearity
#     - plot mean vs exposure
#     - plot noise vs mean
#     - plot fpn-removed noise vs mean
#     - plot shot noise vs mean
#     - plot sensitivity vs mean
#
# For each of these, we will also plot the expected data, based on the datasheet of the OROCHI simulator (Oro-S), and the expected performance of the OROCHI Flight Model (Oro-M).

# %% [markdown]
# As we'd like to repeat this for each camera, we will write each of these steps into functions, contained in the notebook here, such that the analysis can be iterated and automated.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Expected Performance of OROS and OROCHI
#
# ## OROCHI Simulator (OROS)
#
# The OROCHI Simulator cameras each use the Sony IMX249LLJ CMOS sensor, in the TIS (The Imaging Source) DMK 33GX249 camera unit https://www.theimagingsource.com/en-us/product/industrial/33g/dmk33gx249/.
# This is a 2.35MP monochrome sensor, with 5.86µm pixel pitch.
#
# The datasheet for the sensor does not offer detailled information,
# https://s1-dl.theimagingsource.com/api/2.5/packages/publication/sensor-sony/imx249llj/6a48775d-a298-532c-b1ec-5b4c0262b7c4/imx249llj_1.0.en_US.pdf
# however 3rd parties do provide further characteristics:
# https://www.baumer.com/medias/__secure__/EMVA_VCXG-24M_CID010002_External.pdf?mediaPK=9021140598814
# https://www.framos.com/en/products/imx249llj-c-17041
#
# The most detailed specifications are given by Baumer, recorded empirically using the EMVA1288 Standard method.
#
# The revelant results are as follows:
#
# Sense Node Gain: 26.5 µV/e- (850 mV saturation from Sony Datasheet, over 32059 e- full well here) \
# Overall system sensitivity: 7.979 e−/DN \
# Temporal dark noise: 0.82 DN (6.13 e−) \
# SNRmax: 179 (45.1 dB, 7.5 bit) \
# Dynamic range: 4535 (73.1 dB, 12.1 bit) \
# Nonlinearity: LE 0.37% (LEmin -0.41%, LEmax 0.32%) \
# Read Noise: 7.07 e− \
# Full Well: 32059 e−
#
# Note this was collected with a Gain of 1.0 (i.e. 0.0 dB) and a blacklevel of 39 DN.

# %% [markdown]
# ## OROCHI Flight Model
#
# The OROCHI Flight Model cameras each use the On-Semiconductor KAI-08051 CCD Interline Transfer sensor.
# The datasheet (https://www.mouser.com/datasheet/2/308/KAI-08051-D-599880.pdf) gives detailled information on the performance:
#
# Sense Node Gain: 39 µV/e- \
# Overall system sensitivity: 4.88 e-/DN (Full Well over Max DN, for 12-bit mode) \
# Temporal dark noise: 0.82 DN (6.13 e−) \
# SNRmax: 141.4 (43.0 dB, 7.1 bit) \
# Dynamic range: 2000 (66 dB, 11 bit) \
# Nonlinearity: LE 1%  \
# Read Noise: 10 e− \
# Full Well: 20000 e−
#
# Given the dynamic range of the camera is less than 12, we expect only a 12-bit ADC to be neccessary.

# %% [markdown]
# # Comparison
#
# ## Full Well
#
# The Full Well $n_{FW}$ of Oro-S is greater thatn Oro-M: 32049 vs 20000 electrons.
#
# ## SNR-Max
# The key impact of the Full Well is on the maximum possible SNR, approximated by:
#
# ${SNR}_{max} = n_{FW} / \sqrt{n_{FW}}$
#
# where $\sqrt{n_{FW}}$ is the shot-noise at Full Well.
# Hence we have Oro-S achieving a greater ${SNR}_{max}$ of 179 vs 141.
#
# The implication is that we can limit the performance of the OROCHI simulator to match that of the flight model by ensuring the detection does not exceed 20000 electrons.
#
# ## Sensitivity and System Gain
#
# The overall system sensitivty of Oro-S is just more than half that of Oro-M, giving 7.979 e- for each DN, in comparison to 4.88 e-.
# This has implications, as it means that each DN represents a different number of electrons for the two systems, so in the range of interest, the sensitivity of Oro-S is lower.
#
# We can mitigate this the gain settings of Oro-S, that are set interms of dB:
#
# $20*\log(7.979/4.88) = 4.27$ dB
#
# Applying this gain to the system should achieve an equivalent sensitivity.
# However, it will also increase the read noise, but it should not effect the shot noise, as this is pre-gain.
# It will, however, effect the max SNR achievable, as the full-well capacity will have been scaled to ~6567 DN, much greater than the 4096 DN maximum 12-bit value of Oro-S.
# The apparent full-well will now be approximately 20,000 electrons, such taht we do not have to make enforcements to ensure that the 20000 electron limit is exceeded.
#
# ## Read Noise
#
# The read noise sets the lower limit of detectability.
# With a gain of 0 dB, the read noise of Oro-S was expected to be 7.07 e-, that would have equated to a DN rms level of 0.88 DN.
# With a new sensitivity of 4.88 e-/DN, we can expect a read noise of 1.45 DN.
# As we do not expect to analyse regions of the image in the read-limited regime of the detector, we do not expect this to be an issue.
# However, if the read noise consists of signficant post-amplifier noise sources, then we will expect this value to be amplifed. We deduce if there is signifcant post-amplifier noise by comparing the observed read noise to the expectation value.
#
# ## Dynamic Range
#
# With a gain of 0 dB, Oro-S had a dynamic range of 73.15 dB, requiring 4535 steps to represent, of which 4096 could be represented by the 12-bit detector.
# With a gain of 4.27 dB, we expect the new dynamic range to be 69 dB, requiring 2829 steps to represent, of which we can represent 4096.
# Note that this still exceeds that of Oro-M, which has 66 dB dynamic range, requiring 2000 steps.
#
# ## Linearity
#
# Oro-S has an expected linearity that is higher than Oro-M, with an expected error of <0.4 % in comparison to an expected error of 1%.
# However, we still must verify if this holds over the complete detector range.
# As we are applying gain, and thus operating the sense-node far below the saturation region, we expect to attain high linearity for all values.
#
# ## Note
#
# We are predominantly concerned with ensuring all pixels exceed a certin electron count, such that a minimum exposed SNR of 100 is achieved in all channels.
# At the new gain settings, we expect to achieve an SNR of 100, requring 10000 electrons, at a level of 2049 DN.
# So should look in the data for true SNR 100 threshold, in terms of electron count and DN level to verify this.
#
# For a Read Noise of 1.44 DN, we will set our blacklevel to 8 DN, to achieve greater than 5-sigma headroom for the dark images.

# %% [markdown]
# # PCT99
#
# Here we process the PTC (Photon Transfer Curve) data for each channel in turn.

# %%
from pathlib import Path
import orochi_sim_proc as osp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def process_ptc(subject):
    channels = sorted(list(Path('..', 'data', subject).glob('[!.]*')))

    # grouped plots
    fig_k, ax_k = plt.subplots() # init the grouped k_adc plot    

    fw_exp_os = 32049.0 # expected full well (e-) for OROS
    fw_exp_of = 20000.0 # expected full well (e-) for OROCHI
    rn_exp_os = 7.07 # expected read noise (e-) for Oro-S
    rn_exp_of = 10.0 # expected read noise (e-) for Oro-S
    k_exp_of = fw_exp_of / 2**12 # expected sensitivity in 12-bit mode for OROCHI
    k_exp_os = 7.979 # expected sensitivity in 12-bit mode for Oro-S - Baumer EMVA Study
    snr_exp_of = fw_exp_of / np.sqrt(fw_exp_of) # expected peak SNR for OROCHI
    snr_exp_os = fw_exp_os / np.sqrt(fw_exp_os) # expected peak SNR for OROS
    snr_min = 100 # minimum acceptable SNR

    fig_exp, ax_exp = osp.grid_plot() # init the exposure grid plot
    cntr_exp = ax_exp[8] # centre plot for overlaying the exposures

    fig_ptc_dn, ax_ptc_dn = osp.grid_plot() # init the ptc DN plot
    cntr_ptc_dn = ax_ptc_dn[8] # centre plot for overlaying the PTC DN

    fig_kadc, ax_kadc = osp.grid_plot() # init the K ADC plot
    cntr_kadc = ax_kadc[8] # centre plot for overlaying the K ADC

    fig_ptc, ax_ptc = osp.grid_plot() # init the ptc grid plot
    cntr_ptc = ax_ptc[8] # centre plot for overlaying the PTC

    fig_d_exp, ax_d_exp = osp.grid_plot() # init the dark signal plot
    cntr_d_exp = ax_d_exp[8] # centre plot for overlaying the dark signal

    fig_dsnu_exp, ax_dsnu_exp = osp.grid_plot() # init the DSNU plot
    cntr_dsnu_exp = ax_dsnu_exp[8] # centre plot for overlaying the DSNU

    fig_snr, ax_snr = osp.grid_plot() # init the SNR plot
    cntr_snr = ax_snr[8] # centre plot for overlaying the SNR

    k_adcs = []
    full_wells = []
    read_noises = []
    drs = []

    for channel_path in channels:
        channel = channel_path.name        
        print('--------------------------------------------')
        print(f'Processing {subject}/{channel}')
        # load the calibration target images, and compute the full well, linear sensitivity and read noise
        pct_data, full_well, k_adc, read_noise = osp.load_pct_frames(subject, channel)
        # pct_data.sort_values('exposure', inplace=True)
        num = int(channel.split('_')[0]) # get camera number
        wvl = int(channel.split('_')[1]) # get camera wavelength        
        chnl_str = f'Camera {num}: {wvl} nm' # create channel string

        # plot sensitivity for all channels
        ax_k.plot(pct_data['mean'], pct_data['k_adc'], 'o', label=chnl_str)    
        colour = ax_k.get_lines()[-1].get_color() # get colour for channel
        # overplot the mean k_adc for the channel
        ax_k.plot(pct_data['mean'], k_adc+(0.0*pct_data['mean']), color=colour)    
        ax_k.set_ylim(0, 2.0 * k_exp_of)    

        # plot Mean vs Exposure
        pct_data.plot.scatter('exposure', 'mean', title=chnl_str, color=colour, logx=True, logy=True, ax=ax_exp[num])
        pct_data.plot.scatter('exposure', 'mean', title='All Channels', color=colour, logx=True, logy=True, ax=cntr_exp)
        ax_exp[num].set_ylabel('Mean (DN)')
        ax_exp[num].set_xlabel('Exposure (s)')
        cntr_exp.set_ylabel('Mean (DN)')
        cntr_exp.set_xlabel('Exposure (s)')

        # plot Noise (Total, FPN-removed, Shot) vs Mean and FW and Read Noise and expectations
        # data
        pct_data.plot('mean', ['std_t','std_rs', 'std_s'], style=['.','x', '+'], logx=True, logy=True, color=colour, title=chnl_str, ax=ax_ptc_dn[num] ,legend=False)
        pct_data.plot('mean', ['std_t','std_rs', 'std_s'], style=['.','x', '+'], logx=True, logy=True, color=colour, title='All Channels', ax=cntr_ptc_dn, legend=False)
        # fitted read noise                
        ax_ptc_dn[num].plot(pct_data['mean'], read_noise+(0.0*pct_data['mean']), linestyle='dashed', color=colour, label='RN')
        cntr_ptc_dn.plot(pct_data['mean'], read_noise+(0.0*pct_data['mean']), linestyle='dashed', color=colour, label='RN')
        # expected read noise
        # fitted full well
        ax_ptc_dn[num].plot(full_well + (0.0*pct_data['std_t']), pct_data['std_t'], linestyle='dotted', color=colour, label='FW')        
        cntr_ptc_dn.plot(full_well + (0.0*pct_data['std_t']), pct_data['std_t'], linestyle='dotted', color=colour, label='FW')
        # expected full well
        # fitted gain
        ax_ptc_dn[num].plot(pct_data['mean'], np.sqrt(pct_data['mean']/k_adc), linestyle='solid', color=colour, label='$K_{ADC}$')
        cntr_ptc_dn.plot(pct_data['mean'], np.sqrt(pct_data['mean']/k_adc), linestyle='solid', color=colour, label='$K_{ADC}$ Expected')
        # expected gain

        # ax_ptc_dn[num].legend()
        ax_ptc_dn[num].set_ylabel('Noise (DN)')
        ax_ptc_dn[num].set_xlabel('Mean Signal (DN)')
        cntr_ptc_dn.set_ylabel('Noise (DN)')
        cntr_ptc_dn.set_xlabel('Mean Signal (DN)')

        # plot sensitivity for all channels
        # data
        ax_kadc[num].plot(pct_data['mean'], pct_data['k_adc'], '.', label=chnl_str, color=colour)            
        cntr_kadc.plot(pct_data['mean'], pct_data['k_adc'], '.', label='All Channels', color=colour)            
        ax_kadc[num].set_ylim(0, 2.0 * k_exp_of)        
        cntr_kadc.set_ylim(0, 2.0 * k_exp_of)        
        ax_kadc[num].set_title(chnl_str)
        cntr_kadc.set_title('All Channels')
        # fitted sensitivity
        ax_kadc[num].plot(pct_data['mean'], k_adc+(0.0*pct_data['mean']), color=colour)  # overplot the mean k_adc for the channel 
        cntr_kadc.plot(pct_data['mean'], k_adc+(0.0*pct_data['mean']), color=colour)  # overplot the mean k_adc for the channel 

        ax_kadc[num].set_ylabel('Sensitivity (e-/DN)')
        ax_kadc[num].set_xlabel('Mean Signal (DN)')
        cntr_kadc.set_ylabel('Sensitivity (e-/DN)')
        cntr_kadc.set_xlabel('Mean Signal (s)')

        # plot Electron Signal and Noise        
        pct_data.plot.scatter('e-','e-_noise', logx=True, logy=True, marker='+', title=chnl_str, color=colour, ax=ax_ptc[num], legend=False)
        pct_data.plot.scatter('e-','e-_noise', logx=True, logy=True, marker='+', title='All Channels', color=colour, ax=cntr_ptc, legend=False)
        # fitted read noise
        ax_ptc[num].plot(pct_data['e-'], (k_adc*read_noise)+(0.0*pct_data['e-']), linestyle='dashed', color=colour, label='RN')
        cntr_ptc.plot(pct_data['e-'], (k_adc*read_noise)+(0.0*pct_data['e-']), linestyle='dashed', color=colour, label='RN')
        # expected read noise
        # fitted full well
        ax_ptc[num].plot((full_well*k_adc) + (0.0*pct_data['e-_noise']), pct_data['e-_noise'], linestyle='dotted', color=colour, label='FW')
        cntr_ptc.plot((full_well*k_adc)+(0.0*pct_data['e-_noise']), pct_data['e-_noise'], linestyle='dotted', color=colour, label='FW')
        # expected full well
        # expected shot response
        ax_ptc[num].plot(pct_data['e-'], np.sqrt(pct_data['e-']), linestyle='solid', color=colour, label='Shot Limit')
        cntr_ptc.plot(pct_data['e-'], np.sqrt(pct_data['e-']), linestyle='solid', color=colour, label='Shot Limit')
        # expected gain

        ax_ptc[num].set_ylabel('Noise (e-)')
        ax_ptc[num].set_xlabel('Mean Signal (e-)')
        cntr_ptc.set_ylabel('Noise (e-)')
        cntr_ptc.set_xlabel('Mean Signal (e-)')

        # plot Offset vs Exposure
        pct_data.plot.scatter('exposure', 'd_mean', title=chnl_str, color=colour, ax=ax_d_exp[num])
        pct_data.plot.scatter('exposure', 'd_mean', title='All Channels', color=colour, ax=cntr_d_exp)
        ax_d_exp[num].set_ylabel('Mean Offset (DN)')
        ax_d_exp[num].set_xlabel('Exposure (s)')
        cntr_d_exp.set_ylabel('Mean Offset (DN)')
        cntr_d_exp.set_xlabel('Exposure (s)')
    
        # plot DSNU vs Exposure
        pct_data.plot.scatter('exposure', 'd_dsnu', title=chnl_str, color=colour, ax=ax_dsnu_exp[num])
        pct_data.plot.scatter('exposure', 'd_dsnu', title='All Channels', color=colour, ax=cntr_dsnu_exp)
        ax_dsnu_exp[num].set_ylabel('Mean DSNU (DN)')
        ax_dsnu_exp[num].set_xlabel('Exposure (s)')
        cntr_dsnu_exp.set_ylabel('Mean DSNU (DN)')
        cntr_dsnu_exp.set_xlabel('Exposure (s)')

        # plot SNR vs Mean for all channels
        pct_data.plot('mean',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=ax_snr[num], title=chnl_str, legend=False)    
        ax_snr[num].plot(pct_data['mean'], np.sqrt(k_adc*pct_data['mean']), color=colour, label='SNR-fit')
        pct_data.plot('mean',['snr', 'snr_t'], ylim=(0, 200), style=['+', '.'], color=colour, ax=cntr_snr, title='All Channels', legend=False)         
        ax_snr[num].set_ylabel('SNR')
        ax_snr[num].set_xlabel('Mean Signal (DN)')
        cntr_snr.set_ylabel('SNR')
        cntr_snr.set_xlabel('Mean Signal (DN)')

        # SNR max
        snr_max = np.sqrt(full_well*k_adc)
        snr_min = 100.0
        ax_snr[num].plot(pct_data['mean'], snr_max+(0.0*pct_data['mean']), color=colour, linestyle='dashed', label='SNR-max')        
        ax_snr[num].plot(pct_data['mean'], snr_min+(0.0*pct_data['mean']), color='k', linestyle='dotted', label='Min. accept.')

        # shade acceptable DN range
        dn_min = (snr_min**2)/k_adc
        dn_max = (snr_max**2)/k_adc
        ax_snr[num].fill_betweenx([0,200], dn_min, dn_max, color=colour, alpha=0.1)
        cntr_snr.fill_betweenx([0,200], dn_min, dn_max, color=colour, alpha=0.1)

        cntr_snr.plot(pct_data['mean'], np.sqrt(full_well*k_adc)+(0.0*pct_data['mean']), color=colour, label='SNR-max')        
   
        # add extracted full well, gain and read-noise to the plots

        k_adcs.append(k_adc)
        full_wells.append(full_well*k_adc)
        read_noises.append(read_noise*k_adc)
        drs.append(20.0*np.log10(full_well/read_noise))
        print('--------------------------------------------')
        # print electron full well

    osp.show_grid(fig_exp, ax_exp)    
    cntr_ptc_dn.plot(pct_data['mean'], 1.45+(0.0*pct_data['mean']), linestyle='solid', color='k', label='RN-expected')
    cntr_ptc_dn.plot((fw_exp_of/k_exp_of) + (0.0*pct_data['std_t']), pct_data['std_t'], linestyle='solid', color='k', label='FW-expected')
    cntr_ptc_dn.plot(pct_data['mean'], np.sqrt(pct_data['mean']/k_exp_of), linestyle='solid', color='k', label='$K_{ADC}$ Expected')
    osp.show_grid(fig_ptc_dn, ax_ptc_dn)        
    # expected sensitivity
    cntr_kadc.plot(pct_data['mean'], k_exp_of+(0.0*pct_data['mean']), color='k', linestyle='dotted',label='OROS exp.') # overplot expectation
    osp.show_grid(fig_kadc, ax_kadc)
    cntr_ptc.plot(pct_data['e-'], rn_exp_os+(0.0*pct_data['e-']), linestyle='solid', color='k', label='RN-expected')
    cntr_ptc.plot(fw_exp_of+(0.0*pct_data['e-_noise']), pct_data['e-_noise'], linestyle='solid', color='k', label='FW-expected')
    cntr_ptc.plot(pct_data['e-'], np.sqrt(pct_data['mean']*k_exp_of), linestyle='solid', color='k', label='Expected Shot Limit')
    osp.show_grid(fig_ptc, ax_ptc)
    osp.show_grid(fig_d_exp, ax_d_exp)
    osp.show_grid(fig_dsnu_exp, ax_dsnu_exp)
    cntr_snr.plot(pct_data['mean'], snr_min+(0.0*pct_data['mean']), color='k', linestyle='dotted', label='Min. accept.')
    cntr_snr.plot(pct_data['mean'], snr_exp_of+(0.0*pct_data['mean']), color='k', linestyle='dashed', label='SNR-max Expected')
    osp.show_grid(fig_snr, ax_snr)

    results = pd.DataFrame({'channel': channels, 'k_adc': k_adcs, 'full_well': full_wells, 'read_noise': read_noises, 'DR': drs})
    return results

# %%
subject = 'SCT99'
process_ptc(subject)
# Out:
# --------------------------------------------
# Processing SCT99/0_650
# Loaded images (650_104us_1_calibration) for: 0 (650 nm)
# Loaded images (650_104us_2_calibration) for: 0 (650 nm)
# Loaded images (650_104us_d_drk) for: 0 (650 nm)
# Loaded images (650_1109us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1109us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1109us_d_drk) for: 0 (650 nm)
# Loaded images (650_124us_1_calibration) for: 0 (650 nm)
# Loaded images (650_124us_2_calibration) for: 0 (650 nm)
# Loaded images (650_124us_d_drk) for: 0 (650 nm)
# Loaded images (650_1331us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1331us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1331us_d_drk) for: 0 (650 nm)
# Loaded images (650_149us_1_calibration) for: 0 (650 nm)
# Loaded images (650_149us_2_calibration) for: 0 (650 nm)
# Loaded images (650_149us_d_drk) for: 0 (650 nm)
# Loaded images (650_1597us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1597us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1597us_d_drk) for: 0 (650 nm)
# Loaded images (650_179us_1_calibration) for: 0 (650 nm)
# Loaded images (650_179us_2_calibration) for: 0 (650 nm)
# Loaded images (650_179us_d_drk) for: 0 (650 nm)
# Loaded images (650_1917us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1917us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1917us_d_drk) for: 0 (650 nm)
# Loaded images (650_215us_1_calibration) for: 0 (650 nm)
# Loaded images (650_215us_2_calibration) for: 0 (650 nm)
# Loaded images (650_215us_d_drk) for: 0 (650 nm)
# Loaded images (650_2300us_1_calibration) for: 0 (650 nm)
# Loaded images (650_2300us_2_calibration) for: 0 (650 nm)
# Loaded images (650_2300us_d_drk) for: 0 (650 nm)
# Loaded images (650_258us_1_calibration) for: 0 (650 nm)
# Loaded images (650_258us_2_calibration) for: 0 (650 nm)
# Loaded images (650_258us_d_drk) for: 0 (650 nm)
# Loaded images (650_2760us_1_calibration) for: 0 (650 nm)
# Loaded images (650_2760us_2_calibration) for: 0 (650 nm)
# Loaded images (650_2760us_d_drk) for: 0 (650 nm)
# Loaded images (650_310us_1_calibration) for: 0 (650 nm)
# Loaded images (650_310us_2_calibration) for: 0 (650 nm)
# Loaded images (650_310us_d_drk) for: 0 (650 nm)
# Loaded images (650_3313us_1_calibration) for: 0 (650 nm)
# Loaded images (650_3313us_2_calibration) for: 0 (650 nm)
# Loaded images (650_3313us_d_drk) for: 0 (650 nm)
# Loaded images (650_372us_1_calibration) for: 0 (650 nm)
# Loaded images (650_372us_2_calibration) for: 0 (650 nm)
# Loaded images (650_372us_d_drk) for: 0 (650 nm)
# Loaded images (650_3975us_1_calibration) for: 0 (650 nm)
# Loaded images (650_3975us_2_calibration) for: 0 (650 nm)
# Loaded images (650_3975us_d_drk) for: 0 (650 nm)
# Loaded images (650_4027us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4027us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4027us_d_drk) for: 0 (650 nm)
# Loaded images (650_4067us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4067us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4067us_d_drk) for: 0 (650 nm)
# Loaded images (650_4108us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4108us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4108us_d_drk) for: 0 (650 nm)
# Loaded images (650_4150us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4150us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4150us_d_drk) for: 0 (650 nm)
# Loaded images (650_4192us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4192us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4192us_d_drk) for: 0 (650 nm)
# Loaded images (650_4234us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4234us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4234us_d_drk) for: 0 (650 nm)
# Loaded images (650_4277us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4277us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4277us_d_drk) for: 0 (650 nm)
# Loaded images (650_4320us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4320us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4320us_d_drk) for: 0 (650 nm)
# Loaded images (650_4364us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4364us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4364us_d_drk) for: 0 (650 nm)
# Loaded images (650_4408us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4408us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4408us_d_drk) for: 0 (650 nm)
# Loaded images (650_4452us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4452us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4452us_d_drk) for: 0 (650 nm)
# Loaded images (650_446us_1_calibration) for: 0 (650 nm)
# Loaded images (650_446us_2_calibration) for: 0 (650 nm)
# Loaded images (650_446us_d_drk) for: 0 (650 nm)
# Loaded images (650_4497us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4497us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4497us_d_drk) for: 0 (650 nm)
# Loaded images (650_4543us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4543us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4543us_d_drk) for: 0 (650 nm)
# Loaded images (650_4589us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4589us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4589us_d_drk) for: 0 (650 nm)
# Loaded images (650_4635us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4635us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4635us_d_drk) for: 0 (650 nm)
# Loaded images (650_4682us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4682us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4682us_d_drk) for: 0 (650 nm)
# Loaded images (650_4729us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4729us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4729us_d_drk) for: 0 (650 nm)
# Loaded images (650_4770us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4770us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4770us_d_drk) for: 0 (650 nm)
# Loaded images (650_4777us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4777us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4777us_d_drk) for: 0 (650 nm)
# Loaded images (650_4825us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4825us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4825us_d_drk) for: 0 (650 nm)
# Loaded images (650_4874us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4874us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4874us_d_drk) for: 0 (650 nm)
# Loaded images (650_4923us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4923us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4923us_d_drk) for: 0 (650 nm)
# Loaded images (650_4973us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4973us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4973us_d_drk) for: 0 (650 nm)
# Loaded images (650_5023us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5023us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5023us_d_drk) for: 0 (650 nm)
# Loaded images (650_5074us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5074us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5074us_d_drk) for: 0 (650 nm)
# Loaded images (650_5125us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5125us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5125us_d_drk) for: 0 (650 nm)
# Loaded images (650_5177us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5177us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5177us_d_drk) for: 0 (650 nm)
# Loaded images (650_5229us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5229us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5229us_d_drk) for: 0 (650 nm)
# Loaded images (650_5282us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5282us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5282us_d_drk) for: 0 (650 nm)
# Loaded images (650_5335us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5335us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5335us_d_drk) for: 0 (650 nm)
# Loaded images (650_535us_1_calibration) for: 0 (650 nm)
# Loaded images (650_535us_2_calibration) for: 0 (650 nm)
# Loaded images (650_535us_d_drk) for: 0 (650 nm)
# Loaded images (650_5389us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5389us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5389us_d_drk) for: 0 (650 nm)
# Loaded images (650_5443us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5443us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5443us_d_drk) for: 0 (650 nm)
# Loaded images (650_5498us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5498us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5498us_d_drk) for: 0 (650 nm)
# Loaded images (650_5554us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5554us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5554us_d_drk) for: 0 (650 nm)
# Loaded images (650_5610us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5610us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5610us_d_drk) for: 0 (650 nm)
# Loaded images (650_5667us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5667us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5667us_d_drk) for: 0 (650 nm)
# Loaded images (650_5724us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5724us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5724us_d_drk) for: 0 (650 nm)
# Loaded images (650_60us_1_calibration) for: 0 (650 nm)
# Loaded images (650_60us_2_calibration) for: 0 (650 nm)
# Loaded images (650_60us_d_drk) for: 0 (650 nm)
# Loaded images (650_642us_1_calibration) for: 0 (650 nm)
# Loaded images (650_642us_2_calibration) for: 0 (650 nm)
# Loaded images (650_642us_d_drk) for: 0 (650 nm)
# Loaded images (650_72us_1_calibration) for: 0 (650 nm)
# Loaded images (650_72us_2_calibration) for: 0 (650 nm)
# Loaded images (650_72us_d_drk) for: 0 (650 nm)
# Loaded images (650_770us_1_calibration) for: 0 (650 nm)
# Loaded images (650_770us_2_calibration) for: 0 (650 nm)
# Loaded images (650_770us_d_drk) for: 0 (650 nm)
# Loaded images (650_86us_1_calibration) for: 0 (650 nm)
# Loaded images (650_86us_2_calibration) for: 0 (650 nm)
# Loaded images (650_86us_d_drk) for: 0 (650 nm)
# Loaded images (650_924us_1_calibration) for: 0 (650 nm)
# Loaded images (650_924us_2_calibration) for: 0 (650 nm)
# Loaded images (650_924us_d_drk) for: 0 (650 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99/1_475
# Loaded images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded images (475_104us_d_drk) for: 1 (475 nm)
# Loaded images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1109us_d_drk) for: 1 (475 nm)
# Loaded images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded images (475_124us_d_drk) for: 1 (475 nm)
# Loaded images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1331us_d_drk) for: 1 (475 nm)
# Loaded images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded images (475_149us_d_drk) for: 1 (475 nm)
# Loaded images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1597us_d_drk) for: 1 (475 nm)
# Loaded images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded images (475_179us_d_drk) for: 1 (475 nm)
# Loaded images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1917us_d_drk) for: 1 (475 nm)
# Loaded images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded images (475_215us_d_drk) for: 1 (475 nm)
# Loaded images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded images (475_2300us_d_drk) for: 1 (475 nm)
# Loaded images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded images (475_258us_d_drk) for: 1 (475 nm)
# Loaded images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded images (475_2760us_d_drk) for: 1 (475 nm)
# Loaded images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded images (475_310us_d_drk) for: 1 (475 nm)
# Loaded images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded images (475_3313us_d_drk) for: 1 (475 nm)
# Loaded images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded images (475_372us_d_drk) for: 1 (475 nm)
# Loaded images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded images (475_3975us_d_drk) for: 1 (475 nm)
# Loaded images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded images (475_446us_d_drk) for: 1 (475 nm)
# Loaded images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded images (475_4770us_d_drk) for: 1 (475 nm)
# Loaded images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded images (475_535us_d_drk) for: 1 (475 nm)
# Loaded images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded images (475_5724us_d_drk) for: 1 (475 nm)
# Loaded images (475_5857us_1_calibration) for: 1 (475 nm)
# Loaded images (475_5857us_2_calibration) for: 1 (475 nm)
# Loaded images (475_5857us_d_drk) for: 1 (475 nm)
# Loaded images (475_5916us_1_calibration) for: 1 (475 nm)
# Loaded images (475_5916us_2_calibration) for: 1 (475 nm)
# Loaded images (475_5916us_d_drk) for: 1 (475 nm)
# Loaded images (475_5976us_1_calibration) for: 1 (475 nm)
# Loaded images (475_5976us_2_calibration) for: 1 (475 nm)
# Loaded images (475_5976us_d_drk) for: 1 (475 nm)
# Loaded images (475_6036us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6036us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6036us_d_drk) for: 1 (475 nm)
# Loaded images (475_6097us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6097us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6097us_d_drk) for: 1 (475 nm)
# Loaded images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded images (475_60us_d_drk) for: 1 (475 nm)
# Loaded images (475_6159us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6159us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6159us_d_drk) for: 1 (475 nm)
# Loaded images (475_6221us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6221us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6221us_d_drk) for: 1 (475 nm)
# Loaded images (475_6284us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6284us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6284us_d_drk) for: 1 (475 nm)
# Loaded images (475_6347us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6347us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6347us_d_drk) for: 1 (475 nm)
# Loaded images (475_6411us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6411us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6411us_d_drk) for: 1 (475 nm)
# Loaded images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded images (475_642us_d_drk) for: 1 (475 nm)
# Loaded images (475_6476us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6476us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6476us_d_drk) for: 1 (475 nm)
# Loaded images (475_6541us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6541us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6541us_d_drk) for: 1 (475 nm)
# Loaded images (475_6607us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6607us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6607us_d_drk) for: 1 (475 nm)
# Loaded images (475_6674us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6674us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6674us_d_drk) for: 1 (475 nm)
# Loaded images (475_6742us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6742us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6742us_d_drk) for: 1 (475 nm)
# Loaded images (475_6810us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6810us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6810us_d_drk) for: 1 (475 nm)
# Loaded images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6869us_d_drk) for: 1 (475 nm)
# Loaded images (475_6879us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6879us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6879us_d_drk) for: 1 (475 nm)
# Loaded images (475_6948us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6948us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6948us_d_drk) for: 1 (475 nm)
# Loaded images (475_7018us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7018us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7018us_d_drk) for: 1 (475 nm)
# Loaded images (475_7089us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7089us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7089us_d_drk) for: 1 (475 nm)
# Loaded images (475_7161us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7161us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7161us_d_drk) for: 1 (475 nm)
# Loaded images (475_7233us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7233us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7233us_d_drk) for: 1 (475 nm)
# Loaded images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded images (475_72us_d_drk) for: 1 (475 nm)
# Loaded images (475_7306us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7306us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7306us_d_drk) for: 1 (475 nm)
# Loaded images (475_7380us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7380us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7380us_d_drk) for: 1 (475 nm)
# Loaded images (475_7454us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7454us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7454us_d_drk) for: 1 (475 nm)
# Loaded images (475_7530us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7530us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7530us_d_drk) for: 1 (475 nm)
# Loaded images (475_7606us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7606us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7606us_d_drk) for: 1 (475 nm)
# Loaded images (475_7683us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7683us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7683us_d_drk) for: 1 (475 nm)
# Loaded images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded images (475_770us_d_drk) for: 1 (475 nm)
# Loaded images (475_7760us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7760us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7760us_d_drk) for: 1 (475 nm)
# Loaded images (475_7839us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7839us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7839us_d_drk) for: 1 (475 nm)
# Loaded images (475_7918us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7918us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7918us_d_drk) for: 1 (475 nm)
# Loaded images (475_7998us_1_calibration) for: 1 (475 nm)
# Loaded images (475_7998us_2_calibration) for: 1 (475 nm)
# Loaded images (475_7998us_d_drk) for: 1 (475 nm)
# Loaded images (475_8079us_1_calibration) for: 1 (475 nm)
# Loaded images (475_8079us_2_calibration) for: 1 (475 nm)
# Loaded images (475_8079us_d_drk) for: 1 (475 nm)
# Loaded images (475_8160us_1_calibration) for: 1 (475 nm)
# Loaded images (475_8160us_2_calibration) for: 1 (475 nm)
# Loaded images (475_8160us_d_drk) for: 1 (475 nm)
# Loaded images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded images (475_8243us_d_drk) for: 1 (475 nm)
# Loaded images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded images (475_86us_d_drk) for: 1 (475 nm)
# Loaded images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded images (475_924us_d_drk) for: 1 (475 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99/3_400
# Loaded images (400_104us_1_calibration) for: 3 (400 nm)
# Loaded images (400_104us_2_calibration) for: 3 (400 nm)
# Loaded images (400_104us_d_drk) for: 3 (400 nm)
# Loaded images (400_1109us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1109us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1109us_d_drk) for: 3 (400 nm)
# Loaded images (400_11869us_1_calibration) for: 3 (400 nm)
# Loaded images (400_11869us_2_calibration) for: 3 (400 nm)
# Loaded images (400_11869us_d_drk) for: 3 (400 nm)
# Loaded images (400_124us_1_calibration) for: 3 (400 nm)
# Loaded images (400_124us_2_calibration) for: 3 (400 nm)
# Loaded images (400_124us_d_drk) for: 3 (400 nm)
# Loaded images (400_1331us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1331us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1331us_d_drk) for: 3 (400 nm)
# Loaded images (400_14243us_1_calibration) for: 3 (400 nm)
# Loaded images (400_14243us_2_calibration) for: 3 (400 nm)
# Loaded images (400_14243us_d_drk) for: 3 (400 nm)
# Loaded images (400_149us_1_calibration) for: 3 (400 nm)
# Loaded images (400_149us_2_calibration) for: 3 (400 nm)
# Loaded images (400_149us_d_drk) for: 3 (400 nm)
# Loaded images (400_1597us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1597us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1597us_d_drk) for: 3 (400 nm)
# Loaded images (400_17092us_1_calibration) for: 3 (400 nm)
# Loaded images (400_17092us_2_calibration) for: 3 (400 nm)
# Loaded images (400_17092us_d_drk) for: 3 (400 nm)
# Loaded images (400_179us_1_calibration) for: 3 (400 nm)
# Loaded images (400_179us_2_calibration) for: 3 (400 nm)
# Loaded images (400_179us_d_drk) for: 3 (400 nm)
# Loaded images (400_1917us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1917us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1917us_d_drk) for: 3 (400 nm)
# Loaded images (400_20510us_1_calibration) for: 3 (400 nm)
# Loaded images (400_20510us_2_calibration) for: 3 (400 nm)
# Loaded images (400_20510us_d_drk) for: 3 (400 nm)
# Loaded images (400_215us_1_calibration) for: 3 (400 nm)
# Loaded images (400_215us_2_calibration) for: 3 (400 nm)
# Loaded images (400_215us_d_drk) for: 3 (400 nm)
# Loaded images (400_2300us_1_calibration) for: 3 (400 nm)
# Loaded images (400_2300us_2_calibration) for: 3 (400 nm)
# Loaded images (400_2300us_d_drk) for: 3 (400 nm)
# Loaded images (400_24612us_1_calibration) for: 3 (400 nm)
# Loaded images (400_24612us_2_calibration) for: 3 (400 nm)
# Loaded images (400_24612us_d_drk) for: 3 (400 nm)
# Loaded images (400_258us_1_calibration) for: 3 (400 nm)
# Loaded images (400_258us_2_calibration) for: 3 (400 nm)
# Loaded images (400_258us_d_drk) for: 3 (400 nm)
# Loaded images (400_2760us_1_calibration) for: 3 (400 nm)
# Loaded images (400_2760us_2_calibration) for: 3 (400 nm)
# Loaded images (400_2760us_d_drk) for: 3 (400 nm)
# Loaded images (400_27885us_1_calibration) for: 3 (400 nm)
# Loaded images (400_27885us_2_calibration) for: 3 (400 nm)
# Loaded images (400_27885us_d_drk) for: 3 (400 nm)
# Loaded images (400_28167us_1_calibration) for: 3 (400 nm)
# Loaded images (400_28167us_2_calibration) for: 3 (400 nm)
# Loaded images (400_28167us_d_drk) for: 3 (400 nm)
# Loaded images (400_28451us_1_calibration) for: 3 (400 nm)
# Loaded images (400_28451us_2_calibration) for: 3 (400 nm)
# Loaded images (400_28451us_d_drk) for: 3 (400 nm)
# Loaded images (400_28739us_1_calibration) for: 3 (400 nm)
# Loaded images (400_28739us_2_calibration) for: 3 (400 nm)
# Loaded images (400_28739us_d_drk) for: 3 (400 nm)
# Loaded images (400_29029us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29029us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29029us_d_drk) for: 3 (400 nm)
# Loaded images (400_29322us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29322us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29322us_d_drk) for: 3 (400 nm)
# Loaded images (400_29535us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29535us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29535us_d_drk) for: 3 (400 nm)
# Loaded images (400_29618us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29618us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29618us_d_drk) for: 3 (400 nm)
# Loaded images (400_29917us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29917us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29917us_d_drk) for: 3 (400 nm)
# Loaded images (400_30220us_1_calibration) for: 3 (400 nm)
# Loaded images (400_30220us_2_calibration) for: 3 (400 nm)
# Loaded images (400_30220us_d_drk) for: 3 (400 nm)
# Loaded images (400_30525us_1_calibration) for: 3 (400 nm)
# Loaded images (400_30525us_2_calibration) for: 3 (400 nm)
# Loaded images (400_30525us_d_drk) for: 3 (400 nm)
# Loaded images (400_30833us_1_calibration) for: 3 (400 nm)
# Loaded images (400_30833us_2_calibration) for: 3 (400 nm)
# Loaded images (400_30833us_d_drk) for: 3 (400 nm)
# Loaded images (400_310us_1_calibration) for: 3 (400 nm)
# Loaded images (400_310us_2_calibration) for: 3 (400 nm)
# Loaded images (400_310us_d_drk) for: 3 (400 nm)
# Loaded images (400_31145us_1_calibration) for: 3 (400 nm)
# Loaded images (400_31145us_2_calibration) for: 3 (400 nm)
# Loaded images (400_31145us_d_drk) for: 3 (400 nm)
# Loaded images (400_31459us_1_calibration) for: 3 (400 nm)
# Loaded images (400_31459us_2_calibration) for: 3 (400 nm)
# Loaded images (400_31459us_d_drk) for: 3 (400 nm)
# Loaded images (400_31777us_1_calibration) for: 3 (400 nm)
# Loaded images (400_31777us_2_calibration) for: 3 (400 nm)
# Loaded images (400_31777us_d_drk) for: 3 (400 nm)
# Loaded images (400_32098us_1_calibration) for: 3 (400 nm)
# Loaded images (400_32098us_2_calibration) for: 3 (400 nm)
# Loaded images (400_32098us_d_drk) for: 3 (400 nm)
# Loaded images (400_32422us_1_calibration) for: 3 (400 nm)
# Loaded images (400_32422us_2_calibration) for: 3 (400 nm)
# Loaded images (400_32422us_d_drk) for: 3 (400 nm)
# Loaded images (400_32750us_1_calibration) for: 3 (400 nm)
# Loaded images (400_32750us_2_calibration) for: 3 (400 nm)
# Loaded images (400_32750us_d_drk) for: 3 (400 nm)
# Loaded images (400_33081us_1_calibration) for: 3 (400 nm)
# Loaded images (400_33081us_2_calibration) for: 3 (400 nm)
# Loaded images (400_33081us_d_drk) for: 3 (400 nm)
# Loaded images (400_3313us_1_calibration) for: 3 (400 nm)
# Loaded images (400_3313us_2_calibration) for: 3 (400 nm)
# Loaded images (400_3313us_d_drk) for: 3 (400 nm)
# Loaded images (400_33415us_1_calibration) for: 3 (400 nm)
# Loaded images (400_33415us_2_calibration) for: 3 (400 nm)
# Loaded images (400_33415us_d_drk) for: 3 (400 nm)
# Loaded images (400_33752us_1_calibration) for: 3 (400 nm)
# Loaded images (400_33752us_2_calibration) for: 3 (400 nm)
# Loaded images (400_33752us_d_drk) for: 3 (400 nm)
# Loaded images (400_34093us_1_calibration) for: 3 (400 nm)
# Loaded images (400_34093us_2_calibration) for: 3 (400 nm)
# Loaded images (400_34093us_d_drk) for: 3 (400 nm)
# Loaded images (400_34438us_1_calibration) for: 3 (400 nm)
# Loaded images (400_34438us_2_calibration) for: 3 (400 nm)
# Loaded images (400_34438us_d_drk) for: 3 (400 nm)
# Loaded images (400_34785us_1_calibration) for: 3 (400 nm)
# Loaded images (400_34785us_2_calibration) for: 3 (400 nm)
# Loaded images (400_34785us_d_drk) for: 3 (400 nm)
# Loaded images (400_35137us_1_calibration) for: 3 (400 nm)
# Loaded images (400_35137us_2_calibration) for: 3 (400 nm)
# Loaded images (400_35137us_d_drk) for: 3 (400 nm)
# Loaded images (400_35442us_1_calibration) for: 3 (400 nm)
# Loaded images (400_35442us_2_calibration) for: 3 (400 nm)
# Loaded images (400_35442us_d_drk) for: 3 (400 nm)
# Loaded images (400_35492us_1_calibration) for: 3 (400 nm)
# Loaded images (400_35492us_2_calibration) for: 3 (400 nm)
# Loaded images (400_35492us_d_drk) for: 3 (400 nm)
# Loaded images (400_35850us_1_calibration) for: 3 (400 nm)
# Loaded images (400_35850us_2_calibration) for: 3 (400 nm)
# Loaded images (400_35850us_d_drk) for: 3 (400 nm)
# Loaded images (400_36212us_1_calibration) for: 3 (400 nm)
# Loaded images (400_36212us_2_calibration) for: 3 (400 nm)
# Loaded images (400_36212us_d_drk) for: 3 (400 nm)
# Loaded images (400_36578us_1_calibration) for: 3 (400 nm)
# Loaded images (400_36578us_2_calibration) for: 3 (400 nm)
# Loaded images (400_36578us_d_drk) for: 3 (400 nm)
# Loaded images (400_36948us_1_calibration) for: 3 (400 nm)
# Loaded images (400_36948us_2_calibration) for: 3 (400 nm)
# Loaded images (400_36948us_d_drk) for: 3 (400 nm)
# Loaded images (400_372us_1_calibration) for: 3 (400 nm)
# Loaded images (400_372us_2_calibration) for: 3 (400 nm)
# Loaded images (400_372us_d_drk) for: 3 (400 nm)
# Loaded images (400_37321us_1_calibration) for: 3 (400 nm)
# Loaded images (400_37321us_2_calibration) for: 3 (400 nm)
# Loaded images (400_37321us_d_drk) for: 3 (400 nm)
# Loaded images (400_37698us_1_calibration) for: 3 (400 nm)
# Loaded images (400_37698us_2_calibration) for: 3 (400 nm)
# Loaded images (400_37698us_d_drk) for: 3 (400 nm)
# Loaded images (400_38079us_1_calibration) for: 3 (400 nm)
# Loaded images (400_38079us_2_calibration) for: 3 (400 nm)
# Loaded images (400_38079us_d_drk) for: 3 (400 nm)
# Loaded images (400_38463us_1_calibration) for: 3 (400 nm)
# Loaded images (400_38463us_2_calibration) for: 3 (400 nm)
# Loaded images (400_38463us_d_drk) for: 3 (400 nm)
# Loaded images (400_38852us_1_calibration) for: 3 (400 nm)
# Loaded images (400_38852us_2_calibration) for: 3 (400 nm)
# Loaded images (400_38852us_d_drk) for: 3 (400 nm)
# Loaded images (400_39244us_1_calibration) for: 3 (400 nm)
# Loaded images (400_39244us_2_calibration) for: 3 (400 nm)
# Loaded images (400_39244us_d_drk) for: 3 (400 nm)
# Loaded images (400_39641us_1_calibration) for: 3 (400 nm)
# Loaded images (400_39641us_2_calibration) for: 3 (400 nm)
# Loaded images (400_39641us_d_drk) for: 3 (400 nm)
# Loaded images (400_3975us_1_calibration) for: 3 (400 nm)
# Loaded images (400_3975us_2_calibration) for: 3 (400 nm)
# Loaded images (400_3975us_d_drk) for: 3 (400 nm)
# Loaded images (400_40041us_1_calibration) for: 3 (400 nm)
# Loaded images (400_40041us_2_calibration) for: 3 (400 nm)
# Loaded images (400_40041us_d_drk) for: 3 (400 nm)
# Loaded images (400_40445us_1_calibration) for: 3 (400 nm)
# Loaded images (400_40445us_2_calibration) for: 3 (400 nm)
# Loaded images (400_40445us_d_drk) for: 3 (400 nm)
# Loaded images (400_40854us_1_calibration) for: 3 (400 nm)
# Loaded images (400_40854us_2_calibration) for: 3 (400 nm)
# Loaded images (400_40854us_d_drk) for: 3 (400 nm)
# Loaded images (400_41267us_1_calibration) for: 3 (400 nm)
# Loaded images (400_41267us_2_calibration) for: 3 (400 nm)
# Loaded images (400_41267us_d_drk) for: 3 (400 nm)
# Loaded images (400_41683us_1_calibration) for: 3 (400 nm)
# Loaded images (400_41683us_2_calibration) for: 3 (400 nm)
# Loaded images (400_41683us_d_drk) for: 3 (400 nm)
# Loaded images (400_42105us_1_calibration) for: 3 (400 nm)
# Loaded images (400_42105us_2_calibration) for: 3 (400 nm)
# Loaded images (400_42105us_d_drk) for: 3 (400 nm)
# Loaded images (400_42530us_1_calibration) for: 3 (400 nm)
# Loaded images (400_42530us_2_calibration) for: 3 (400 nm)
# Loaded images (400_42530us_d_drk) for: 3 (400 nm)
# Loaded images (400_446us_1_calibration) for: 3 (400 nm)
# Loaded images (400_446us_2_calibration) for: 3 (400 nm)
# Loaded images (400_446us_d_drk) for: 3 (400 nm)
# Loaded images (400_4770us_1_calibration) for: 3 (400 nm)
# Loaded images (400_4770us_2_calibration) for: 3 (400 nm)
# Loaded images (400_4770us_d_drk) for: 3 (400 nm)
# Loaded images (400_535us_1_calibration) for: 3 (400 nm)
# Loaded images (400_535us_2_calibration) for: 3 (400 nm)
# Loaded images (400_535us_d_drk) for: 3 (400 nm)
# Loaded images (400_5724us_1_calibration) for: 3 (400 nm)
# Loaded images (400_5724us_2_calibration) for: 3 (400 nm)
# Loaded images (400_5724us_d_drk) for: 3 (400 nm)
# Loaded images (400_60us_1_calibration) for: 3 (400 nm)
# Loaded images (400_60us_2_calibration) for: 3 (400 nm)
# Loaded images (400_60us_d_drk) for: 3 (400 nm)
# Loaded images (400_642us_1_calibration) for: 3 (400 nm)
# Loaded images (400_642us_2_calibration) for: 3 (400 nm)
# Loaded images (400_642us_d_drk) for: 3 (400 nm)
# Loaded images (400_6869us_1_calibration) for: 3 (400 nm)
# Loaded images (400_6869us_2_calibration) for: 3 (400 nm)
# Loaded images (400_6869us_d_drk) for: 3 (400 nm)
# Loaded images (400_72us_1_calibration) for: 3 (400 nm)
# Loaded images (400_72us_2_calibration) for: 3 (400 nm)
# Loaded images (400_72us_d_drk) for: 3 (400 nm)
# Loaded images (400_770us_1_calibration) for: 3 (400 nm)
# Loaded images (400_770us_2_calibration) for: 3 (400 nm)
# Loaded images (400_770us_d_drk) for: 3 (400 nm)
# Loaded images (400_8243us_1_calibration) for: 3 (400 nm)
# Loaded images (400_8243us_2_calibration) for: 3 (400 nm)
# Loaded images (400_8243us_d_drk) for: 3 (400 nm)
# Loaded images (400_86us_1_calibration) for: 3 (400 nm)
# Loaded images (400_86us_2_calibration) for: 3 (400 nm)
# Loaded images (400_86us_d_drk) for: 3 (400 nm)
# Loaded images (400_924us_1_calibration) for: 3 (400 nm)
# Loaded images (400_924us_2_calibration) for: 3 (400 nm)
# Loaded images (400_924us_d_drk) for: 3 (400 nm)
# Loaded images (400_9891us_1_calibration) for: 3 (400 nm)
# Loaded images (400_9891us_2_calibration) for: 3 (400 nm)
# Loaded images (400_9891us_d_drk) for: 3 (400 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99/4_725
# Loaded images (725_104us_1_calibration) for: 4 (725 nm)
# Loaded images (725_104us_2_calibration) for: 4 (725 nm)
# Loaded images (725_104us_d_drk) for: 4 (725 nm)
# Loaded images (725_1109us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1109us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1109us_d_drk) for: 4 (725 nm)
# Loaded images (725_124us_1_calibration) for: 4 (725 nm)
# Loaded images (725_124us_2_calibration) for: 4 (725 nm)
# Loaded images (725_124us_d_drk) for: 4 (725 nm)
# Loaded images (725_1331us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1331us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1331us_d_drk) for: 4 (725 nm)
# Loaded images (725_149us_1_calibration) for: 4 (725 nm)
# Loaded images (725_149us_2_calibration) for: 4 (725 nm)
# Loaded images (725_149us_d_drk) for: 4 (725 nm)
# Loaded images (725_1597us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1597us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1597us_d_drk) for: 4 (725 nm)
# Loaded images (725_179us_1_calibration) for: 4 (725 nm)
# Loaded images (725_179us_2_calibration) for: 4 (725 nm)
# Loaded images (725_179us_d_drk) for: 4 (725 nm)
# Loaded images (725_1917us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1917us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1917us_d_drk) for: 4 (725 nm)
# Loaded images (725_215us_1_calibration) for: 4 (725 nm)
# Loaded images (725_215us_2_calibration) for: 4 (725 nm)
# Loaded images (725_215us_d_drk) for: 4 (725 nm)
# Loaded images (725_2300us_1_calibration) for: 4 (725 nm)
# Loaded images (725_2300us_2_calibration) for: 4 (725 nm)
# Loaded images (725_2300us_d_drk) for: 4 (725 nm)
# Loaded images (725_258us_1_calibration) for: 4 (725 nm)
# Loaded images (725_258us_2_calibration) for: 4 (725 nm)
# Loaded images (725_258us_d_drk) for: 4 (725 nm)
# Loaded images (725_2760us_1_calibration) for: 4 (725 nm)
# Loaded images (725_2760us_2_calibration) for: 4 (725 nm)
# Loaded images (725_2760us_d_drk) for: 4 (725 nm)
# Loaded images (725_310us_1_calibration) for: 4 (725 nm)
# Loaded images (725_310us_2_calibration) for: 4 (725 nm)
# Loaded images (725_310us_d_drk) for: 4 (725 nm)
# Loaded images (725_3313us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3313us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3313us_d_drk) for: 4 (725 nm)
# Loaded images (725_3715us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3715us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3715us_d_drk) for: 4 (725 nm)
# Loaded images (725_372us_1_calibration) for: 4 (725 nm)
# Loaded images (725_372us_2_calibration) for: 4 (725 nm)
# Loaded images (725_372us_d_drk) for: 4 (725 nm)
# Loaded images (725_3753us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3753us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3753us_d_drk) for: 4 (725 nm)
# Loaded images (725_3791us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3791us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3791us_d_drk) for: 4 (725 nm)
# Loaded images (725_3829us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3829us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3829us_d_drk) for: 4 (725 nm)
# Loaded images (725_3868us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3868us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3868us_d_drk) for: 4 (725 nm)
# Loaded images (725_3907us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3907us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3907us_d_drk) for: 4 (725 nm)
# Loaded images (725_3946us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3946us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3946us_d_drk) for: 4 (725 nm)
# Loaded images (725_3975us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3975us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3975us_d_drk) for: 4 (725 nm)
# Loaded images (725_3986us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3986us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3986us_d_drk) for: 4 (725 nm)
# Loaded images (725_4027us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4027us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4027us_d_drk) for: 4 (725 nm)
# Loaded images (725_4067us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4067us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4067us_d_drk) for: 4 (725 nm)
# Loaded images (725_4108us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4108us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4108us_d_drk) for: 4 (725 nm)
# Loaded images (725_4150us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4150us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4150us_d_drk) for: 4 (725 nm)
# Loaded images (725_4192us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4192us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4192us_d_drk) for: 4 (725 nm)
# Loaded images (725_4234us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4234us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4234us_d_drk) for: 4 (725 nm)
# Loaded images (725_4277us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4277us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4277us_d_drk) for: 4 (725 nm)
# Loaded images (725_4320us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4320us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4320us_d_drk) for: 4 (725 nm)
# Loaded images (725_4364us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4364us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4364us_d_drk) for: 4 (725 nm)
# Loaded images (725_4408us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4408us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4408us_d_drk) for: 4 (725 nm)
# Loaded images (725_4452us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4452us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4452us_d_drk) for: 4 (725 nm)
# Loaded images (725_446us_1_calibration) for: 4 (725 nm)
# Loaded images (725_446us_2_calibration) for: 4 (725 nm)
# Loaded images (725_446us_d_drk) for: 4 (725 nm)
# Loaded images (725_4497us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4497us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4497us_d_drk) for: 4 (725 nm)
# Loaded images (725_4543us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4543us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4543us_d_drk) for: 4 (725 nm)
# Loaded images (725_4589us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4589us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4589us_d_drk) for: 4 (725 nm)
# Loaded images (725_4635us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4635us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4635us_d_drk) for: 4 (725 nm)
# Loaded images (725_4682us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4682us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4682us_d_drk) for: 4 (725 nm)
# Loaded images (725_4729us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4729us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4729us_d_drk) for: 4 (725 nm)
# Loaded images (725_4770us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4770us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4770us_d_drk) for: 4 (725 nm)
# Loaded images (725_4777us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4777us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4777us_d_drk) for: 4 (725 nm)
# Loaded images (725_4825us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4825us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4825us_d_drk) for: 4 (725 nm)
# Loaded images (725_4874us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4874us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4874us_d_drk) for: 4 (725 nm)
# Loaded images (725_4923us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4923us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4923us_d_drk) for: 4 (725 nm)
# Loaded images (725_4973us_1_calibration) for: 4 (725 nm)
# Loaded images (725_4973us_2_calibration) for: 4 (725 nm)
# Loaded images (725_4973us_d_drk) for: 4 (725 nm)
# Loaded images (725_5023us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5023us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5023us_d_drk) for: 4 (725 nm)
# Loaded images (725_5074us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5074us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5074us_d_drk) for: 4 (725 nm)
# Loaded images (725_5125us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5125us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5125us_d_drk) for: 4 (725 nm)
# Loaded images (725_5177us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5177us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5177us_d_drk) for: 4 (725 nm)
# Loaded images (725_5229us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5229us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5229us_d_drk) for: 4 (725 nm)
# Loaded images (725_5282us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5282us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5282us_d_drk) for: 4 (725 nm)
# Loaded images (725_5335us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5335us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5335us_d_drk) for: 4 (725 nm)
# Loaded images (725_535us_1_calibration) for: 4 (725 nm)
# Loaded images (725_535us_2_calibration) for: 4 (725 nm)
# Loaded images (725_535us_d_drk) for: 4 (725 nm)
# Loaded images (725_5389us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5389us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5389us_d_drk) for: 4 (725 nm)
# Loaded images (725_5443us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5443us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5443us_d_drk) for: 4 (725 nm)
# Loaded images (725_5498us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5498us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5498us_d_drk) for: 4 (725 nm)
# Loaded images (725_5554us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5554us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5554us_d_drk) for: 4 (725 nm)
# Loaded images (725_5610us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5610us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5610us_d_drk) for: 4 (725 nm)
# Loaded images (725_5667us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5667us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5667us_d_drk) for: 4 (725 nm)
# Loaded images (725_5724us_1_calibration) for: 4 (725 nm)
# Loaded images (725_5724us_2_calibration) for: 4 (725 nm)
# Loaded images (725_5724us_d_drk) for: 4 (725 nm)
# Loaded images (725_60us_1_calibration) for: 4 (725 nm)
# Loaded images (725_60us_2_calibration) for: 4 (725 nm)
# Loaded images (725_60us_d_drk) for: 4 (725 nm)
# Loaded images (725_642us_1_calibration) for: 4 (725 nm)
# Loaded images (725_642us_2_calibration) for: 4 (725 nm)
# Loaded images (725_642us_d_drk) for: 4 (725 nm)
# Loaded images (725_72us_1_calibration) for: 4 (725 nm)
# Loaded images (725_72us_2_calibration) for: 4 (725 nm)
# Loaded images (725_72us_d_drk) for: 4 (725 nm)
# Loaded images (725_770us_1_calibration) for: 4 (725 nm)
# Loaded images (725_770us_2_calibration) for: 4 (725 nm)
# Loaded images (725_770us_d_drk) for: 4 (725 nm)
# Loaded images (725_86us_1_calibration) for: 4 (725 nm)
# Loaded images (725_86us_2_calibration) for: 4 (725 nm)
# Loaded images (725_86us_d_drk) for: 4 (725 nm)
# Loaded images (725_924us_1_calibration) for: 4 (725 nm)
# Loaded images (725_924us_2_calibration) for: 4 (725 nm)
# Loaded images (725_924us_d_drk) for: 4 (725 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99/5_850
# Loaded images (850_10019us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10019us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10019us_d_drk) for: 5 (850 nm)
# Loaded images (850_10121us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10121us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10121us_d_drk) for: 5 (850 nm)
# Loaded images (850_10223us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10223us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10223us_d_drk) for: 5 (850 nm)
# Loaded images (850_10326us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10326us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10326us_d_drk) for: 5 (850 nm)
# Loaded images (850_10430us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10430us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10430us_d_drk) for: 5 (850 nm)
# Loaded images (850_104us_1_calibration) for: 5 (850 nm)
# Loaded images (850_104us_2_calibration) for: 5 (850 nm)
# Loaded images (850_104us_d_drk) for: 5 (850 nm)
# Loaded images (850_10536us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10536us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10536us_d_drk) for: 5 (850 nm)
# Loaded images (850_10642us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10642us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10642us_d_drk) for: 5 (850 nm)
# Loaded images (850_10750us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10750us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10750us_d_drk) for: 5 (850 nm)
# Loaded images (850_10858us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10858us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10858us_d_drk) for: 5 (850 nm)
# Loaded images (850_10968us_1_calibration) for: 5 (850 nm)
# Loaded images (850_10968us_2_calibration) for: 5 (850 nm)
# Loaded images (850_10968us_d_drk) for: 5 (850 nm)
# Loaded images (850_11079us_1_calibration) for: 5 (850 nm)
# Loaded images (850_11079us_2_calibration) for: 5 (850 nm)
# Loaded images (850_11079us_d_drk) for: 5 (850 nm)
# Loaded images (850_1109us_1_calibration) for: 5 (850 nm)
# Loaded images (850_1109us_2_calibration) for: 5 (850 nm)
# Loaded images (850_1109us_d_drk) for: 5 (850 nm)
# Loaded images (850_11191us_1_calibration) for: 5 (850 nm)
# Loaded images (850_11191us_2_calibration) for: 5 (850 nm)
# Loaded images (850_11191us_d_drk) for: 5 (850 nm)
# Loaded images (850_11304us_1_calibration) for: 5 (850 nm)
# Loaded images (850_11304us_2_calibration) for: 5 (850 nm)
# Loaded images (850_11304us_d_drk) for: 5 (850 nm)
# ...
# Loaded images (550_1978us_2_calibration) for: 6 (550 nm)
# Loaded images (550_1978us_d_drk) for: 6 (550 nm)
# Loaded images (550_1998us_1_calibration) for: 6 (550 nm)
# Loaded images (550_1998us_2_calibration) for: 6 (550 nm)
# Loaded images (550_1998us_d_drk) for: 6 (550 nm)
# Loaded images (550_2019us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2019us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2019us_d_drk) for: 6 (550 nm)
# Loaded images (550_2039us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2039us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2039us_d_drk) for: 6 (550 nm)
# Loaded images (550_2060us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2060us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2060us_d_drk) for: 6 (550 nm)
# Loaded images (550_2080us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2080us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2080us_d_drk) for: 6 (550 nm)
# Loaded images (550_2101us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2101us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2101us_d_drk) for: 6 (550 nm)
# Loaded images (550_2123us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2123us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2123us_d_drk) for: 6 (550 nm)
# Loaded images (550_2144us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2144us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2144us_d_drk) for: 6 (550 nm)
# Loaded images (550_215us_1_calibration) for: 6 (550 nm)
# Loaded images (550_215us_2_calibration) for: 6 (550 nm)
# Loaded images (550_215us_d_drk) for: 6 (550 nm)
# Loaded images (550_2166us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2166us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2166us_d_drk) for: 6 (550 nm)
# Loaded images (550_2188us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2188us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2188us_d_drk) for: 6 (550 nm)
# Loaded images (550_2210us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2210us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2210us_d_drk) for: 6 (550 nm)
# Loaded images (550_2232us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2232us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2232us_d_drk) for: 6 (550 nm)
# Loaded images (550_2255us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2255us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2255us_d_drk) for: 6 (550 nm)
# Loaded images (550_2277us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2277us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2277us_d_drk) for: 6 (550 nm)
# Loaded images (550_2300us_1_calibration) for: 6 (550 nm)
# Loaded images (550_2300us_2_calibration) for: 6 (550 nm)
# Loaded images (550_2300us_d_drk) for: 6 (550 nm)
# Loaded images (550_258us_1_calibration) for: 6 (550 nm)
# Loaded images (550_258us_2_calibration) for: 6 (550 nm)
# Loaded images (550_258us_d_drk) for: 6 (550 nm)
# Loaded images (550_310us_1_calibration) for: 6 (550 nm)
# Loaded images (550_310us_2_calibration) for: 6 (550 nm)
# Loaded images (550_310us_d_drk) for: 6 (550 nm)
# Loaded images (550_372us_1_calibration) for: 6 (550 nm)
# Loaded images (550_372us_2_calibration) for: 6 (550 nm)
# Loaded images (550_372us_d_drk) for: 6 (550 nm)
# Loaded images (550_446us_1_calibration) for: 6 (550 nm)
# Loaded images (550_446us_2_calibration) for: 6 (550 nm)
# Loaded images (550_446us_d_drk) for: 6 (550 nm)
# Loaded images (550_535us_1_calibration) for: 6 (550 nm)
# Loaded images (550_535us_2_calibration) for: 6 (550 nm)
# Loaded images (550_535us_d_drk) for: 6 (550 nm)
# Loaded images (550_60us_1_calibration) for: 6 (550 nm)
# Loaded images (550_60us_2_calibration) for: 6 (550 nm)
# Loaded images (550_60us_d_drk) for: 6 (550 nm)
# Loaded images (550_642us_1_calibration) for: 6 (550 nm)
# Loaded images (550_642us_2_calibration) for: 6 (550 nm)
# Loaded images (550_642us_d_drk) for: 6 (550 nm)
# Loaded images (550_72us_1_calibration) for: 6 (550 nm)
# Loaded images (550_72us_2_calibration) for: 6 (550 nm)
# Loaded images (550_72us_d_drk) for: 6 (550 nm)
# Loaded images (550_770us_1_calibration) for: 6 (550 nm)
# Loaded images (550_770us_2_calibration) for: 6 (550 nm)
# Loaded images (550_770us_d_drk) for: 6 (550 nm)
# Loaded images (550_86us_1_calibration) for: 6 (550 nm)
# Loaded images (550_86us_2_calibration) for: 6 (550 nm)
# Loaded images (550_86us_d_drk) for: 6 (550 nm)
# Loaded images (550_924us_1_calibration) for: 6 (550 nm)
# Loaded images (550_924us_2_calibration) for: 6 (550 nm)
# Loaded images (550_924us_d_drk) for: 6 (550 nm)
# --------------------------------------------
# --------------------------------------------
# Processing SCT99/7_950
# Loaded images (950_104us_1_calibration) for: 7 (950 nm)
# Loaded images (950_104us_2_calibration) for: 7 (950 nm)
# Loaded images (950_104us_d_drk) for: 7 (950 nm)
# Loaded images (950_1109us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1109us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1109us_d_drk) for: 7 (950 nm)
# Loaded images (950_11869us_1_calibration) for: 7 (950 nm)
# Loaded images (950_11869us_2_calibration) for: 7 (950 nm)
# Loaded images (950_11869us_d_drk) for: 7 (950 nm)
# Loaded images (950_124us_1_calibration) for: 7 (950 nm)
# Loaded images (950_124us_2_calibration) for: 7 (950 nm)
# Loaded images (950_124us_d_drk) for: 7 (950 nm)
# Loaded images (950_1331us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1331us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1331us_d_drk) for: 7 (950 nm)
# Loaded images (950_14243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_14243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_14243us_d_drk) for: 7 (950 nm)
# Loaded images (950_149us_1_calibration) for: 7 (950 nm)
# Loaded images (950_149us_2_calibration) for: 7 (950 nm)
# Loaded images (950_149us_d_drk) for: 7 (950 nm)
# Loaded images (950_1597us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1597us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1597us_d_drk) for: 7 (950 nm)
# Loaded images (950_17092us_1_calibration) for: 7 (950 nm)
# Loaded images (950_17092us_2_calibration) for: 7 (950 nm)
# Loaded images (950_17092us_d_drk) for: 7 (950 nm)
# Loaded images (950_179us_1_calibration) for: 7 (950 nm)
# Loaded images (950_179us_2_calibration) for: 7 (950 nm)
# Loaded images (950_179us_d_drk) for: 7 (950 nm)
# Loaded images (950_1917us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1917us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1917us_d_drk) for: 7 (950 nm)
# Loaded images (950_20510us_1_calibration) for: 7 (950 nm)
# Loaded images (950_20510us_2_calibration) for: 7 (950 nm)
# Loaded images (950_20510us_d_drk) for: 7 (950 nm)
# Loaded images (950_215us_1_calibration) for: 7 (950 nm)
# Loaded images (950_215us_2_calibration) for: 7 (950 nm)
# Loaded images (950_215us_d_drk) for: 7 (950 nm)
# Loaded images (950_2300us_1_calibration) for: 7 (950 nm)
# Loaded images (950_2300us_2_calibration) for: 7 (950 nm)
# Loaded images (950_2300us_d_drk) for: 7 (950 nm)
# Loaded images (950_24612us_1_calibration) for: 7 (950 nm)
# Loaded images (950_24612us_2_calibration) for: 7 (950 nm)
# Loaded images (950_24612us_d_drk) for: 7 (950 nm)
# Loaded images (950_258us_1_calibration) for: 7 (950 nm)
# Loaded images (950_258us_2_calibration) for: 7 (950 nm)
# Loaded images (950_258us_d_drk) for: 7 (950 nm)
# Loaded images (950_2760us_1_calibration) for: 7 (950 nm)
# Loaded images (950_2760us_2_calibration) for: 7 (950 nm)
# Loaded images (950_2760us_d_drk) for: 7 (950 nm)
# Loaded images (950_29535us_1_calibration) for: 7 (950 nm)
# Loaded images (950_29535us_2_calibration) for: 7 (950 nm)
# Loaded images (950_29535us_d_drk) for: 7 (950 nm)
# Loaded images (950_310us_1_calibration) for: 7 (950 nm)
# Loaded images (950_310us_2_calibration) for: 7 (950 nm)
# Loaded images (950_310us_d_drk) for: 7 (950 nm)
# Loaded images (950_3313us_1_calibration) for: 7 (950 nm)
# Loaded images (950_3313us_2_calibration) for: 7 (950 nm)
# Loaded images (950_3313us_d_drk) for: 7 (950 nm)
# Loaded images (950_35442us_1_calibration) for: 7 (950 nm)
# Loaded images (950_35442us_2_calibration) for: 7 (950 nm)
# Loaded images (950_35442us_d_drk) for: 7 (950 nm)
# Loaded images (950_372us_1_calibration) for: 7 (950 nm)
# Loaded images (950_372us_2_calibration) for: 7 (950 nm)
# Loaded images (950_372us_d_drk) for: 7 (950 nm)
# Loaded images (950_3975us_1_calibration) for: 7 (950 nm)
# Loaded images (950_3975us_2_calibration) for: 7 (950 nm)
# Loaded images (950_3975us_d_drk) for: 7 (950 nm)
# Loaded images (950_42530us_1_calibration) for: 7 (950 nm)
# Loaded images (950_42530us_2_calibration) for: 7 (950 nm)
# Loaded images (950_42530us_d_drk) for: 7 (950 nm)
# Loaded images (950_446us_1_calibration) for: 7 (950 nm)
# Loaded images (950_446us_2_calibration) for: 7 (950 nm)
# Loaded images (950_446us_d_drk) for: 7 (950 nm)
# Loaded images (950_46688us_1_calibration) for: 7 (950 nm)
# Loaded images (950_46688us_2_calibration) for: 7 (950 nm)
# Loaded images (950_46688us_d_drk) for: 7 (950 nm)
# Loaded images (950_47160us_1_calibration) for: 7 (950 nm)
# Loaded images (950_47160us_2_calibration) for: 7 (950 nm)
# Loaded images (950_47160us_d_drk) for: 7 (950 nm)
# Loaded images (950_47636us_1_calibration) for: 7 (950 nm)
# Loaded images (950_47636us_2_calibration) for: 7 (950 nm)
# Loaded images (950_47636us_d_drk) for: 7 (950 nm)
# Loaded images (950_4770us_1_calibration) for: 7 (950 nm)
# Loaded images (950_4770us_2_calibration) for: 7 (950 nm)
# Loaded images (950_4770us_d_drk) for: 7 (950 nm)
# Loaded images (950_48117us_1_calibration) for: 7 (950 nm)
# Loaded images (950_48117us_2_calibration) for: 7 (950 nm)
# Loaded images (950_48117us_d_drk) for: 7 (950 nm)
# Loaded images (950_48603us_1_calibration) for: 7 (950 nm)
# Loaded images (950_48603us_2_calibration) for: 7 (950 nm)
# Loaded images (950_48603us_d_drk) for: 7 (950 nm)
# Loaded images (950_49094us_1_calibration) for: 7 (950 nm)
# Loaded images (950_49094us_2_calibration) for: 7 (950 nm)
# Loaded images (950_49094us_d_drk) for: 7 (950 nm)
# Loaded images (950_49590us_1_calibration) for: 7 (950 nm)
# Loaded images (950_49590us_2_calibration) for: 7 (950 nm)
# Loaded images (950_49590us_d_drk) for: 7 (950 nm)
# Loaded images (950_50091us_1_calibration) for: 7 (950 nm)
# Loaded images (950_50091us_2_calibration) for: 7 (950 nm)
# Loaded images (950_50091us_d_drk) for: 7 (950 nm)
# Loaded images (950_50597us_1_calibration) for: 7 (950 nm)
# Loaded images (950_50597us_2_calibration) for: 7 (950 nm)
# Loaded images (950_50597us_d_drk) for: 7 (950 nm)
# Loaded images (950_51036us_1_calibration) for: 7 (950 nm)
# Loaded images (950_51036us_2_calibration) for: 7 (950 nm)
# Loaded images (950_51036us_d_drk) for: 7 (950 nm)
# Loaded images (950_51108us_1_calibration) for: 7 (950 nm)
# Loaded images (950_51108us_2_calibration) for: 7 (950 nm)
# Loaded images (950_51108us_d_drk) for: 7 (950 nm)
# Loaded images (950_51624us_1_calibration) for: 7 (950 nm)
# Loaded images (950_51624us_2_calibration) for: 7 (950 nm)
# Loaded images (950_51624us_d_drk) for: 7 (950 nm)
# Loaded images (950_52146us_1_calibration) for: 7 (950 nm)
# Loaded images (950_52146us_2_calibration) for: 7 (950 nm)
# Loaded images (950_52146us_d_drk) for: 7 (950 nm)
# Loaded images (950_52672us_1_calibration) for: 7 (950 nm)
# Loaded images (950_52672us_2_calibration) for: 7 (950 nm)
# Loaded images (950_52672us_d_drk) for: 7 (950 nm)
# Loaded images (950_53205us_1_calibration) for: 7 (950 nm)
# Loaded images (950_53205us_2_calibration) for: 7 (950 nm)
# Loaded images (950_53205us_d_drk) for: 7 (950 nm)
# Loaded images (950_535us_1_calibration) for: 7 (950 nm)
# Loaded images (950_535us_2_calibration) for: 7 (950 nm)
# Loaded images (950_535us_d_drk) for: 7 (950 nm)
# Loaded images (950_53742us_1_calibration) for: 7 (950 nm)
# Loaded images (950_53742us_2_calibration) for: 7 (950 nm)
# Loaded images (950_53742us_d_drk) for: 7 (950 nm)
# Loaded images (950_54285us_1_calibration) for: 7 (950 nm)
# Loaded images (950_54285us_2_calibration) for: 7 (950 nm)
# Loaded images (950_54285us_d_drk) for: 7 (950 nm)
# Loaded images (950_54833us_1_calibration) for: 7 (950 nm)
# Loaded images (950_54833us_2_calibration) for: 7 (950 nm)
# Loaded images (950_54833us_d_drk) for: 7 (950 nm)
# Loaded images (950_55387us_1_calibration) for: 7 (950 nm)
# Loaded images (950_55387us_2_calibration) for: 7 (950 nm)
# Loaded images (950_55387us_d_drk) for: 7 (950 nm)
# Loaded images (950_55946us_1_calibration) for: 7 (950 nm)
# Loaded images (950_55946us_2_calibration) for: 7 (950 nm)
# Loaded images (950_55946us_d_drk) for: 7 (950 nm)
# Loaded images (950_56512us_1_calibration) for: 7 (950 nm)
# Loaded images (950_56512us_2_calibration) for: 7 (950 nm)
# Loaded images (950_56512us_d_drk) for: 7 (950 nm)
# Loaded images (950_57082us_1_calibration) for: 7 (950 nm)
# Loaded images (950_57082us_2_calibration) for: 7 (950 nm)
# Loaded images (950_57082us_d_drk) for: 7 (950 nm)
# Loaded images (950_5724us_1_calibration) for: 7 (950 nm)
# Loaded images (950_5724us_2_calibration) for: 7 (950 nm)
# Loaded images (950_5724us_d_drk) for: 7 (950 nm)
# Loaded images (950_57659us_1_calibration) for: 7 (950 nm)
# Loaded images (950_57659us_2_calibration) for: 7 (950 nm)
# Loaded images (950_57659us_d_drk) for: 7 (950 nm)
# Loaded images (950_58241us_1_calibration) for: 7 (950 nm)
# Loaded images (950_58241us_2_calibration) for: 7 (950 nm)
# Loaded images (950_58241us_d_drk) for: 7 (950 nm)
# Loaded images (950_58830us_1_calibration) for: 7 (950 nm)
# Loaded images (950_58830us_2_calibration) for: 7 (950 nm)
# Loaded images (950_58830us_d_drk) for: 7 (950 nm)
# Loaded images (950_59424us_1_calibration) for: 7 (950 nm)
# Loaded images (950_59424us_2_calibration) for: 7 (950 nm)
# Loaded images (950_59424us_d_drk) for: 7 (950 nm)
# Loaded images (950_60024us_1_calibration) for: 7 (950 nm)
# Loaded images (950_60024us_2_calibration) for: 7 (950 nm)
# Loaded images (950_60024us_d_drk) for: 7 (950 nm)
# Loaded images (950_60631us_1_calibration) for: 7 (950 nm)
# Loaded images (950_60631us_2_calibration) for: 7 (950 nm)
# Loaded images (950_60631us_d_drk) for: 7 (950 nm)
# Loaded images (950_60us_1_calibration) for: 7 (950 nm)
# Loaded images (950_60us_2_calibration) for: 7 (950 nm)
# Loaded images (950_60us_d_drk) for: 7 (950 nm)
# Loaded images (950_61243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_61243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_61243us_d_drk) for: 7 (950 nm)
# Loaded images (950_642us_1_calibration) for: 7 (950 nm)
# Loaded images (950_642us_2_calibration) for: 7 (950 nm)
# Loaded images (950_642us_d_drk) for: 7 (950 nm)
# Loaded images (950_6869us_1_calibration) for: 7 (950 nm)
# Loaded images (950_6869us_2_calibration) for: 7 (950 nm)
# Loaded images (950_6869us_d_drk) for: 7 (950 nm)
# Loaded images (950_72us_1_calibration) for: 7 (950 nm)
# Loaded images (950_72us_2_calibration) for: 7 (950 nm)
# Loaded images (950_72us_d_drk) for: 7 (950 nm)
# Loaded images (950_770us_1_calibration) for: 7 (950 nm)
# Loaded images (950_770us_2_calibration) for: 7 (950 nm)
# Loaded images (950_770us_d_drk) for: 7 (950 nm)
# Loaded images (950_8243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_8243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_8243us_d_drk) for: 7 (950 nm)
# Loaded images (950_86us_1_calibration) for: 7 (950 nm)
# Loaded images (950_86us_2_calibration) for: 7 (950 nm)
# Loaded images (950_86us_d_drk) for: 7 (950 nm)
# Loaded images (950_924us_1_calibration) for: 7 (950 nm)
# Loaded images (950_924us_2_calibration) for: 7 (950 nm)
# Loaded images (950_924us_d_drk) for: 7 (950 nm)
# Loaded images (950_9891us_1_calibration) for: 7 (950 nm)
# Loaded images (950_9891us_2_calibration) for: 7 (950 nm)
# Loaded images (950_9891us_d_drk) for: 7 (950 nm)
# --------------------------------------------
#                channel     k_adc     full_well  read_noise         DR
# 0  ../data/SCT99/0_650  4.650351  17308.570154    8.438075  66.240356
# 1  ../data/SCT99/1_475  4.798178  17981.482217    3.131240  75.182183
# 2  ../data/SCT99/3_400  4.718340  17379.483529    1.647762  80.462850
# 3  ../data/SCT99/4_725  4.833022  17831.878660    7.700374  67.293705
# 4  ../data/SCT99/5_850  4.652724  17341.676801    3.574052  73.718604
# 5  ../data/SCT99/6_550  4.895812  18090.266881    9.446503  65.643478
# 6  ../data/SCT99/7_950  4.718582  16082.058876    5.057681  70.047804

# %%
subject = 'SCT5'
process_ptc(subject)
# Out:
# --------------------------------------------
# Processing SCT5/0_650
# Loaded images (650_100784us_1_calibration) for: 0 (650 nm)
# Loaded images (650_100784us_2_calibration) for: 0 (650 nm)
# Loaded images (650_100784us_d_drk) for: 0 (650 nm)
# Loaded images (650_101802us_1_calibration) for: 0 (650 nm)
# Loaded images (650_101802us_2_calibration) for: 0 (650 nm)
# Loaded images (650_101802us_d_drk) for: 0 (650 nm)
# Loaded images (650_102830us_1_calibration) for: 0 (650 nm)
# Loaded images (650_102830us_2_calibration) for: 0 (650 nm)
# Loaded images (650_102830us_d_drk) for: 0 (650 nm)
# Loaded images (650_103869us_1_calibration) for: 0 (650 nm)
# Loaded images (650_103869us_2_calibration) for: 0 (650 nm)
# Loaded images (650_103869us_d_drk) for: 0 (650 nm)
# Loaded images (650_104918us_1_calibration) for: 0 (650 nm)
# Loaded images (650_104918us_2_calibration) for: 0 (650 nm)
# Loaded images (650_104918us_d_drk) for: 0 (650 nm)
# Loaded images (650_104us_1_calibration) for: 0 (650 nm)
# Loaded images (650_104us_2_calibration) for: 0 (650 nm)
# Loaded images (650_104us_d_drk) for: 0 (650 nm)
# Loaded images (650_105828us_1_calibration) for: 0 (650 nm)
# Loaded images (650_105828us_2_calibration) for: 0 (650 nm)
# Loaded images (650_105828us_d_drk) for: 0 (650 nm)
# Loaded images (650_105978us_1_calibration) for: 0 (650 nm)
# Loaded images (650_105978us_2_calibration) for: 0 (650 nm)
# Loaded images (650_105978us_d_drk) for: 0 (650 nm)
# Loaded images (650_107048us_1_calibration) for: 0 (650 nm)
# Loaded images (650_107048us_2_calibration) for: 0 (650 nm)
# Loaded images (650_107048us_d_drk) for: 0 (650 nm)
# Loaded images (650_108129us_1_calibration) for: 0 (650 nm)
# Loaded images (650_108129us_2_calibration) for: 0 (650 nm)
# Loaded images (650_108129us_d_drk) for: 0 (650 nm)
# Loaded images (650_109222us_1_calibration) for: 0 (650 nm)
# Loaded images (650_109222us_2_calibration) for: 0 (650 nm)
# Loaded images (650_109222us_d_drk) for: 0 (650 nm)
# Loaded images (650_110325us_1_calibration) for: 0 (650 nm)
# Loaded images (650_110325us_2_calibration) for: 0 (650 nm)
# Loaded images (650_110325us_d_drk) for: 0 (650 nm)
# Loaded images (650_1109us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1109us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1109us_d_drk) for: 0 (650 nm)
# Loaded images (650_111439us_1_calibration) for: 0 (650 nm)
# Loaded images (650_111439us_2_calibration) for: 0 (650 nm)
# Loaded images (650_111439us_d_drk) for: 0 (650 nm)
# Loaded images (650_112565us_1_calibration) for: 0 (650 nm)
# Loaded images (650_112565us_2_calibration) for: 0 (650 nm)
# Loaded images (650_112565us_d_drk) for: 0 (650 nm)
# Loaded images (650_113702us_1_calibration) for: 0 (650 nm)
# Loaded images (650_113702us_2_calibration) for: 0 (650 nm)
# Loaded images (650_113702us_d_drk) for: 0 (650 nm)
# Loaded images (650_114851us_1_calibration) for: 0 (650 nm)
# Loaded images (650_114851us_2_calibration) for: 0 (650 nm)
# Loaded images (650_114851us_d_drk) for: 0 (650 nm)
# Loaded images (650_116011us_1_calibration) for: 0 (650 nm)
# Loaded images (650_116011us_2_calibration) for: 0 (650 nm)
# Loaded images (650_116011us_d_drk) for: 0 (650 nm)
# Loaded images (650_117182us_1_calibration) for: 0 (650 nm)
# Loaded images (650_117182us_2_calibration) for: 0 (650 nm)
# Loaded images (650_117182us_d_drk) for: 0 (650 nm)
# Loaded images (650_118366us_1_calibration) for: 0 (650 nm)
# Loaded images (650_118366us_2_calibration) for: 0 (650 nm)
# Loaded images (650_118366us_d_drk) for: 0 (650 nm)
# Loaded images (650_11869us_1_calibration) for: 0 (650 nm)
# Loaded images (650_11869us_2_calibration) for: 0 (650 nm)
# Loaded images (650_11869us_d_drk) for: 0 (650 nm)
# Loaded images (650_119562us_1_calibration) for: 0 (650 nm)
# Loaded images (650_119562us_2_calibration) for: 0 (650 nm)
# Loaded images (650_119562us_d_drk) for: 0 (650 nm)
# Loaded images (650_120769us_1_calibration) for: 0 (650 nm)
# Loaded images (650_120769us_2_calibration) for: 0 (650 nm)
# Loaded images (650_120769us_d_drk) for: 0 (650 nm)
# Loaded images (650_121989us_1_calibration) for: 0 (650 nm)
# Loaded images (650_121989us_2_calibration) for: 0 (650 nm)
# Loaded images (650_121989us_d_drk) for: 0 (650 nm)
# Loaded images (650_123222us_1_calibration) for: 0 (650 nm)
# Loaded images (650_123222us_2_calibration) for: 0 (650 nm)
# Loaded images (650_123222us_d_drk) for: 0 (650 nm)
# Loaded images (650_124466us_1_calibration) for: 0 (650 nm)
# Loaded images (650_124466us_2_calibration) for: 0 (650 nm)
# Loaded images (650_124466us_d_drk) for: 0 (650 nm)
# Loaded images (650_124us_1_calibration) for: 0 (650 nm)
# Loaded images (650_124us_2_calibration) for: 0 (650 nm)
# Loaded images (650_124us_d_drk) for: 0 (650 nm)
# Loaded images (650_125723us_1_calibration) for: 0 (650 nm)
# Loaded images (650_125723us_2_calibration) for: 0 (650 nm)
# Loaded images (650_125723us_d_drk) for: 0 (650 nm)
# Loaded images (650_126993us_1_calibration) for: 0 (650 nm)
# Loaded images (650_126993us_2_calibration) for: 0 (650 nm)
# Loaded images (650_126993us_d_drk) for: 0 (650 nm)
# Loaded images (650_1331us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1331us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1331us_d_drk) for: 0 (650 nm)
# Loaded images (650_14243us_1_calibration) for: 0 (650 nm)
# Loaded images (650_14243us_2_calibration) for: 0 (650 nm)
# Loaded images (650_14243us_d_drk) for: 0 (650 nm)
# Loaded images (650_149us_1_calibration) for: 0 (650 nm)
# Loaded images (650_149us_2_calibration) for: 0 (650 nm)
# Loaded images (650_149us_d_drk) for: 0 (650 nm)
# Loaded images (650_1597us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1597us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1597us_d_drk) for: 0 (650 nm)
# Loaded images (650_17092us_1_calibration) for: 0 (650 nm)
# Loaded images (650_17092us_2_calibration) for: 0 (650 nm)
# Loaded images (650_17092us_d_drk) for: 0 (650 nm)
# Loaded images (650_179us_1_calibration) for: 0 (650 nm)
# Loaded images (650_179us_2_calibration) for: 0 (650 nm)
# Loaded images (650_179us_d_drk) for: 0 (650 nm)
# Loaded images (650_1917us_1_calibration) for: 0 (650 nm)
# Loaded images (650_1917us_2_calibration) for: 0 (650 nm)
# Loaded images (650_1917us_d_drk) for: 0 (650 nm)
# Loaded images (650_20510us_1_calibration) for: 0 (650 nm)
# Loaded images (650_20510us_2_calibration) for: 0 (650 nm)
# Loaded images (650_20510us_d_drk) for: 0 (650 nm)
# Loaded images (650_215us_1_calibration) for: 0 (650 nm)
# Loaded images (650_215us_2_calibration) for: 0 (650 nm)
# Loaded images (650_215us_d_drk) for: 0 (650 nm)
# Loaded images (650_2300us_1_calibration) for: 0 (650 nm)
# Loaded images (650_2300us_2_calibration) for: 0 (650 nm)
# Loaded images (650_2300us_d_drk) for: 0 (650 nm)
# Loaded images (650_24612us_1_calibration) for: 0 (650 nm)
# Loaded images (650_24612us_2_calibration) for: 0 (650 nm)
# Loaded images (650_24612us_d_drk) for: 0 (650 nm)
# Loaded images (650_258us_1_calibration) for: 0 (650 nm)
# Loaded images (650_258us_2_calibration) for: 0 (650 nm)
# Loaded images (650_258us_d_drk) for: 0 (650 nm)
# Loaded images (650_2760us_1_calibration) for: 0 (650 nm)
# Loaded images (650_2760us_2_calibration) for: 0 (650 nm)
# Loaded images (650_2760us_d_drk) for: 0 (650 nm)
# Loaded images (650_29535us_1_calibration) for: 0 (650 nm)
# Loaded images (650_29535us_2_calibration) for: 0 (650 nm)
# Loaded images (650_29535us_d_drk) for: 0 (650 nm)
# Loaded images (650_310us_1_calibration) for: 0 (650 nm)
# Loaded images (650_310us_2_calibration) for: 0 (650 nm)
# Loaded images (650_310us_d_drk) for: 0 (650 nm)
# Loaded images (650_3313us_1_calibration) for: 0 (650 nm)
# Loaded images (650_3313us_2_calibration) for: 0 (650 nm)
# Loaded images (650_3313us_d_drk) for: 0 (650 nm)
# Loaded images (650_35442us_1_calibration) for: 0 (650 nm)
# Loaded images (650_35442us_2_calibration) for: 0 (650 nm)
# Loaded images (650_35442us_d_drk) for: 0 (650 nm)
# Loaded images (650_372us_1_calibration) for: 0 (650 nm)
# Loaded images (650_372us_2_calibration) for: 0 (650 nm)
# Loaded images (650_372us_d_drk) for: 0 (650 nm)
# Loaded images (650_3975us_1_calibration) for: 0 (650 nm)
# Loaded images (650_3975us_2_calibration) for: 0 (650 nm)
# Loaded images (650_3975us_d_drk) for: 0 (650 nm)
# Loaded images (650_42530us_1_calibration) for: 0 (650 nm)
# Loaded images (650_42530us_2_calibration) for: 0 (650 nm)
# Loaded images (650_42530us_d_drk) for: 0 (650 nm)
# Loaded images (650_446us_1_calibration) for: 0 (650 nm)
# Loaded images (650_446us_2_calibration) for: 0 (650 nm)
# Loaded images (650_446us_d_drk) for: 0 (650 nm)
# Loaded images (650_4770us_1_calibration) for: 0 (650 nm)
# Loaded images (650_4770us_2_calibration) for: 0 (650 nm)
# Loaded images (650_4770us_d_drk) for: 0 (650 nm)
# Loaded images (650_51036us_1_calibration) for: 0 (650 nm)
# Loaded images (650_51036us_2_calibration) for: 0 (650 nm)
# Loaded images (650_51036us_d_drk) for: 0 (650 nm)
# Loaded images (650_535us_1_calibration) for: 0 (650 nm)
# Loaded images (650_535us_2_calibration) for: 0 (650 nm)
# Loaded images (650_535us_d_drk) for: 0 (650 nm)
# Loaded images (650_5724us_1_calibration) for: 0 (650 nm)
# Loaded images (650_5724us_2_calibration) for: 0 (650 nm)
# Loaded images (650_5724us_d_drk) for: 0 (650 nm)
# Loaded images (650_60us_1_calibration) for: 0 (650 nm)
# Loaded images (650_60us_2_calibration) for: 0 (650 nm)
# Loaded images (650_60us_d_drk) for: 0 (650 nm)
# Loaded images (650_61243us_1_calibration) for: 0 (650 nm)
# Loaded images (650_61243us_2_calibration) for: 0 (650 nm)
# Loaded images (650_61243us_d_drk) for: 0 (650 nm)
# Loaded images (650_642us_1_calibration) for: 0 (650 nm)
# Loaded images (650_642us_2_calibration) for: 0 (650 nm)
# Loaded images (650_642us_d_drk) for: 0 (650 nm)
# Loaded images (650_6869us_1_calibration) for: 0 (650 nm)
# Loaded images (650_6869us_2_calibration) for: 0 (650 nm)
# Loaded images (650_6869us_d_drk) for: 0 (650 nm)
# Loaded images (650_72us_1_calibration) for: 0 (650 nm)
# Loaded images (650_72us_2_calibration) for: 0 (650 nm)
# Loaded images (650_72us_d_drk) for: 0 (650 nm)
# Loaded images (650_73492us_1_calibration) for: 0 (650 nm)
# Loaded images (650_73492us_2_calibration) for: 0 (650 nm)
# Loaded images (650_73492us_d_drk) for: 0 (650 nm)
# Loaded images (650_770us_1_calibration) for: 0 (650 nm)
# Loaded images (650_770us_2_calibration) for: 0 (650 nm)
# Loaded images (650_770us_d_drk) for: 0 (650 nm)
# Loaded images (650_79983us_1_calibration) for: 0 (650 nm)
# Loaded images (650_79983us_2_calibration) for: 0 (650 nm)
# Loaded images (650_79983us_d_drk) for: 0 (650 nm)
# Loaded images (650_80791us_1_calibration) for: 0 (650 nm)
# Loaded images (650_80791us_2_calibration) for: 0 (650 nm)
# Loaded images (650_80791us_d_drk) for: 0 (650 nm)
# Loaded images (650_81607us_1_calibration) for: 0 (650 nm)
# Loaded images (650_81607us_2_calibration) for: 0 (650 nm)
# Loaded images (650_81607us_d_drk) for: 0 (650 nm)
# Loaded images (650_82432us_1_calibration) for: 0 (650 nm)
# Loaded images (650_82432us_2_calibration) for: 0 (650 nm)
# Loaded images (650_82432us_d_drk) for: 0 (650 nm)
# Loaded images (650_8243us_1_calibration) for: 0 (650 nm)
# Loaded images (650_8243us_2_calibration) for: 0 (650 nm)
# Loaded images (650_8243us_d_drk) for: 0 (650 nm)
# Loaded images (650_83264us_1_calibration) for: 0 (650 nm)
# Loaded images (650_83264us_2_calibration) for: 0 (650 nm)
# Loaded images (650_83264us_d_drk) for: 0 (650 nm)
# Loaded images (650_84105us_1_calibration) for: 0 (650 nm)
# Loaded images (650_84105us_2_calibration) for: 0 (650 nm)
# Loaded images (650_84105us_d_drk) for: 0 (650 nm)
# Loaded images (650_84955us_1_calibration) for: 0 (650 nm)
# Loaded images (650_84955us_2_calibration) for: 0 (650 nm)
# Loaded images (650_84955us_d_drk) for: 0 (650 nm)
# Loaded images (650_85813us_1_calibration) for: 0 (650 nm)
# Loaded images (650_85813us_2_calibration) for: 0 (650 nm)
# Loaded images (650_85813us_d_drk) for: 0 (650 nm)
# Loaded images (650_86680us_1_calibration) for: 0 (650 nm)
# Loaded images (650_86680us_2_calibration) for: 0 (650 nm)
# Loaded images (650_86680us_d_drk) for: 0 (650 nm)
# Loaded images (650_86us_1_calibration) for: 0 (650 nm)
# Loaded images (650_86us_2_calibration) for: 0 (650 nm)
# Loaded images (650_86us_d_drk) for: 0 (650 nm)
# Loaded images (650_87555us_1_calibration) for: 0 (650 nm)
# Loaded images (650_87555us_2_calibration) for: 0 (650 nm)
# Loaded images (650_87555us_d_drk) for: 0 (650 nm)
# Loaded images (650_88190us_1_calibration) for: 0 (650 nm)
# Loaded images (650_88190us_2_calibration) for: 0 (650 nm)
# Loaded images (650_88190us_d_drk) for: 0 (650 nm)
# Loaded images (650_88440us_1_calibration) for: 0 (650 nm)
# Loaded images (650_88440us_2_calibration) for: 0 (650 nm)
# Loaded images (650_88440us_d_drk) for: 0 (650 nm)
# Loaded images (650_89333us_1_calibration) for: 0 (650 nm)
# Loaded images (650_89333us_2_calibration) for: 0 (650 nm)
# Loaded images (650_89333us_d_drk) for: 0 (650 nm)
# Loaded images (650_90236us_1_calibration) for: 0 (650 nm)
# Loaded images (650_90236us_2_calibration) for: 0 (650 nm)
# Loaded images (650_90236us_d_drk) for: 0 (650 nm)
# Loaded images (650_91147us_1_calibration) for: 0 (650 nm)
# Loaded images (650_91147us_2_calibration) for: 0 (650 nm)
# Loaded images (650_91147us_d_drk) for: 0 (650 nm)
# Loaded images (650_92068us_1_calibration) for: 0 (650 nm)
# Loaded images (650_92068us_2_calibration) for: 0 (650 nm)
# Loaded images (650_92068us_d_drk) for: 0 (650 nm)
# Loaded images (650_924us_1_calibration) for: 0 (650 nm)
# Loaded images (650_924us_2_calibration) for: 0 (650 nm)
# Loaded images (650_924us_d_drk) for: 0 (650 nm)
# Loaded images (650_92998us_1_calibration) for: 0 (650 nm)
# Loaded images (650_92998us_2_calibration) for: 0 (650 nm)
# Loaded images (650_92998us_d_drk) for: 0 (650 nm)
# Loaded images (650_93937us_1_calibration) for: 0 (650 nm)
# Loaded images (650_93937us_2_calibration) for: 0 (650 nm)
# Loaded images (650_93937us_d_drk) for: 0 (650 nm)
# Loaded images (650_94886us_1_calibration) for: 0 (650 nm)
# Loaded images (650_94886us_2_calibration) for: 0 (650 nm)
# Loaded images (650_94886us_d_drk) for: 0 (650 nm)
# Loaded images (650_95844us_1_calibration) for: 0 (650 nm)
# Loaded images (650_95844us_2_calibration) for: 0 (650 nm)
# Loaded images (650_95844us_d_drk) for: 0 (650 nm)
# Loaded images (650_96812us_1_calibration) for: 0 (650 nm)
# Loaded images (650_96812us_2_calibration) for: 0 (650 nm)
# Loaded images (650_96812us_d_drk) for: 0 (650 nm)
# Loaded images (650_97790us_1_calibration) for: 0 (650 nm)
# Loaded images (650_97790us_2_calibration) for: 0 (650 nm)
# Loaded images (650_97790us_d_drk) for: 0 (650 nm)
# Loaded images (650_98778us_1_calibration) for: 0 (650 nm)
# Loaded images (650_98778us_2_calibration) for: 0 (650 nm)
# Loaded images (650_98778us_d_drk) for: 0 (650 nm)
# Loaded images (650_9891us_1_calibration) for: 0 (650 nm)
# Loaded images (650_9891us_2_calibration) for: 0 (650 nm)
# Loaded images (650_9891us_d_drk) for: 0 (650 nm)
# Loaded images (650_99776us_1_calibration) for: 0 (650 nm)
# Loaded images (650_99776us_2_calibration) for: 0 (650 nm)
# Loaded images (650_99776us_d_drk) for: 0 (650 nm)
# /var/folders/w4/44k32f413dd82lxmtw9456w80000gp/T/ipykernel_15079/561204539.py:180: RuntimeWarning: divide by zero encountered in divide
#   drs.append(20.0*np.log10(full_well/read_noise))
# --------------------------------------------
# --------------------------------------------
# Processing SCT5/1_475
# Loaded images (475_104us_1_calibration) for: 1 (475 nm)
# Loaded images (475_104us_2_calibration) for: 1 (475 nm)
# Loaded images (475_104us_d_drk) for: 1 (475 nm)
# Loaded images (475_105828us_1_calibration) for: 1 (475 nm)
# Loaded images (475_105828us_2_calibration) for: 1 (475 nm)
# Loaded images (475_105828us_d_drk) for: 1 (475 nm)
# Loaded images (475_1109us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1109us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1109us_d_drk) for: 1 (475 nm)
# Loaded images (475_11869us_1_calibration) for: 1 (475 nm)
# Loaded images (475_11869us_2_calibration) for: 1 (475 nm)
# Loaded images (475_11869us_d_drk) for: 1 (475 nm)
# Loaded images (475_124us_1_calibration) for: 1 (475 nm)
# Loaded images (475_124us_2_calibration) for: 1 (475 nm)
# Loaded images (475_124us_d_drk) for: 1 (475 nm)
# Loaded images (475_126080us_1_calibration) for: 1 (475 nm)
# Loaded images (475_126080us_2_calibration) for: 1 (475 nm)
# Loaded images (475_126080us_d_drk) for: 1 (475 nm)
# Loaded images (475_126993us_1_calibration) for: 1 (475 nm)
# Loaded images (475_126993us_2_calibration) for: 1 (475 nm)
# Loaded images (475_126993us_d_drk) for: 1 (475 nm)
# Loaded images (475_127353us_1_calibration) for: 1 (475 nm)
# Loaded images (475_127353us_2_calibration) for: 1 (475 nm)
# Loaded images (475_127353us_d_drk) for: 1 (475 nm)
# Loaded images (475_128640us_1_calibration) for: 1 (475 nm)
# Loaded images (475_128640us_2_calibration) for: 1 (475 nm)
# Loaded images (475_128640us_d_drk) for: 1 (475 nm)
# Loaded images (475_129939us_1_calibration) for: 1 (475 nm)
# Loaded images (475_129939us_2_calibration) for: 1 (475 nm)
# Loaded images (475_129939us_d_drk) for: 1 (475 nm)
# Loaded images (475_131252us_1_calibration) for: 1 (475 nm)
# Loaded images (475_131252us_2_calibration) for: 1 (475 nm)
# Loaded images (475_131252us_d_drk) for: 1 (475 nm)
# Loaded images (475_132577us_1_calibration) for: 1 (475 nm)
# Loaded images (475_132577us_2_calibration) for: 1 (475 nm)
# Loaded images (475_132577us_d_drk) for: 1 (475 nm)
# Loaded images (475_1331us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1331us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1331us_d_drk) for: 1 (475 nm)
# Loaded images (475_133917us_1_calibration) for: 1 (475 nm)
# Loaded images (475_133917us_2_calibration) for: 1 (475 nm)
# Loaded images (475_133917us_d_drk) for: 1 (475 nm)
# Loaded images (475_135269us_1_calibration) for: 1 (475 nm)
# Loaded images (475_135269us_2_calibration) for: 1 (475 nm)
# Loaded images (475_135269us_d_drk) for: 1 (475 nm)
# Loaded images (475_136636us_1_calibration) for: 1 (475 nm)
# Loaded images (475_136636us_2_calibration) for: 1 (475 nm)
# Loaded images (475_136636us_d_drk) for: 1 (475 nm)
# Loaded images (475_138016us_1_calibration) for: 1 (475 nm)
# Loaded images (475_138016us_2_calibration) for: 1 (475 nm)
# Loaded images (475_138016us_d_drk) for: 1 (475 nm)
# Loaded images (475_139410us_1_calibration) for: 1 (475 nm)
# Loaded images (475_139410us_2_calibration) for: 1 (475 nm)
# Loaded images (475_139410us_d_drk) for: 1 (475 nm)
# Loaded images (475_140818us_1_calibration) for: 1 (475 nm)
# Loaded images (475_140818us_2_calibration) for: 1 (475 nm)
# Loaded images (475_140818us_d_drk) for: 1 (475 nm)
# Loaded images (475_142241us_1_calibration) for: 1 (475 nm)
# Loaded images (475_142241us_2_calibration) for: 1 (475 nm)
# Loaded images (475_142241us_d_drk) for: 1 (475 nm)
# Loaded images (475_14243us_1_calibration) for: 1 (475 nm)
# Loaded images (475_14243us_2_calibration) for: 1 (475 nm)
# Loaded images (475_14243us_d_drk) for: 1 (475 nm)
# Loaded images (475_143677us_1_calibration) for: 1 (475 nm)
# Loaded images (475_143677us_2_calibration) for: 1 (475 nm)
# Loaded images (475_143677us_d_drk) for: 1 (475 nm)
# Loaded images (475_145129us_1_calibration) for: 1 (475 nm)
# Loaded images (475_145129us_2_calibration) for: 1 (475 nm)
# Loaded images (475_145129us_d_drk) for: 1 (475 nm)
# Loaded images (475_146595us_1_calibration) for: 1 (475 nm)
# Loaded images (475_146595us_2_calibration) for: 1 (475 nm)
# Loaded images (475_146595us_d_drk) for: 1 (475 nm)
# Loaded images (475_148075us_1_calibration) for: 1 (475 nm)
# Loaded images (475_148075us_2_calibration) for: 1 (475 nm)
# Loaded images (475_148075us_d_drk) for: 1 (475 nm)
# Loaded images (475_149571us_1_calibration) for: 1 (475 nm)
# Loaded images (475_149571us_2_calibration) for: 1 (475 nm)
# Loaded images (475_149571us_d_drk) for: 1 (475 nm)
# Loaded images (475_149us_1_calibration) for: 1 (475 nm)
# Loaded images (475_149us_2_calibration) for: 1 (475 nm)
# Loaded images (475_149us_d_drk) for: 1 (475 nm)
# Loaded images (475_151082us_1_calibration) for: 1 (475 nm)
# Loaded images (475_151082us_2_calibration) for: 1 (475 nm)
# Loaded images (475_151082us_d_drk) for: 1 (475 nm)
# Loaded images (475_152392us_1_calibration) for: 1 (475 nm)
# Loaded images (475_152392us_2_calibration) for: 1 (475 nm)
# Loaded images (475_152392us_d_drk) for: 1 (475 nm)
# Loaded images (475_152608us_1_calibration) for: 1 (475 nm)
# Loaded images (475_152608us_2_calibration) for: 1 (475 nm)
# Loaded images (475_152608us_d_drk) for: 1 (475 nm)
# Loaded images (475_154149us_1_calibration) for: 1 (475 nm)
# Loaded images (475_154149us_2_calibration) for: 1 (475 nm)
# Loaded images (475_154149us_d_drk) for: 1 (475 nm)
# Loaded images (475_155706us_1_calibration) for: 1 (475 nm)
# Loaded images (475_155706us_2_calibration) for: 1 (475 nm)
# Loaded images (475_155706us_d_drk) for: 1 (475 nm)
# Loaded images (475_157279us_1_calibration) for: 1 (475 nm)
# Loaded images (475_157279us_2_calibration) for: 1 (475 nm)
# Loaded images (475_157279us_d_drk) for: 1 (475 nm)
# Loaded images (475_158868us_1_calibration) for: 1 (475 nm)
# Loaded images (475_158868us_2_calibration) for: 1 (475 nm)
# Loaded images (475_158868us_d_drk) for: 1 (475 nm)
# Loaded images (475_1597us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1597us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1597us_d_drk) for: 1 (475 nm)
# Loaded images (475_160473us_1_calibration) for: 1 (475 nm)
# Loaded images (475_160473us_2_calibration) for: 1 (475 nm)
# Loaded images (475_160473us_d_drk) for: 1 (475 nm)
# Loaded images (475_162094us_1_calibration) for: 1 (475 nm)
# Loaded images (475_162094us_2_calibration) for: 1 (475 nm)
# Loaded images (475_162094us_d_drk) for: 1 (475 nm)
# Loaded images (475_163731us_1_calibration) for: 1 (475 nm)
# Loaded images (475_163731us_2_calibration) for: 1 (475 nm)
# Loaded images (475_163731us_d_drk) for: 1 (475 nm)
# Loaded images (475_165385us_1_calibration) for: 1 (475 nm)
# Loaded images (475_165385us_2_calibration) for: 1 (475 nm)
# Loaded images (475_165385us_d_drk) for: 1 (475 nm)
# Loaded images (475_167055us_1_calibration) for: 1 (475 nm)
# Loaded images (475_167055us_2_calibration) for: 1 (475 nm)
# Loaded images (475_167055us_d_drk) for: 1 (475 nm)
# Loaded images (475_168743us_1_calibration) for: 1 (475 nm)
# Loaded images (475_168743us_2_calibration) for: 1 (475 nm)
# Loaded images (475_168743us_d_drk) for: 1 (475 nm)
# Loaded images (475_170447us_1_calibration) for: 1 (475 nm)
# Loaded images (475_170447us_2_calibration) for: 1 (475 nm)
# Loaded images (475_170447us_d_drk) for: 1 (475 nm)
# Loaded images (475_17092us_1_calibration) for: 1 (475 nm)
# Loaded images (475_17092us_2_calibration) for: 1 (475 nm)
# Loaded images (475_17092us_d_drk) for: 1 (475 nm)
# Loaded images (475_172169us_1_calibration) for: 1 (475 nm)
# Loaded images (475_172169us_2_calibration) for: 1 (475 nm)
# Loaded images (475_172169us_d_drk) for: 1 (475 nm)
# Loaded images (475_173908us_1_calibration) for: 1 (475 nm)
# Loaded images (475_173908us_2_calibration) for: 1 (475 nm)
# Loaded images (475_173908us_d_drk) for: 1 (475 nm)
# Loaded images (475_175665us_1_calibration) for: 1 (475 nm)
# Loaded images (475_175665us_2_calibration) for: 1 (475 nm)
# Loaded images (475_175665us_d_drk) for: 1 (475 nm)
# Loaded images (475_177439us_1_calibration) for: 1 (475 nm)
# Loaded images (475_177439us_2_calibration) for: 1 (475 nm)
# Loaded images (475_177439us_d_drk) for: 1 (475 nm)
# Loaded images (475_179231us_1_calibration) for: 1 (475 nm)
# Loaded images (475_179231us_2_calibration) for: 1 (475 nm)
# Loaded images (475_179231us_d_drk) for: 1 (475 nm)
# Loaded images (475_179us_1_calibration) for: 1 (475 nm)
# Loaded images (475_179us_2_calibration) for: 1 (475 nm)
# Loaded images (475_179us_d_drk) for: 1 (475 nm)
# Loaded images (475_181042us_1_calibration) for: 1 (475 nm)
# Loaded images (475_181042us_2_calibration) for: 1 (475 nm)
# Loaded images (475_181042us_d_drk) for: 1 (475 nm)
# Loaded images (475_182870us_1_calibration) for: 1 (475 nm)
# Loaded images (475_182870us_2_calibration) for: 1 (475 nm)
# Loaded images (475_182870us_d_drk) for: 1 (475 nm)
# Loaded images (475_1917us_1_calibration) for: 1 (475 nm)
# Loaded images (475_1917us_2_calibration) for: 1 (475 nm)
# Loaded images (475_1917us_d_drk) for: 1 (475 nm)
# Loaded images (475_20510us_1_calibration) for: 1 (475 nm)
# Loaded images (475_20510us_2_calibration) for: 1 (475 nm)
# Loaded images (475_20510us_d_drk) for: 1 (475 nm)
# Loaded images (475_215us_1_calibration) for: 1 (475 nm)
# Loaded images (475_215us_2_calibration) for: 1 (475 nm)
# Loaded images (475_215us_d_drk) for: 1 (475 nm)
# Loaded images (475_2300us_1_calibration) for: 1 (475 nm)
# Loaded images (475_2300us_2_calibration) for: 1 (475 nm)
# Loaded images (475_2300us_d_drk) for: 1 (475 nm)
# Loaded images (475_24612us_1_calibration) for: 1 (475 nm)
# Loaded images (475_24612us_2_calibration) for: 1 (475 nm)
# Loaded images (475_24612us_d_drk) for: 1 (475 nm)
# Loaded images (475_258us_1_calibration) for: 1 (475 nm)
# Loaded images (475_258us_2_calibration) for: 1 (475 nm)
# Loaded images (475_258us_d_drk) for: 1 (475 nm)
# Loaded images (475_2760us_1_calibration) for: 1 (475 nm)
# Loaded images (475_2760us_2_calibration) for: 1 (475 nm)
# Loaded images (475_2760us_d_drk) for: 1 (475 nm)
# Loaded images (475_29535us_1_calibration) for: 1 (475 nm)
# Loaded images (475_29535us_2_calibration) for: 1 (475 nm)
# Loaded images (475_29535us_d_drk) for: 1 (475 nm)
# Loaded images (475_310us_1_calibration) for: 1 (475 nm)
# Loaded images (475_310us_2_calibration) for: 1 (475 nm)
# Loaded images (475_310us_d_drk) for: 1 (475 nm)
# Loaded images (475_3313us_1_calibration) for: 1 (475 nm)
# Loaded images (475_3313us_2_calibration) for: 1 (475 nm)
# Loaded images (475_3313us_d_drk) for: 1 (475 nm)
# Loaded images (475_35442us_1_calibration) for: 1 (475 nm)
# Loaded images (475_35442us_2_calibration) for: 1 (475 nm)
# Loaded images (475_35442us_d_drk) for: 1 (475 nm)
# Loaded images (475_372us_1_calibration) for: 1 (475 nm)
# Loaded images (475_372us_2_calibration) for: 1 (475 nm)
# Loaded images (475_372us_d_drk) for: 1 (475 nm)
# Loaded images (475_3975us_1_calibration) for: 1 (475 nm)
# Loaded images (475_3975us_2_calibration) for: 1 (475 nm)
# Loaded images (475_3975us_d_drk) for: 1 (475 nm)
# Loaded images (475_42530us_1_calibration) for: 1 (475 nm)
# Loaded images (475_42530us_2_calibration) for: 1 (475 nm)
# Loaded images (475_42530us_d_drk) for: 1 (475 nm)
# Loaded images (475_446us_1_calibration) for: 1 (475 nm)
# Loaded images (475_446us_2_calibration) for: 1 (475 nm)
# Loaded images (475_446us_d_drk) for: 1 (475 nm)
# Loaded images (475_4770us_1_calibration) for: 1 (475 nm)
# Loaded images (475_4770us_2_calibration) for: 1 (475 nm)
# Loaded images (475_4770us_d_drk) for: 1 (475 nm)
# Loaded images (475_51036us_1_calibration) for: 1 (475 nm)
# Loaded images (475_51036us_2_calibration) for: 1 (475 nm)
# Loaded images (475_51036us_d_drk) for: 1 (475 nm)
# Loaded images (475_535us_1_calibration) for: 1 (475 nm)
# Loaded images (475_535us_2_calibration) for: 1 (475 nm)
# Loaded images (475_535us_d_drk) for: 1 (475 nm)
# Loaded images (475_5724us_1_calibration) for: 1 (475 nm)
# Loaded images (475_5724us_2_calibration) for: 1 (475 nm)
# Loaded images (475_5724us_d_drk) for: 1 (475 nm)
# Loaded images (475_60us_1_calibration) for: 1 (475 nm)
# Loaded images (475_60us_2_calibration) for: 1 (475 nm)
# Loaded images (475_60us_d_drk) for: 1 (475 nm)
# Loaded images (475_61243us_1_calibration) for: 1 (475 nm)
# Loaded images (475_61243us_2_calibration) for: 1 (475 nm)
# Loaded images (475_61243us_d_drk) for: 1 (475 nm)
# Loaded images (475_642us_1_calibration) for: 1 (475 nm)
# Loaded images (475_642us_2_calibration) for: 1 (475 nm)
# Loaded images (475_642us_d_drk) for: 1 (475 nm)
# Loaded images (475_6869us_1_calibration) for: 1 (475 nm)
# Loaded images (475_6869us_2_calibration) for: 1 (475 nm)
# Loaded images (475_6869us_d_drk) for: 1 (475 nm)
# Loaded images (475_72us_1_calibration) for: 1 (475 nm)
# Loaded images (475_72us_2_calibration) for: 1 (475 nm)
# Loaded images (475_72us_d_drk) for: 1 (475 nm)
# Loaded images (475_73492us_1_calibration) for: 1 (475 nm)
# Loaded images (475_73492us_2_calibration) for: 1 (475 nm)
# Loaded images (475_73492us_d_drk) for: 1 (475 nm)
# Loaded images (475_770us_1_calibration) for: 1 (475 nm)
# Loaded images (475_770us_2_calibration) for: 1 (475 nm)
# Loaded images (475_770us_d_drk) for: 1 (475 nm)
# Loaded images (475_8243us_1_calibration) for: 1 (475 nm)
# Loaded images (475_8243us_2_calibration) for: 1 (475 nm)
# Loaded images (475_8243us_d_drk) for: 1 (475 nm)
# Loaded images (475_86us_1_calibration) for: 1 (475 nm)
# Loaded images (475_86us_2_calibration) for: 1 (475 nm)
# Loaded images (475_86us_d_drk) for: 1 (475 nm)
# Loaded images (475_88190us_1_calibration) for: 1 (475 nm)
# Loaded images (475_88190us_2_calibration) for: 1 (475 nm)
# Loaded images (475_88190us_d_drk) for: 1 (475 nm)
# Loaded images (475_924us_1_calibration) for: 1 (475 nm)
# Loaded images (475_924us_2_calibration) for: 1 (475 nm)
# Loaded images (475_924us_d_drk) for: 1 (475 nm)
# Loaded images (475_9891us_1_calibration) for: 1 (475 nm)
# Loaded images (475_9891us_2_calibration) for: 1 (475 nm)
# Loaded images (475_9891us_d_drk) for: 1 (475 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT5/3_400
# Loaded images (400_104us_1_calibration) for: 3 (400 nm)
# Loaded images (400_104us_2_calibration) for: 3 (400 nm)
# Loaded images (400_104us_d_drk) for: 3 (400 nm)
# Loaded images (400_105828us_1_calibration) for: 3 (400 nm)
# Loaded images (400_105828us_2_calibration) for: 3 (400 nm)
# Loaded images (400_105828us_d_drk) for: 3 (400 nm)
# Loaded images (400_1109us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1109us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1109us_d_drk) for: 3 (400 nm)
# Loaded images (400_11869us_1_calibration) for: 3 (400 nm)
# Loaded images (400_11869us_2_calibration) for: 3 (400 nm)
# Loaded images (400_11869us_d_drk) for: 3 (400 nm)
# Loaded images (400_124us_1_calibration) for: 3 (400 nm)
# Loaded images (400_124us_2_calibration) for: 3 (400 nm)
# Loaded images (400_124us_d_drk) for: 3 (400 nm)
# Loaded images (400_126993us_1_calibration) for: 3 (400 nm)
# Loaded images (400_126993us_2_calibration) for: 3 (400 nm)
# Loaded images (400_126993us_d_drk) for: 3 (400 nm)
# Loaded images (400_1331us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1331us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1331us_d_drk) for: 3 (400 nm)
# Loaded images (400_14243us_1_calibration) for: 3 (400 nm)
# Loaded images (400_14243us_2_calibration) for: 3 (400 nm)
# Loaded images (400_14243us_d_drk) for: 3 (400 nm)
# Loaded images (400_149us_1_calibration) for: 3 (400 nm)
# Loaded images (400_149us_2_calibration) for: 3 (400 nm)
# Loaded images (400_149us_d_drk) for: 3 (400 nm)
# Loaded images (400_152392us_1_calibration) for: 3 (400 nm)
# Loaded images (400_152392us_2_calibration) for: 3 (400 nm)
# Loaded images (400_152392us_d_drk) for: 3 (400 nm)
# Loaded images (400_1597us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1597us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1597us_d_drk) for: 3 (400 nm)
# Loaded images (400_17092us_1_calibration) for: 3 (400 nm)
# Loaded images (400_17092us_2_calibration) for: 3 (400 nm)
# Loaded images (400_17092us_d_drk) for: 3 (400 nm)
# Loaded images (400_179us_1_calibration) for: 3 (400 nm)
# Loaded images (400_179us_2_calibration) for: 3 (400 nm)
# Loaded images (400_179us_d_drk) for: 3 (400 nm)
# Loaded images (400_182870us_1_calibration) for: 3 (400 nm)
# Loaded images (400_182870us_2_calibration) for: 3 (400 nm)
# Loaded images (400_182870us_d_drk) for: 3 (400 nm)
# Loaded images (400_1917us_1_calibration) for: 3 (400 nm)
# Loaded images (400_1917us_2_calibration) for: 3 (400 nm)
# Loaded images (400_1917us_d_drk) for: 3 (400 nm)
# Loaded images (400_20510us_1_calibration) for: 3 (400 nm)
# Loaded images (400_20510us_2_calibration) for: 3 (400 nm)
# Loaded images (400_20510us_d_drk) for: 3 (400 nm)
# Loaded images (400_215us_1_calibration) for: 3 (400 nm)
# Loaded images (400_215us_2_calibration) for: 3 (400 nm)
# Loaded images (400_215us_d_drk) for: 3 (400 nm)
# Loaded images (400_219444us_1_calibration) for: 3 (400 nm)
# Loaded images (400_219444us_2_calibration) for: 3 (400 nm)
# Loaded images (400_219444us_d_drk) for: 3 (400 nm)
# Loaded images (400_2300us_1_calibration) for: 3 (400 nm)
# Loaded images (400_2300us_2_calibration) for: 3 (400 nm)
# Loaded images (400_2300us_d_drk) for: 3 (400 nm)
# Loaded images (400_24612us_1_calibration) for: 3 (400 nm)
# Loaded images (400_24612us_2_calibration) for: 3 (400 nm)
# Loaded images (400_24612us_d_drk) for: 3 (400 nm)
# Loaded images (400_258us_1_calibration) for: 3 (400 nm)
# Loaded images (400_258us_2_calibration) for: 3 (400 nm)
# Loaded images (400_258us_d_drk) for: 3 (400 nm)
# Loaded images (400_263333us_1_calibration) for: 3 (400 nm)
# Loaded images (400_263333us_2_calibration) for: 3 (400 nm)
# Loaded images (400_263333us_d_drk) for: 3 (400 nm)
# Loaded images (400_2760us_1_calibration) for: 3 (400 nm)
# Loaded images (400_2760us_2_calibration) for: 3 (400 nm)
# Loaded images (400_2760us_d_drk) for: 3 (400 nm)
# Loaded images (400_29535us_1_calibration) for: 3 (400 nm)
# Loaded images (400_29535us_2_calibration) for: 3 (400 nm)
# Loaded images (400_29535us_d_drk) for: 3 (400 nm)
# Loaded images (400_310us_1_calibration) for: 3 (400 nm)
# Loaded images (400_310us_2_calibration) for: 3 (400 nm)
# Loaded images (400_310us_d_drk) for: 3 (400 nm)
# Loaded images (400_316000us_1_calibration) for: 3 (400 nm)
# Loaded images (400_316000us_2_calibration) for: 3 (400 nm)
# Loaded images (400_316000us_d_drk) for: 3 (400 nm)
# Loaded images (400_3313us_1_calibration) for: 3 (400 nm)
# Loaded images (400_3313us_2_calibration) for: 3 (400 nm)
# Loaded images (400_3313us_d_drk) for: 3 (400 nm)
# Loaded images (400_35442us_1_calibration) for: 3 (400 nm)
# Loaded images (400_35442us_2_calibration) for: 3 (400 nm)
# Loaded images (400_35442us_d_drk) for: 3 (400 nm)
# Loaded images (400_372us_1_calibration) for: 3 (400 nm)
# Loaded images (400_372us_2_calibration) for: 3 (400 nm)
# Loaded images (400_372us_d_drk) for: 3 (400 nm)
# Loaded images (400_379200us_1_calibration) for: 3 (400 nm)
# Loaded images (400_379200us_2_calibration) for: 3 (400 nm)
# Loaded images (400_379200us_d_drk) for: 3 (400 nm)
# Loaded images (400_3975us_1_calibration) for: 3 (400 nm)
# Loaded images (400_3975us_2_calibration) for: 3 (400 nm)
# Loaded images (400_3975us_d_drk) for: 3 (400 nm)
# Loaded images (400_42530us_1_calibration) for: 3 (400 nm)
# Loaded images (400_42530us_2_calibration) for: 3 (400 nm)
# Loaded images (400_42530us_d_drk) for: 3 (400 nm)
# Loaded images (400_446us_1_calibration) for: 3 (400 nm)
# Loaded images (400_446us_2_calibration) for: 3 (400 nm)
# Loaded images (400_446us_d_drk) for: 3 (400 nm)
# Loaded images (400_455040us_1_calibration) for: 3 (400 nm)
# Loaded images (400_455040us_2_calibration) for: 3 (400 nm)
# Loaded images (400_455040us_d_drk) for: 3 (400 nm)
# Loaded images (400_4770us_1_calibration) for: 3 (400 nm)
# Loaded images (400_4770us_2_calibration) for: 3 (400 nm)
# Loaded images (400_4770us_d_drk) for: 3 (400 nm)
# Loaded images (400_51036us_1_calibration) for: 3 (400 nm)
# Loaded images (400_51036us_2_calibration) for: 3 (400 nm)
# Loaded images (400_51036us_d_drk) for: 3 (400 nm)
# Loaded images (400_535us_1_calibration) for: 3 (400 nm)
# Loaded images (400_535us_2_calibration) for: 3 (400 nm)
# Loaded images (400_535us_d_drk) for: 3 (400 nm)
# Loaded images (400_546048us_1_calibration) for: 3 (400 nm)
# Loaded images (400_546048us_2_calibration) for: 3 (400 nm)
# Loaded images (400_546048us_d_drk) for: 3 (400 nm)
# Loaded images (400_5724us_1_calibration) for: 3 (400 nm)
# Loaded images (400_5724us_2_calibration) for: 3 (400 nm)
# Loaded images (400_5724us_d_drk) for: 3 (400 nm)
# Loaded images (400_60us_1_calibration) for: 3 (400 nm)
# Loaded images (400_60us_2_calibration) for: 3 (400 nm)
# Loaded images (400_60us_d_drk) for: 3 (400 nm)
# Loaded images (400_61243us_1_calibration) for: 3 (400 nm)
# Loaded images (400_61243us_2_calibration) for: 3 (400 nm)
# Loaded images (400_61243us_d_drk) for: 3 (400 nm)
# Loaded images (400_642us_1_calibration) for: 3 (400 nm)
# Loaded images (400_642us_2_calibration) for: 3 (400 nm)
# Loaded images (400_642us_d_drk) for: 3 (400 nm)
# Loaded images (400_655258us_1_calibration) for: 3 (400 nm)
# Loaded images (400_655258us_2_calibration) for: 3 (400 nm)
# Loaded images (400_655258us_d_drk) for: 3 (400 nm)
# Loaded images (400_6869us_1_calibration) for: 3 (400 nm)
# Loaded images (400_6869us_2_calibration) for: 3 (400 nm)
# Loaded images (400_6869us_d_drk) for: 3 (400 nm)
# Loaded images (400_697960us_1_calibration) for: 3 (400 nm)
# Loaded images (400_697960us_2_calibration) for: 3 (400 nm)
# Loaded images (400_697960us_d_drk) for: 3 (400 nm)
# Loaded images (400_705010us_1_calibration) for: 3 (400 nm)
# Loaded images (400_705010us_2_calibration) for: 3 (400 nm)
# Loaded images (400_705010us_d_drk) for: 3 (400 nm)
# Loaded images (400_712131us_1_calibration) for: 3 (400 nm)
# Loaded images (400_712131us_2_calibration) for: 3 (400 nm)
# Loaded images (400_712131us_d_drk) for: 3 (400 nm)
# Loaded images (400_719325us_1_calibration) for: 3 (400 nm)
# Loaded images (400_719325us_2_calibration) for: 3 (400 nm)
# Loaded images (400_719325us_d_drk) for: 3 (400 nm)
# Loaded images (400_726591us_1_calibration) for: 3 (400 nm)
# Loaded images (400_726591us_2_calibration) for: 3 (400 nm)
# Loaded images (400_726591us_d_drk) for: 3 (400 nm)
# Loaded images (400_72us_1_calibration) for: 3 (400 nm)
# Loaded images (400_72us_2_calibration) for: 3 (400 nm)
# Loaded images (400_72us_d_drk) for: 3 (400 nm)
# Loaded images (400_733930us_1_calibration) for: 3 (400 nm)
# Loaded images (400_733930us_2_calibration) for: 3 (400 nm)
# Loaded images (400_733930us_d_drk) for: 3 (400 nm)
# Loaded images (400_73492us_1_calibration) for: 3 (400 nm)
# Loaded images (400_73492us_2_calibration) for: 3 (400 nm)
# Loaded images (400_73492us_d_drk) for: 3 (400 nm)
# Loaded images (400_741343us_1_calibration) for: 3 (400 nm)
# Loaded images (400_741343us_2_calibration) for: 3 (400 nm)
# Loaded images (400_741343us_d_drk) for: 3 (400 nm)
# Loaded images (400_748832us_1_calibration) for: 3 (400 nm)
# Loaded images (400_748832us_2_calibration) for: 3 (400 nm)
# Loaded images (400_748832us_d_drk) for: 3 (400 nm)
# Loaded images (400_756396us_1_calibration) for: 3 (400 nm)
# Loaded images (400_756396us_2_calibration) for: 3 (400 nm)
# Loaded images (400_756396us_d_drk) for: 3 (400 nm)
# Loaded images (400_764036us_1_calibration) for: 3 (400 nm)
# Loaded images (400_764036us_2_calibration) for: 3 (400 nm)
# Loaded images (400_764036us_d_drk) for: 3 (400 nm)
# Loaded images (400_770us_1_calibration) for: 3 (400 nm)
# Loaded images (400_770us_2_calibration) for: 3 (400 nm)
# Loaded images (400_770us_d_drk) for: 3 (400 nm)
# Loaded images (400_771753us_1_calibration) for: 3 (400 nm)
# Loaded images (400_771753us_2_calibration) for: 3 (400 nm)
# Loaded images (400_771753us_d_drk) for: 3 (400 nm)
# Loaded images (400_779549us_1_calibration) for: 3 (400 nm)
# Loaded images (400_779549us_2_calibration) for: 3 (400 nm)
# Loaded images (400_779549us_d_drk) for: 3 (400 nm)
# Loaded images (400_786309us_1_calibration) for: 3 (400 nm)
# Loaded images (400_786309us_2_calibration) for: 3 (400 nm)
# Loaded images (400_786309us_d_drk) for: 3 (400 nm)
# Loaded images (400_787423us_1_calibration) for: 3 (400 nm)
# Loaded images (400_787423us_2_calibration) for: 3 (400 nm)
# Loaded images (400_787423us_d_drk) for: 3 (400 nm)
# Loaded images (400_795377us_1_calibration) for: 3 (400 nm)
# Loaded images (400_795377us_2_calibration) for: 3 (400 nm)
# Loaded images (400_795377us_d_drk) for: 3 (400 nm)
# Loaded images (400_803411us_1_calibration) for: 3 (400 nm)
# Loaded images (400_803411us_2_calibration) for: 3 (400 nm)
# Loaded images (400_803411us_d_drk) for: 3 (400 nm)
# Loaded images (400_811526us_1_calibration) for: 3 (400 nm)
# Loaded images (400_811526us_2_calibration) for: 3 (400 nm)
# Loaded images (400_811526us_d_drk) for: 3 (400 nm)
# Loaded images (400_819724us_1_calibration) for: 3 (400 nm)
# Loaded images (400_819724us_2_calibration) for: 3 (400 nm)
# Loaded images (400_819724us_d_drk) for: 3 (400 nm)
# Loaded images (400_8243us_1_calibration) for: 3 (400 nm)
# Loaded images (400_8243us_2_calibration) for: 3 (400 nm)
# Loaded images (400_8243us_d_drk) for: 3 (400 nm)
# Loaded images (400_828004us_1_calibration) for: 3 (400 nm)
# Loaded images (400_828004us_2_calibration) for: 3 (400 nm)
# Loaded images (400_828004us_d_drk) for: 3 (400 nm)
# Loaded images (400_836367us_1_calibration) for: 3 (400 nm)
# Loaded images (400_836367us_2_calibration) for: 3 (400 nm)
# Loaded images (400_836367us_d_drk) for: 3 (400 nm)
# Loaded images (400_844815us_1_calibration) for: 3 (400 nm)
# Loaded images (400_844815us_2_calibration) for: 3 (400 nm)
# Loaded images (400_844815us_d_drk) for: 3 (400 nm)
# Loaded images (400_853349us_1_calibration) for: 3 (400 nm)
# Loaded images (400_853349us_2_calibration) for: 3 (400 nm)
# Loaded images (400_853349us_d_drk) for: 3 (400 nm)
# Loaded images (400_861969us_1_calibration) for: 3 (400 nm)
# Loaded images (400_861969us_2_calibration) for: 3 (400 nm)
# Loaded images (400_861969us_d_drk) for: 3 (400 nm)
# Loaded images (400_86us_1_calibration) for: 3 (400 nm)
# Loaded images (400_86us_2_calibration) for: 3 (400 nm)
# Loaded images (400_86us_d_drk) for: 3 (400 nm)
# Loaded images (400_870675us_1_calibration) for: 3 (400 nm)
# Loaded images (400_870675us_2_calibration) for: 3 (400 nm)
# Loaded images (400_870675us_d_drk) for: 3 (400 nm)
# Loaded images (400_879470us_1_calibration) for: 3 (400 nm)
# Loaded images (400_879470us_2_calibration) for: 3 (400 nm)
# Loaded images (400_879470us_d_drk) for: 3 (400 nm)
# Loaded images (400_88190us_1_calibration) for: 3 (400 nm)
# Loaded images (400_88190us_2_calibration) for: 3 (400 nm)
# Loaded images (400_88190us_d_drk) for: 3 (400 nm)
# Loaded images (400_888354us_1_calibration) for: 3 (400 nm)
# Loaded images (400_888354us_2_calibration) for: 3 (400 nm)
# Loaded images (400_888354us_d_drk) for: 3 (400 nm)
# Loaded images (400_897327us_1_calibration) for: 3 (400 nm)
# Loaded images (400_897327us_2_calibration) for: 3 (400 nm)
# Loaded images (400_897327us_d_drk) for: 3 (400 nm)
# Loaded images (400_906391us_1_calibration) for: 3 (400 nm)
# Loaded images (400_906391us_2_calibration) for: 3 (400 nm)
# Loaded images (400_906391us_d_drk) for: 3 (400 nm)
# Loaded images (400_915546us_1_calibration) for: 3 (400 nm)
# Loaded images (400_915546us_2_calibration) for: 3 (400 nm)
# Loaded images (400_915546us_d_drk) for: 3 (400 nm)
# Loaded images (400_924794us_1_calibration) for: 3 (400 nm)
# Loaded images (400_924794us_2_calibration) for: 3 (400 nm)
# Loaded images (400_924794us_d_drk) for: 3 (400 nm)
# Loaded images (400_924us_1_calibration) for: 3 (400 nm)
# Loaded images (400_924us_2_calibration) for: 3 (400 nm)
# Loaded images (400_924us_d_drk) for: 3 (400 nm)
# Loaded images (400_934135us_1_calibration) for: 3 (400 nm)
# Loaded images (400_934135us_2_calibration) for: 3 (400 nm)
# Loaded images (400_934135us_d_drk) for: 3 (400 nm)
# Loaded images (400_943571us_1_calibration) for: 3 (400 nm)
# Loaded images (400_943571us_2_calibration) for: 3 (400 nm)
# Loaded images (400_943571us_d_drk) for: 3 (400 nm)
# Loaded images (400_9891us_1_calibration) for: 3 (400 nm)
# Loaded images (400_9891us_2_calibration) for: 3 (400 nm)
# Loaded images (400_9891us_d_drk) for: 3 (400 nm)
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT5/4_725
# Loaded images (725_100641us_1_calibration) for: 4 (725 nm)
# Loaded images (725_100641us_2_calibration) for: 4 (725 nm)
# Loaded images (725_100641us_d_drk) for: 4 (725 nm)
# Loaded images (725_101658us_1_calibration) for: 4 (725 nm)
# Loaded images (725_101658us_2_calibration) for: 4 (725 nm)
# Loaded images (725_101658us_d_drk) for: 4 (725 nm)
# Loaded images (725_102685us_1_calibration) for: 4 (725 nm)
# Loaded images (725_102685us_2_calibration) for: 4 (725 nm)
# Loaded images (725_102685us_d_drk) for: 4 (725 nm)
# Loaded images (725_103722us_1_calibration) for: 4 (725 nm)
# Loaded images (725_103722us_2_calibration) for: 4 (725 nm)
# Loaded images (725_103722us_d_drk) for: 4 (725 nm)
# Loaded images (725_104770us_1_calibration) for: 4 (725 nm)
# Loaded images (725_104770us_2_calibration) for: 4 (725 nm)
# Loaded images (725_104770us_d_drk) for: 4 (725 nm)
# Loaded images (725_104us_1_calibration) for: 4 (725 nm)
# Loaded images (725_104us_2_calibration) for: 4 (725 nm)
# Loaded images (725_104us_d_drk) for: 4 (725 nm)
# Loaded images (725_105828us_1_calibration) for: 4 (725 nm)
# Loaded images (725_105828us_2_calibration) for: 4 (725 nm)
# Loaded images (725_105828us_d_drk) for: 4 (725 nm)
# Loaded images (725_1109us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1109us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1109us_d_drk) for: 4 (725 nm)
# Loaded images (725_11869us_1_calibration) for: 4 (725 nm)
# Loaded images (725_11869us_2_calibration) for: 4 (725 nm)
# Loaded images (725_11869us_d_drk) for: 4 (725 nm)
# Loaded images (725_124us_1_calibration) for: 4 (725 nm)
# Loaded images (725_124us_2_calibration) for: 4 (725 nm)
# Loaded images (725_124us_d_drk) for: 4 (725 nm)
# Loaded images (725_1331us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1331us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1331us_d_drk) for: 4 (725 nm)
# Loaded images (725_14243us_1_calibration) for: 4 (725 nm)
# Loaded images (725_14243us_2_calibration) for: 4 (725 nm)
# Loaded images (725_14243us_d_drk) for: 4 (725 nm)
# Loaded images (725_149us_1_calibration) for: 4 (725 nm)
# Loaded images (725_149us_2_calibration) for: 4 (725 nm)
# Loaded images (725_149us_d_drk) for: 4 (725 nm)
# Loaded images (725_1597us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1597us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1597us_d_drk) for: 4 (725 nm)
# Loaded images (725_17092us_1_calibration) for: 4 (725 nm)
# Loaded images (725_17092us_2_calibration) for: 4 (725 nm)
# Loaded images (725_17092us_d_drk) for: 4 (725 nm)
# Loaded images (725_179us_1_calibration) for: 4 (725 nm)
# Loaded images (725_179us_2_calibration) for: 4 (725 nm)
# Loaded images (725_179us_d_drk) for: 4 (725 nm)
# Loaded images (725_1917us_1_calibration) for: 4 (725 nm)
# Loaded images (725_1917us_2_calibration) for: 4 (725 nm)
# Loaded images (725_1917us_d_drk) for: 4 (725 nm)
# Loaded images (725_20510us_1_calibration) for: 4 (725 nm)
# Loaded images (725_20510us_2_calibration) for: 4 (725 nm)
# Loaded images (725_20510us_d_drk) for: 4 (725 nm)
# Loaded images (725_215us_1_calibration) for: 4 (725 nm)
# Loaded images (725_215us_2_calibration) for: 4 (725 nm)
# Loaded images (725_215us_d_drk) for: 4 (725 nm)
# Loaded images (725_2300us_1_calibration) for: 4 (725 nm)
# Loaded images (725_2300us_2_calibration) for: 4 (725 nm)
# Loaded images (725_2300us_d_drk) for: 4 (725 nm)
# Loaded images (725_24612us_1_calibration) for: 4 (725 nm)
# Loaded images (725_24612us_2_calibration) for: 4 (725 nm)
# Loaded images (725_24612us_d_drk) for: 4 (725 nm)
# Loaded images (725_258us_1_calibration) for: 4 (725 nm)
# Loaded images (725_258us_2_calibration) for: 4 (725 nm)
# Loaded images (725_258us_d_drk) for: 4 (725 nm)
# Loaded images (725_2760us_1_calibration) for: 4 (725 nm)
# Loaded images (725_2760us_2_calibration) for: 4 (725 nm)
# Loaded images (725_2760us_d_drk) for: 4 (725 nm)
# Loaded images (725_29535us_1_calibration) for: 4 (725 nm)
# Loaded images (725_29535us_2_calibration) for: 4 (725 nm)
# Loaded images (725_29535us_d_drk) for: 4 (725 nm)
# Loaded images (725_310us_1_calibration) for: 4 (725 nm)
# Loaded images (725_310us_2_calibration) for: 4 (725 nm)
# Loaded images (725_310us_d_drk) for: 4 (725 nm)
# Loaded images (725_3313us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3313us_2_calibration) for: 4 (725 nm)
# Loaded images (725_3313us_d_drk) for: 4 (725 nm)
# Loaded images (725_35442us_1_calibration) for: 4 (725 nm)
# Loaded images (725_35442us_2_calibration) for: 4 (725 nm)
# Loaded images (725_35442us_d_drk) for: 4 (725 nm)
# Loaded images (725_372us_1_calibration) for: 4 (725 nm)
# Loaded images (725_372us_2_calibration) for: 4 (725 nm)
# Loaded images (725_372us_d_drk) for: 4 (725 nm)
# Loaded images (725_3975us_1_calibration) for: 4 (725 nm)
# Loaded images (725_3975us_2_calibration) for: 4 (725 nm)
# ...
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --------------------------------------------
# --------------------------------------------
# Processing SCT5/7_950
# Loaded images (950_1003641us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1003641us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1003641us_d_drk) for: 7 (950 nm)
# Loaded images (950_1013778us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1013778us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1013778us_d_drk) for: 7 (950 nm)
# Loaded images (950_1024019us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1024019us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1024019us_d_drk) for: 7 (950 nm)
# Loaded images (950_1034362us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1034362us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1034362us_d_drk) for: 7 (950 nm)
# Loaded images (950_1044810us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1044810us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1044810us_d_drk) for: 7 (950 nm)
# Loaded images (950_104us_1_calibration) for: 7 (950 nm)
# Loaded images (950_104us_2_calibration) for: 7 (950 nm)
# Loaded images (950_104us_d_drk) for: 7 (950 nm)
# Loaded images (950_1055364us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1055364us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1055364us_d_drk) for: 7 (950 nm)
# Loaded images (950_105828us_1_calibration) for: 7 (950 nm)
# Loaded images (950_105828us_2_calibration) for: 7 (950 nm)
# Loaded images (950_105828us_d_drk) for: 7 (950 nm)
# Loaded images (950_1066024us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1066024us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1066024us_d_drk) for: 7 (950 nm)
# Loaded images (950_1076792us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1076792us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1076792us_d_drk) for: 7 (950 nm)
# Loaded images (950_1087669us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1087669us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1087669us_d_drk) for: 7 (950 nm)
# Loaded images (950_1098655us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1098655us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1098655us_d_drk) for: 7 (950 nm)
# Loaded images (950_1109753us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1109753us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1109753us_d_drk) for: 7 (950 nm)
# Loaded images (950_1109us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1109us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1109us_d_drk) for: 7 (950 nm)
# Loaded images (950_1120963us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1120963us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1120963us_d_drk) for: 7 (950 nm)
# Loaded images (950_1132285us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1132285us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1132285us_d_drk) for: 7 (950 nm)
# Loaded images (950_11869us_1_calibration) for: 7 (950 nm)
# Loaded images (950_11869us_2_calibration) for: 7 (950 nm)
# Loaded images (950_11869us_d_drk) for: 7 (950 nm)
# Loaded images (950_124us_1_calibration) for: 7 (950 nm)
# Loaded images (950_124us_2_calibration) for: 7 (950 nm)
# Loaded images (950_124us_d_drk) for: 7 (950 nm)
# Loaded images (950_126993us_1_calibration) for: 7 (950 nm)
# Loaded images (950_126993us_2_calibration) for: 7 (950 nm)
# Loaded images (950_126993us_d_drk) for: 7 (950 nm)
# Loaded images (950_1331us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1331us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1331us_d_drk) for: 7 (950 nm)
# Loaded images (950_14243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_14243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_14243us_d_drk) for: 7 (950 nm)
# Loaded images (950_149us_1_calibration) for: 7 (950 nm)
# Loaded images (950_149us_2_calibration) for: 7 (950 nm)
# Loaded images (950_149us_d_drk) for: 7 (950 nm)
# Loaded images (950_152392us_1_calibration) for: 7 (950 nm)
# Loaded images (950_152392us_2_calibration) for: 7 (950 nm)
# Loaded images (950_152392us_d_drk) for: 7 (950 nm)
# Loaded images (950_1597us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1597us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1597us_d_drk) for: 7 (950 nm)
# Loaded images (950_17092us_1_calibration) for: 7 (950 nm)
# Loaded images (950_17092us_2_calibration) for: 7 (950 nm)
# Loaded images (950_17092us_d_drk) for: 7 (950 nm)
# Loaded images (950_179us_1_calibration) for: 7 (950 nm)
# Loaded images (950_179us_2_calibration) for: 7 (950 nm)
# Loaded images (950_179us_d_drk) for: 7 (950 nm)
# Loaded images (950_182870us_1_calibration) for: 7 (950 nm)
# Loaded images (950_182870us_2_calibration) for: 7 (950 nm)
# Loaded images (950_182870us_d_drk) for: 7 (950 nm)
# Loaded images (950_1917us_1_calibration) for: 7 (950 nm)
# Loaded images (950_1917us_2_calibration) for: 7 (950 nm)
# Loaded images (950_1917us_d_drk) for: 7 (950 nm)
# Loaded images (950_20510us_1_calibration) for: 7 (950 nm)
# Loaded images (950_20510us_2_calibration) for: 7 (950 nm)
# Loaded images (950_20510us_d_drk) for: 7 (950 nm)
# Loaded images (950_215us_1_calibration) for: 7 (950 nm)
# Loaded images (950_215us_2_calibration) for: 7 (950 nm)
# Loaded images (950_215us_d_drk) for: 7 (950 nm)
# Loaded images (950_219444us_1_calibration) for: 7 (950 nm)
# Loaded images (950_219444us_2_calibration) for: 7 (950 nm)
# Loaded images (950_219444us_d_drk) for: 7 (950 nm)
# Loaded images (950_2300us_1_calibration) for: 7 (950 nm)
# Loaded images (950_2300us_2_calibration) for: 7 (950 nm)
# Loaded images (950_2300us_d_drk) for: 7 (950 nm)
# Loaded images (950_24612us_1_calibration) for: 7 (950 nm)
# Loaded images (950_24612us_2_calibration) for: 7 (950 nm)
# Loaded images (950_24612us_d_drk) for: 7 (950 nm)
# Loaded images (950_258us_1_calibration) for: 7 (950 nm)
# Loaded images (950_258us_2_calibration) for: 7 (950 nm)
# Loaded images (950_258us_d_drk) for: 7 (950 nm)
# Loaded images (950_263333us_1_calibration) for: 7 (950 nm)
# Loaded images (950_263333us_2_calibration) for: 7 (950 nm)
# Loaded images (950_263333us_d_drk) for: 7 (950 nm)
# Loaded images (950_2760us_1_calibration) for: 7 (950 nm)
# Loaded images (950_2760us_2_calibration) for: 7 (950 nm)
# Loaded images (950_2760us_d_drk) for: 7 (950 nm)
# Loaded images (950_29535us_1_calibration) for: 7 (950 nm)
# Loaded images (950_29535us_2_calibration) for: 7 (950 nm)
# Loaded images (950_29535us_d_drk) for: 7 (950 nm)
# Loaded images (950_310us_1_calibration) for: 7 (950 nm)
# Loaded images (950_310us_2_calibration) for: 7 (950 nm)
# Loaded images (950_310us_d_drk) for: 7 (950 nm)
# Loaded images (950_316000us_1_calibration) for: 7 (950 nm)
# Loaded images (950_316000us_2_calibration) for: 7 (950 nm)
# Loaded images (950_316000us_d_drk) for: 7 (950 nm)
# Loaded images (950_3313us_1_calibration) for: 7 (950 nm)
# Loaded images (950_3313us_2_calibration) for: 7 (950 nm)
# Loaded images (950_3313us_d_drk) for: 7 (950 nm)
# Loaded images (950_35442us_1_calibration) for: 7 (950 nm)
# Loaded images (950_35442us_2_calibration) for: 7 (950 nm)
# Loaded images (950_35442us_d_drk) for: 7 (950 nm)
# Loaded images (950_372us_1_calibration) for: 7 (950 nm)
# Loaded images (950_372us_2_calibration) for: 7 (950 nm)
# Loaded images (950_372us_d_drk) for: 7 (950 nm)
# Loaded images (950_379200us_1_calibration) for: 7 (950 nm)
# Loaded images (950_379200us_2_calibration) for: 7 (950 nm)
# Loaded images (950_379200us_d_drk) for: 7 (950 nm)
# Loaded images (950_3975us_1_calibration) for: 7 (950 nm)
# Loaded images (950_3975us_2_calibration) for: 7 (950 nm)
# Loaded images (950_3975us_d_drk) for: 7 (950 nm)
# Loaded images (950_42530us_1_calibration) for: 7 (950 nm)
# Loaded images (950_42530us_2_calibration) for: 7 (950 nm)
# Loaded images (950_42530us_d_drk) for: 7 (950 nm)
# Loaded images (950_446us_1_calibration) for: 7 (950 nm)
# Loaded images (950_446us_2_calibration) for: 7 (950 nm)
# Loaded images (950_446us_d_drk) for: 7 (950 nm)
# Loaded images (950_455040us_1_calibration) for: 7 (950 nm)
# Loaded images (950_455040us_2_calibration) for: 7 (950 nm)
# Loaded images (950_455040us_d_drk) for: 7 (950 nm)
# Loaded images (950_4770us_1_calibration) for: 7 (950 nm)
# Loaded images (950_4770us_2_calibration) for: 7 (950 nm)
# Loaded images (950_4770us_d_drk) for: 7 (950 nm)
# Loaded images (950_51036us_1_calibration) for: 7 (950 nm)
# Loaded images (950_51036us_2_calibration) for: 7 (950 nm)
# Loaded images (950_51036us_d_drk) for: 7 (950 nm)
# Loaded images (950_535us_1_calibration) for: 7 (950 nm)
# Loaded images (950_535us_2_calibration) for: 7 (950 nm)
# Loaded images (950_535us_d_drk) for: 7 (950 nm)
# Loaded images (950_546048us_1_calibration) for: 7 (950 nm)
# Loaded images (950_546048us_2_calibration) for: 7 (950 nm)
# Loaded images (950_546048us_d_drk) for: 7 (950 nm)
# Loaded images (950_5724us_1_calibration) for: 7 (950 nm)
# Loaded images (950_5724us_2_calibration) for: 7 (950 nm)
# Loaded images (950_5724us_d_drk) for: 7 (950 nm)
# Loaded images (950_60us_1_calibration) for: 7 (950 nm)
# Loaded images (950_60us_2_calibration) for: 7 (950 nm)
# Loaded images (950_60us_d_drk) for: 7 (950 nm)
# Loaded images (950_61243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_61243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_61243us_d_drk) for: 7 (950 nm)
# Loaded images (950_642us_1_calibration) for: 7 (950 nm)
# Loaded images (950_642us_2_calibration) for: 7 (950 nm)
# Loaded images (950_642us_d_drk) for: 7 (950 nm)
# Loaded images (950_655258us_1_calibration) for: 7 (950 nm)
# Loaded images (950_655258us_2_calibration) for: 7 (950 nm)
# Loaded images (950_655258us_d_drk) for: 7 (950 nm)
# Loaded images (950_6869us_1_calibration) for: 7 (950 nm)
# Loaded images (950_6869us_2_calibration) for: 7 (950 nm)
# Loaded images (950_6869us_d_drk) for: 7 (950 nm)
# Loaded images (950_72us_1_calibration) for: 7 (950 nm)
# Loaded images (950_72us_2_calibration) for: 7 (950 nm)
# Loaded images (950_72us_d_drk) for: 7 (950 nm)
# Loaded images (950_73492us_1_calibration) for: 7 (950 nm)
# Loaded images (950_73492us_2_calibration) for: 7 (950 nm)
# Loaded images (950_73492us_d_drk) for: 7 (950 nm)
# Loaded images (950_770us_1_calibration) for: 7 (950 nm)
# Loaded images (950_770us_2_calibration) for: 7 (950 nm)
# Loaded images (950_770us_d_drk) for: 7 (950 nm)
# Loaded images (950_786309us_1_calibration) for: 7 (950 nm)
# Loaded images (950_786309us_2_calibration) for: 7 (950 nm)
# Loaded images (950_786309us_d_drk) for: 7 (950 nm)
# Loaded images (950_804549us_1_calibration) for: 7 (950 nm)
# Loaded images (950_804549us_2_calibration) for: 7 (950 nm)
# Loaded images (950_804549us_d_drk) for: 7 (950 nm)
# Loaded images (950_812676us_1_calibration) for: 7 (950 nm)
# Loaded images (950_812676us_2_calibration) for: 7 (950 nm)
# Loaded images (950_812676us_d_drk) for: 7 (950 nm)
# Loaded images (950_820885us_1_calibration) for: 7 (950 nm)
# Loaded images (950_820885us_2_calibration) for: 7 (950 nm)
# Loaded images (950_820885us_d_drk) for: 7 (950 nm)
# Loaded images (950_8243us_1_calibration) for: 7 (950 nm)
# Loaded images (950_8243us_2_calibration) for: 7 (950 nm)
# Loaded images (950_8243us_d_drk) for: 7 (950 nm)
# Loaded images (950_829176us_1_calibration) for: 7 (950 nm)
# Loaded images (950_829176us_2_calibration) for: 7 (950 nm)
# Loaded images (950_829176us_d_drk) for: 7 (950 nm)
# Loaded images (950_837552us_1_calibration) for: 7 (950 nm)
# Loaded images (950_837552us_2_calibration) for: 7 (950 nm)
# Loaded images (950_837552us_d_drk) for: 7 (950 nm)
# Loaded images (950_846012us_1_calibration) for: 7 (950 nm)
# Loaded images (950_846012us_2_calibration) for: 7 (950 nm)
# Loaded images (950_846012us_d_drk) for: 7 (950 nm)
# Loaded images (950_854558us_1_calibration) for: 7 (950 nm)
# Loaded images (950_854558us_2_calibration) for: 7 (950 nm)
# Loaded images (950_854558us_d_drk) for: 7 (950 nm)
# Loaded images (950_863190us_1_calibration) for: 7 (950 nm)
# Loaded images (950_863190us_2_calibration) for: 7 (950 nm)
# Loaded images (950_863190us_d_drk) for: 7 (950 nm)
# Loaded images (950_86us_1_calibration) for: 7 (950 nm)
# Loaded images (950_86us_2_calibration) for: 7 (950 nm)
# Loaded images (950_86us_d_drk) for: 7 (950 nm)
# Loaded images (950_871909us_1_calibration) for: 7 (950 nm)
# Loaded images (950_871909us_2_calibration) for: 7 (950 nm)
# Loaded images (950_871909us_d_drk) for: 7 (950 nm)
# Loaded images (950_880716us_1_calibration) for: 7 (950 nm)
# Loaded images (950_880716us_2_calibration) for: 7 (950 nm)
# Loaded images (950_880716us_d_drk) for: 7 (950 nm)
# Loaded images (950_88190us_1_calibration) for: 7 (950 nm)
# Loaded images (950_88190us_2_calibration) for: 7 (950 nm)
# Loaded images (950_88190us_d_drk) for: 7 (950 nm)
# Loaded images (950_889612us_1_calibration) for: 7 (950 nm)
# Loaded images (950_889612us_2_calibration) for: 7 (950 nm)
# Loaded images (950_889612us_d_drk) for: 7 (950 nm)
# Loaded images (950_898598us_1_calibration) for: 7 (950 nm)
# Loaded images (950_898598us_2_calibration) for: 7 (950 nm)
# Loaded images (950_898598us_d_drk) for: 7 (950 nm)
# Loaded images (950_907675us_1_calibration) for: 7 (950 nm)
# Loaded images (950_907675us_2_calibration) for: 7 (950 nm)
# Loaded images (950_907675us_d_drk) for: 7 (950 nm)
# Loaded images (950_916843us_1_calibration) for: 7 (950 nm)
# Loaded images (950_916843us_2_calibration) for: 7 (950 nm)
# Loaded images (950_916843us_d_drk) for: 7 (950 nm)
# Loaded images (950_924us_1_calibration) for: 7 (950 nm)
# Loaded images (950_924us_2_calibration) for: 7 (950 nm)
# Loaded images (950_924us_d_drk) for: 7 (950 nm)
# Loaded images (950_926104us_1_calibration) for: 7 (950 nm)
# Loaded images (950_926104us_2_calibration) for: 7 (950 nm)
# Loaded images (950_926104us_d_drk) for: 7 (950 nm)
# Loaded images (950_935459us_1_calibration) for: 7 (950 nm)
# Loaded images (950_935459us_2_calibration) for: 7 (950 nm)
# Loaded images (950_935459us_d_drk) for: 7 (950 nm)
# Loaded images (950_943571us_1_calibration) for: 7 (950 nm)
# Loaded images (950_943571us_2_calibration) for: 7 (950 nm)
# Loaded images (950_943571us_d_drk) for: 7 (950 nm)
# Loaded images (950_944908us_1_calibration) for: 7 (950 nm)
# Loaded images (950_944908us_2_calibration) for: 7 (950 nm)
# Loaded images (950_944908us_d_drk) for: 7 (950 nm)
# Loaded images (950_954452us_1_calibration) for: 7 (950 nm)
# Loaded images (950_954452us_2_calibration) for: 7 (950 nm)
# Loaded images (950_954452us_d_drk) for: 7 (950 nm)
# Loaded images (950_964093us_1_calibration) for: 7 (950 nm)
# Loaded images (950_964093us_2_calibration) for: 7 (950 nm)
# Loaded images (950_964093us_d_drk) for: 7 (950 nm)
# Loaded images (950_973832us_1_calibration) for: 7 (950 nm)
# Loaded images (950_973832us_2_calibration) for: 7 (950 nm)
# Loaded images (950_973832us_d_drk) for: 7 (950 nm)
# Loaded images (950_983668us_1_calibration) for: 7 (950 nm)
# Loaded images (950_983668us_2_calibration) for: 7 (950 nm)
# Loaded images (950_983668us_d_drk) for: 7 (950 nm)
# Loaded images (950_9891us_1_calibration) for: 7 (950 nm)
# Loaded images (950_9891us_2_calibration) for: 7 (950 nm)
# Loaded images (950_9891us_d_drk) for: 7 (950 nm)
# Loaded images (950_993604us_1_calibration) for: 7 (950 nm)
# Loaded images (950_993604us_2_calibration) for: 7 (950 nm)
# Loaded images (950_993604us_d_drk) for: 7 (950 nm)
# --------------------------------------------
# /opt/homebrew/Caskroom/miniconda/base/envs/orochi_sim_ctrl/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#               channel     k_adc     full_well  read_noise         DR
# 0  ../data/SCT5/0_650  4.616749  16731.754675    0.000000        inf
# 1  ../data/SCT5/1_475  4.687111  11409.031539    5.076172  67.034249
# 2  ../data/SCT5/3_400  4.574665   5538.913793    5.367907  60.272392
# 3  ../data/SCT5/4_725  4.783409  15920.766174    4.788152  70.435921
# 4  ../data/SCT5/5_850  4.641432   5443.830648    5.127207  60.520475
# 5  ../data/SCT5/6_550  4.754149  17374.985944    5.886441  69.401434
# 6  ../data/SCT5/7_950  4.672180   1496.233259    5.184712  49.205493

# %% [markdown]
# Now we have this information, we need to properly compare it to the expectations of the OROCHI instrument, and scale accordingly.

# %% [markdown]
# First, we see that linearity is good over the 10 - 90 % response range - so we should keep the bias set as it is, and ensure that images are captured within this range.
#
# Then, we need to make sure maximum SNR matches that of OROCHI, that we can achieve by limiting the electron count to the OROCHI Full Well, at 20000 e-.
# This is approximately 2/3s of the detector response, ~2800 DN (12-bit mode).
#
# But we also see from our SNR plots that the minimum SNR that we require occurs at ~2000 DN.
#
# So this means we are aiming for an exposed region of ~2000 - 2800 DN, within the 12-bit window. This may be hard to achieve, if the dynamic range of the environment is much greater than this.
# The best algorithm I think for achieving this is still the percentile algorithm, bbut greater guidance may be required to inform the number of pixels allowed to over expose. Or, we may need to do repeat imaging for the different targets, at different exposures.
#
# SO what we need to do is allow for Auto-Exposure manual ROI selection.
# - perform autoexposure on whole image / sample ROI
# - select reference points
# - re-run autoexposure on reference points
# - set exposure for experiment
# - repeat for a new reference point, and save etc.

# %% [markdown]
# # Notes

# %% [markdown]
# Likely that my Full Well record is an underestimate, due to exaggerated bias.
#
# Note that Bauer set the bias to 39, whereas I have it set to 128. Remiedying this for future studies - recommend setting to 39 - but why?
