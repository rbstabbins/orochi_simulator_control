# %% [markdown]
# A notebook for processing flat field data for each channel of OROS (the OROCHI Simulator).

# %% [markdown]
# # Process Overview
#
# - load flat-field images
# - average frames from different spectralon positions
# - look for convergence toward mean pixel values
#     - by plotting the mean change-in-mean across all pixels
#     - i.e. change in mean is this abs(mean - last mean) - pixel wise
#     - mean of this over all pixels shows how this changes for the repeat images.
# - save final flat field

# %% [markdown]
# # Set up

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import orochi_sim_proc as osp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Processing

# %% [markdown]
# First we load all of the frames, and show the average final frame, and noise, for each channel.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
        img_1.image_load()
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()
        img_1.dark_subtract(drk)
        img_1.image_display()
        img_1.image_display(noise=True, vmax=150)
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 36 images (ave) for: 0 (850 nm)
# Loaded 1 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# ../data/flat_field_dark_11072023/1_475
# Loaded 36 images (ave) for: 1 (475 nm)
# Loaded 1 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# ../data/flat_field_dark_11072023/2_400
# Loaded 36 images (ave) for: 2 (400 nm)
# Loaded 1 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# ../data/flat_field_dark_11072023/3_550
# Loaded 36 images (ave) for: 3 (550 nm)
# Loaded 1 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# ../data/flat_field_dark_11072023/4_725
# Loaded 36 images (ave) for: 4 (725 nm)
# Loaded 1 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# ../data/flat_field_dark_11072023/5_950
# Loaded 36 images (ave) for: 5 (950 nm)
# Loaded 1 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# ../data/flat_field_dark_11072023/6_650
# Loaded 36 images (ave) for: 6 (650 nm)
# Loaded 1 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# ../data/flat_field_dark_11072023/7_550
# Loaded 36 images (ave) for: 7 (550 nm)
# Loaded 1 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)

# %% [markdown]
# Here we've clipped the noise to 40 DN, i.e. ~1% of the range, to illustrate any patterns that indicated resolvable features of the spectralon surface.
# We notice that in the 400 nm and 475 nm channels, there is a ring of rectangle artefacts, implying that there is some contamination of the surface that is highly reflective in these short wavelengths.
# These serve to illustrate the degree to which the spectralon target was displaced during the repeat sampling.

# %% [markdown]
# We now investigate the success of the repeat sampling, but plotting the mean of the absolute change in average pixel level as the trials progressed.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
mean_change = {}
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()
        ave_stk = []
        for i in np.arange(1,36):
            print(i)
            img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
            img_1.image_load(n_imgs = i)
            img_1.dark_subtract(drk)
            ave_stk.append(img_1.img_ave)
        # process average stack into mean of change of average
        ave_stk = np.dstack(ave_stk)
        mean_change[channel] = [np.mean(np.abs(ave_stk[40:60,40:60,i-1] - ave_stk[40:60,40:60,i])) for i in np.arange(1,35)]
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 1 images (ave) for: 0 (850 nm)
# 1
# Loaded 1 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 2
# Loaded 2 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 3
# Loaded 3 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 4
# Loaded 4 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 5
# Loaded 5 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 6
# Loaded 6 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 7
# Loaded 7 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 8
# Loaded 8 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 9
# Loaded 9 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 10
# Loaded 10 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 11
# Loaded 11 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 12
# Loaded 12 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 13
# Loaded 13 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 14
# Loaded 14 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 15
# Loaded 15 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 16
# Loaded 16 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 17
# Loaded 17 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 18
# Loaded 18 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 19
# Loaded 19 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 20
# Loaded 20 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 21
# Loaded 21 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 22
# Loaded 22 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 23
# Loaded 23 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 24
# Loaded 24 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 25
# Loaded 25 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 26
# Loaded 26 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 27
# Loaded 27 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 28
# Loaded 28 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 29
# Loaded 29 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 30
# Loaded 30 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 31
# Loaded 31 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 32
# Loaded 32 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 33
# Loaded 33 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 34
# Loaded 34 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# 35
# Loaded 35 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# ../data/flat_field_dark_11072023/1_475
# Loaded 1 images (ave) for: 1 (475 nm)
# 1
# Loaded 1 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 2
# Loaded 2 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 3
# Loaded 3 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 4
# Loaded 4 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 5
# Loaded 5 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 6
# Loaded 6 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 7
# Loaded 7 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 8
# Loaded 8 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 9
# Loaded 9 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 10
# Loaded 10 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 11
# Loaded 11 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 12
# Loaded 12 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 13
# Loaded 13 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 14
# Loaded 14 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 15
# Loaded 15 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 16
# Loaded 16 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 17
# Loaded 17 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 18
# Loaded 18 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 19
# Loaded 19 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 20
# Loaded 20 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 21
# Loaded 21 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 22
# Loaded 22 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 23
# Loaded 23 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 24
# Loaded 24 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 25
# Loaded 25 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 26
# Loaded 26 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 27
# Loaded 27 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 28
# Loaded 28 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 29
# Loaded 29 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 30
# Loaded 30 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 31
# Loaded 31 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 32
# Loaded 32 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 33
# Loaded 33 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 34
# Loaded 34 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# 35
# Loaded 35 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# ../data/flat_field_dark_11072023/2_400
# Loaded 1 images (ave) for: 2 (400 nm)
# 1
# Loaded 1 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 2
# Loaded 2 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 3
# Loaded 3 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 4
# Loaded 4 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 5
# Loaded 5 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 6
# Loaded 6 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 7
# Loaded 7 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 8
# Loaded 8 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 9
# Loaded 9 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 10
# Loaded 10 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 11
# Loaded 11 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 12
# Loaded 12 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 13
# Loaded 13 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 14
# Loaded 14 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 15
# Loaded 15 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 16
# Loaded 16 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 17
# Loaded 17 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 18
# Loaded 18 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 19
# Loaded 19 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 20
# Loaded 20 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 21
# Loaded 21 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 22
# Loaded 22 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 23
# Loaded 23 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 24
# Loaded 24 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 25
# Loaded 25 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 26
# Loaded 26 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 27
# Loaded 27 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 28
# Loaded 28 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 29
# Loaded 29 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 30
# Loaded 30 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 31
# Loaded 31 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 32
# Loaded 32 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 33
# Loaded 33 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 34
# Loaded 34 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# 35
# Loaded 35 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# ../data/flat_field_dark_11072023/3_550
# Loaded 1 images (ave) for: 3 (550 nm)
# 1
# Loaded 1 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 2
# Loaded 2 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 3
# Loaded 3 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 4
# Loaded 4 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 5
# Loaded 5 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 6
# Loaded 6 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 7
# Loaded 7 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 8
# Loaded 8 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 9
# Loaded 9 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 10
# Loaded 10 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 11
# Loaded 11 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 12
# Loaded 12 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 13
# Loaded 13 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 14
# Loaded 14 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 15
# Loaded 15 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 16
# Loaded 16 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 17
# Loaded 17 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 18
# Loaded 18 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 19
# Loaded 19 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 20
# Loaded 20 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 21
# Loaded 21 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 22
# Loaded 22 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 23
# Loaded 23 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 24
# Loaded 24 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 25
# Loaded 25 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 26
# Loaded 26 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 27
# Loaded 27 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 28
# Loaded 28 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 29
# Loaded 29 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 30
# Loaded 30 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 31
# Loaded 31 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 32
# Loaded 32 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 33
# Loaded 33 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 34
# Loaded 34 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# 35
# Loaded 35 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# ../data/flat_field_dark_11072023/4_725
# Loaded 1 images (ave) for: 4 (725 nm)
# 1
# Loaded 1 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 2
# Loaded 2 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 3
# Loaded 3 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 4
# Loaded 4 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 5
# Loaded 5 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 6
# Loaded 6 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 7
# Loaded 7 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 8
# Loaded 8 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 9
# Loaded 9 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 10
# Loaded 10 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 11
# Loaded 11 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 12
# Loaded 12 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 13
# Loaded 13 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 14
# Loaded 14 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 15
# Loaded 15 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 16
# Loaded 16 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 17
# Loaded 17 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 18
# Loaded 18 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 19
# Loaded 19 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 20
# Loaded 20 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 21
# Loaded 21 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 22
# Loaded 22 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 23
# Loaded 23 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 24
# Loaded 24 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 25
# Loaded 25 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 26
# Loaded 26 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 27
# Loaded 27 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 28
# Loaded 28 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 29
# Loaded 29 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 30
# Loaded 30 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 31
# Loaded 31 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 32
# Loaded 32 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 33
# Loaded 33 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 34
# Loaded 34 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# 35
# Loaded 35 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# ../data/flat_field_dark_11072023/5_950
# Loaded 1 images (ave) for: 5 (950 nm)
# 1
# Loaded 1 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 2
# Loaded 2 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 3
# Loaded 3 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 4
# Loaded 4 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 5
# Loaded 5 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 6
# Loaded 6 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 7
# Loaded 7 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 8
# Loaded 8 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 9
# Loaded 9 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 10
# Loaded 10 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 11
# Loaded 11 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 12
# Loaded 12 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 13
# Loaded 13 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 14
# Loaded 14 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 15
# Loaded 15 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 16
# Loaded 16 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 17
# Loaded 17 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 18
# Loaded 18 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 19
# Loaded 19 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 20
# Loaded 20 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 21
# Loaded 21 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 22
# Loaded 22 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 23
# Loaded 23 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 24
# Loaded 24 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 25
# Loaded 25 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 26
# Loaded 26 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 27
# Loaded 27 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 28
# Loaded 28 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 29
# Loaded 29 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 30
# Loaded 30 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 31
# Loaded 31 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 32
# Loaded 32 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 33
# Loaded 33 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 34
# Loaded 34 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# 35
# Loaded 35 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# ../data/flat_field_dark_11072023/6_650
# Loaded 1 images (ave) for: 6 (650 nm)
# 1
# Loaded 1 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 2
# Loaded 2 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 3
# Loaded 3 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 4
# Loaded 4 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 5
# Loaded 5 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 6
# Loaded 6 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 7
# Loaded 7 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 8
# Loaded 8 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 9
# Loaded 9 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 10
# Loaded 10 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 11
# Loaded 11 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 12
# Loaded 12 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 13
# Loaded 13 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 14
# Loaded 14 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 15
# Loaded 15 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 16
# Loaded 16 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 17
# Loaded 17 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 18
# Loaded 18 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 19
# Loaded 19 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 20
# Loaded 20 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 21
# Loaded 21 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 22
# Loaded 22 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 23
# Loaded 23 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 24
# Loaded 24 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 25
# Loaded 25 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 26
# Loaded 26 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 27
# Loaded 27 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 28
# Loaded 28 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 29
# Loaded 29 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 30
# Loaded 30 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 31
# Loaded 31 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 32
# Loaded 32 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 33
# Loaded 33 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 34
# Loaded 34 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# 35
# Loaded 35 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# ../data/flat_field_dark_11072023/7_550
# Loaded 1 images (ave) for: 7 (550 nm)
# 1
# Loaded 1 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 2
# Loaded 2 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 3
# Loaded 3 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 4
# Loaded 4 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 5
# Loaded 5 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 6
# Loaded 6 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 7
# Loaded 7 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 8
# Loaded 8 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 9
# Loaded 9 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 10
# Loaded 10 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 11
# Loaded 11 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 12
# Loaded 12 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 13
# Loaded 13 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 14
# Loaded 14 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 15
# Loaded 15 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 16
# Loaded 16 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 17
# Loaded 17 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 18
# Loaded 18 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 19
# Loaded 19 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 20
# Loaded 20 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 21
# Loaded 21 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 22
# Loaded 22 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 23
# Loaded 23 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 24
# Loaded 24 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 25
# Loaded 25 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 26
# Loaded 26 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 27
# Loaded 27 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 28
# Loaded 28 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 29
# Loaded 29 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 30
# Loaded 30 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 31
# Loaded 31 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 32
# Loaded 32 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 33
# Loaded 33 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 34
# Loaded 34 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# 35
# Loaded 35 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)

# %%
import matplotlib.pyplot as plt
for channel in illums:
    change = np.array(mean_change[channel])
    plt.plot(np.arange(1,35), change, label=channel.stem)

# %% [markdown]
# We can see that the change is converging towards 0, although this has not been reached for all channels.
# This implies that a larger number of repeat trials are needed.
# We could alternatively investigate using the median, instread of the mean, pixel value, to better exclude outliers in the structure of the spectralon.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
mean_change = {}
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()
        ave_stk = []
        for i in np.arange(1,36):
            img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
            img_1.image_load(n_imgs = i, mode='median')
            img_1.dark_subtract(drk)
            ave_stk.append(img_1.img_ave)
        # process average stack into mean of change of average
        ave_stk = np.dstack(ave_stk)
        mean_change[channel] = [np.mean(np.abs(ave_stk[40:60,40:60,i-1] - ave_stk[40:60,40:60,i])) for i in np.arange(1,35)]
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 1 images (ave) for: 0 (850 nm)
# Loaded 1 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 2 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 3 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 4 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 5 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 6 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 7 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 8 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 9 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 10 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 11 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 12 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 13 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 14 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 15 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 16 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 17 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 18 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 19 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 20 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 21 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 22 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 23 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 24 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 25 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 26 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 27 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 28 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 29 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 30 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 31 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 32 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 33 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 34 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# Loaded 35 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# ../data/flat_field_dark_11072023/1_475
# Loaded 1 images (ave) for: 1 (475 nm)
# Loaded 1 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 2 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 3 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 4 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 5 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 6 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 7 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 8 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 9 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 10 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 11 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 12 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 13 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 14 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 15 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 16 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 17 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 18 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 19 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 20 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 21 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 22 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 23 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 24 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 25 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 26 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 27 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 28 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 29 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 30 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 31 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 32 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 33 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 34 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# Loaded 35 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# ../data/flat_field_dark_11072023/2_400
# Loaded 1 images (ave) for: 2 (400 nm)
# Loaded 1 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 2 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 3 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 4 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 5 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 6 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 7 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 8 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 9 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 10 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 11 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 12 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 13 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 14 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 15 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 16 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 17 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 18 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 19 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 20 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 21 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 22 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 23 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 24 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 25 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 26 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 27 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 28 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 29 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 30 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 31 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 32 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 33 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 34 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# Loaded 35 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# ../data/flat_field_dark_11072023/3_550
# Loaded 1 images (ave) for: 3 (550 nm)
# Loaded 1 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 2 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 3 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 4 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 5 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 6 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 7 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 8 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 9 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 10 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 11 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 12 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 13 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 14 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 15 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 16 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 17 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 18 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 19 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 20 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 21 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 22 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 23 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 24 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 25 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 26 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 27 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 28 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 29 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 30 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 31 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 32 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 33 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 34 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# Loaded 35 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# ../data/flat_field_dark_11072023/4_725
# Loaded 1 images (ave) for: 4 (725 nm)
# Loaded 1 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 2 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 3 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 4 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 5 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 6 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 7 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 8 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 9 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 10 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 11 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 12 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 13 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 14 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 15 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 16 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 17 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 18 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 19 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 20 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 21 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 22 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 23 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 24 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 25 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 26 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 27 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 28 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 29 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 30 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 31 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 32 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 33 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 34 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# Loaded 35 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# ../data/flat_field_dark_11072023/5_950
# Loaded 1 images (ave) for: 5 (950 nm)
# Loaded 1 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 2 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 3 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 4 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 5 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 6 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 7 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 8 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 9 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 10 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 11 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 12 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 13 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 14 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 15 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 16 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 17 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 18 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 19 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 20 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 21 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 22 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 23 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 24 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 25 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 26 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 27 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 28 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 29 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 30 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 31 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 32 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 33 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 34 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# Loaded 35 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# ../data/flat_field_dark_11072023/6_650
# Loaded 1 images (ave) for: 6 (650 nm)
# Loaded 1 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 2 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 3 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 4 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 5 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 6 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 7 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 8 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 9 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 10 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 11 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 12 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 13 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 14 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 15 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 16 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 17 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 18 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 19 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 20 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 21 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 22 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 23 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 24 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 25 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 26 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 27 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 28 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 29 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 30 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 31 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 32 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 33 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 34 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# Loaded 35 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# ../data/flat_field_dark_11072023/7_550
# Loaded 1 images (ave) for: 7 (550 nm)
# Loaded 1 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 2 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 3 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 4 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 5 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 6 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 7 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 8 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 9 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 10 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 11 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 12 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 13 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 14 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 15 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 16 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 17 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 18 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 19 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 20 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 21 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 22 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 23 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 24 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 25 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 26 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 27 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 28 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 29 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 30 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 31 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 32 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 33 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 34 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# Loaded 35 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)

# %%
for channel in illums:
    change = np.array(mean_change[channel])
    print(change)
    plt.plot(np.arange(1,35), change, label=channel.stem)
# Out:
# [18.55616     8.781247    8.196947    6.375052    4.0686955   3.5418036
#   3.183951    2.7142467   2.0526013   1.9431995   1.7461548   1.5771447
#   1.468396    1.4584979   1.2950494   1.237052    1.2799518   1.1424512
#   1.1640009   1.1519983   0.969646    0.91595155  0.8963031   0.8911932
#   0.9939502   0.9224512   0.8407013   0.80109376  0.8662445   0.83254886
#   0.8239477   0.82305056  0.7467041   0.7466998 ]
# [9.607204   8.644301   6.4224534  6.0476503  3.9569516  3.4807415
#  3.2803037  2.9937017  2.5727885  2.316092   2.1124969  1.9027991
#  1.7017032  1.6826013  1.572499   1.5298984  1.4171978  1.2986994
#  1.3158029  1.1859992  1.0681     1.0320969  1.0422482  0.9858472
#  0.95269287 0.95100766 0.9459528  0.93205476 0.9231039  0.8814038
#  0.8887015  0.8667868  0.7790939  0.7627005 ]
# [8.698202   7.358196   4.785147   4.4686427  3.6395974  3.4192975
#  3.297599   2.8486004  2.5874488  2.502753   2.1023455  1.9906458
#  1.9853995  1.839404   1.5695032  1.4517026  1.4142511  1.4085492
#  1.2910473  1.2520468  1.2257501  1.1997497  1.1064956  1.057002
#  0.9496051  0.89549834 0.88484555 0.85234714 0.8377426  0.8055423
#  0.76095396 0.7487564  0.73105377 0.7133551 ]
# [9.088353   8.329154   9.2976465  6.521552   4.158903   3.6913018
#  3.196353   2.765442   2.0534513  1.8735495  1.818197   1.6991998
#  1.4550513  1.3308499  1.3921949  1.344502   1.3617029  1.2302972
#  1.1477008  1.0850003  1.010148   0.99774814 1.0362478  1.0283524
#  0.8583493  0.85234773 0.82344633 0.79404604 0.79729617 0.79189634
#  0.7528436  0.7105572  0.6589984  0.6584012 ]
# [9.498915   6.5703044  3.9354992  3.6712909  3.1472979  3.0788069
#  2.8610456  2.745949   2.4374506  2.3644543  2.1339033  1.8890015
#  1.7646557  1.6300489  1.6343024  1.499704   1.4829986  1.4425055
#  1.2279528  1.215846   1.1431971  1.0543976  1.0149499  0.9375464
#  0.8932538  0.8581494  0.94604856 0.92715454 0.855047   0.79644775
#  0.75290346 0.7127942  0.74600035 0.7395996 ]
# [6.0741014  4.4659953  3.6823566  3.1676476  2.8277478  2.7406507
#  2.357851   2.0883532  2.0814521  1.847058   1.6699604  1.6532556
#  1.5584546  1.3432502  1.2398584  1.1388495  1.0708551  1.0440552
#  1.025158   0.95625365 0.93614686 0.9317517  0.88429505 0.8231
#  0.81770265 0.79341066 0.7442499  0.7335571  0.70955443 0.6691516
#  0.6887982  0.67630434 0.6105548  0.598844  ]
# [14.291248   12.44805     7.375495    5.9933057   4.006344    3.5292492
#   3.2090058   3.1335003   2.5182447   2.2040496   2.043501    1.796695
#   1.8773438   1.6960535   1.5495496   1.5480396   1.4510376   1.3213525
#   1.2279053   1.1785016   1.0617437   1.0245459   1.0232959   1.0125971
#   1.0820941   1.0771009   1.0187476   0.98125     0.8904468   0.8809442
#   0.8297436   0.79335207  0.8631494   0.8270435 ]
# [7.7257023  6.068892   4.5399904  3.6932971  3.203194   3.1650982
#  3.1215522  2.8208497  2.4031043  2.3177009  2.391206   2.2649024
#  2.0030525  1.8453546  1.5901495  1.4600501  1.3605517  1.300553
#  1.2526544  1.2268524  1.1110083  1.014599   0.9457019  0.9367981
#  0.9505451  0.86186033 0.8724542  0.8325531  0.80430174 0.7894018
#  0.7782001  0.777298   0.7329047  0.7069    ]

# %% [markdown]
# This appears to show better convergence, but the convergence is to ~2 DN, rather than 0 DN. This is acceptable.
#
# lets now consult the image results after taking the median rather than the mean - we are looking for the elimination of the rectablges in the 400 nm and 475 nm channels.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
        img_1.image_load(mode='median')
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()
        img_1.dark_subtract(drk)
        img_1.image_display()
        img_1.image_display(noise=True, vmax=40)
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 36 images (ave) for: 0 (850 nm)
# Loaded 1 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# ../data/flat_field_dark_11072023/1_475
# Loaded 36 images (ave) for: 1 (475 nm)
# Loaded 1 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# ../data/flat_field_dark_11072023/2_400
# Loaded 36 images (ave) for: 2 (400 nm)
# Loaded 1 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# ../data/flat_field_dark_11072023/3_550
# Loaded 36 images (ave) for: 3 (550 nm)
# Loaded 1 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# ../data/flat_field_dark_11072023/4_725
# Loaded 36 images (ave) for: 4 (725 nm)
# Loaded 1 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# ../data/flat_field_dark_11072023/5_950
# Loaded 36 images (ave) for: 5 (950 nm)
# Loaded 1 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# ../data/flat_field_dark_11072023/6_650
# Loaded 36 images (ave) for: 6 (650 nm)
# Loaded 1 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# ../data/flat_field_dark_11072023/7_550
# Loaded 36 images (ave) for: 7 (550 nm)
# Loaded 1 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)

# %% [markdown]
# Of course, the artefacts are still present, as taking the median does not change the computation of the standard deviation.

# %% [markdown]
# In conclusion, the median is the right score to use, as it best handles the occurance of stucture in the spectralon.

# %% [markdown]
# # After Processing

# %% [markdown]
# Now what to do with this data and information?
#
# We would like to use these frames to apply illumination and instrument nonuniformity corrections.
#
# This needs to be baked into a new reflectance processing pipeline, where we now take the mean reflectance across the region of interest, after these flat field frames have been applied, and use these to compute the reflectance across the image, as opposed to finding the relfectance correction coefficient for each pixel individually.

# %% [markdown]
# So now I need to normalise these frames, to the mean value of the central region, and save these as the flat-fields.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
        img_1.image_load(mode='median')
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()
        img_1.dark_subtract(drk)
        img_1.img_ave = img_1.img_ave / np.mean(img_1.img_ave[40:60,40:60])
        img_1.image_display(vmin=0.9, vmax=1.1)        
        img_1.img_type = 'flat_field'
        img_1.dir = Path('..', 'data', 'flat_fields_11072023', channel.stem)
        img_1.dir.mkdir(parents=True, exist_ok=True)
        img_1.save_tiff()
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 36 images (ave) for: 0 (850 nm)
# Loaded 1 images (ave) for: 0 (850 nm)
# Subtracting dark frame for: 0 (850 nm)
# ../data/flat_fields_11072023/0_850
# Mean image written to ../data/flat_fields_11072023/0_850/850_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/0_850/850_error_flat_field.tif
# ../data/flat_field_dark_11072023/1_475
# Loaded 36 images (ave) for: 1 (475 nm)
# Loaded 1 images (ave) for: 1 (475 nm)
# Subtracting dark frame for: 1 (475 nm)
# ../data/flat_fields_11072023/1_475
# Mean image written to ../data/flat_fields_11072023/1_475/475_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/1_475/475_error_flat_field.tif
# ../data/flat_field_dark_11072023/2_400
# Loaded 36 images (ave) for: 2 (400 nm)
# Loaded 1 images (ave) for: 2 (400 nm)
# Subtracting dark frame for: 2 (400 nm)
# ../data/flat_fields_11072023/2_400
# Mean image written to ../data/flat_fields_11072023/2_400/400_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/2_400/400_error_flat_field.tif
# ../data/flat_field_dark_11072023/3_550
# Loaded 36 images (ave) for: 3 (550 nm)
# Loaded 1 images (ave) for: 3 (550 nm)
# Subtracting dark frame for: 3 (550 nm)
# ../data/flat_fields_11072023/3_550
# Mean image written to ../data/flat_fields_11072023/3_550/550_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/3_550/550_error_flat_field.tif
# ../data/flat_field_dark_11072023/4_725
# Loaded 36 images (ave) for: 4 (725 nm)
# Loaded 1 images (ave) for: 4 (725 nm)
# Subtracting dark frame for: 4 (725 nm)
# ../data/flat_fields_11072023/4_725
# Mean image written to ../data/flat_fields_11072023/4_725/725_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/4_725/725_error_flat_field.tif
# ../data/flat_field_dark_11072023/5_950
# Loaded 36 images (ave) for: 5 (950 nm)
# Loaded 1 images (ave) for: 5 (950 nm)
# Subtracting dark frame for: 5 (950 nm)
# ../data/flat_fields_11072023/5_950
# Mean image written to ../data/flat_fields_11072023/5_950/950_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/5_950/950_error_flat_field.tif
# ../data/flat_field_dark_11072023/6_650
# Loaded 36 images (ave) for: 6 (650 nm)
# Loaded 1 images (ave) for: 6 (650 nm)
# Subtracting dark frame for: 6 (650 nm)
# ../data/flat_fields_11072023/6_650
# Mean image written to ../data/flat_fields_11072023/6_650/650_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/6_650/650_error_flat_field.tif
# ../data/flat_field_dark_11072023/7_550
# Loaded 36 images (ave) for: 7 (550 nm)
# Loaded 1 images (ave) for: 7 (550 nm)
# Subtracting dark frame for: 7 (550 nm)
# ../data/flat_fields_11072023/7_550
# Mean image written to ../data/flat_fields_11072023/7_550/550_mean_flat_field.tif
# Error image written to ../data/flat_fields_11072023/7_550/550_error_flat_field.tif

# %% [markdown]
# This completes the flat-fielding process.

# %% [markdown]
# # Computing the PRNU and DSNU
#
# Here we follow the EMVA1288 protocal for computing the spatial variance of the dark and lit images, and compute the PRNU and DSNU from these.

# %%
subject = 'flat_field_illum_11072023'
illums = sorted(list(Path('..', 'data', subject).glob('[!.]*')))
dark_subject = 'flat_field_dark_11072023'
darks = sorted(list(Path('..', 'data', dark_subject).glob('[!.]*')))
channels = []
roi2 = [25,75]
roi1 = [36,64]
dsnus1 = []
prnus1 = []
dsnus2 = []
prnus2 = []
for i, channel in enumerate(illums):        
        print(darks[i])
        positions = sorted(list(Path(channel).glob('[!.]*_ave_ave.tif')))
        dark = list(Path(darks[i]).glob('[!.]*_ave_ave.tif'))[0]        
        img_1 = osp.LightImage(subject=subject, channel=channel.stem, img_type='ave')
        img_1.image_load(mode='median')
        drk = osp.DarkImage(dark_subject, darks[i].stem, img_type='ave')
        drk.image_load()        
        var_50 = np.std(img_1.img_ave[roi1[0]:roi1[1],roi1[0]:roi1[1]])**2
        var_drk = np.std(drk.img_ave[roi1[0]:roi1[1],roi1[0]:roi1[1]])**2
        dsnu_1288 = np.sqrt(var_drk)
        prnu_1288 = 100.0 * np.sqrt(var_50 - var_drk) / (np.mean(img_1.img_ave[roi1[0]:roi1[1],roi1[0]:roi1[1]]) - np.mean(drk.img_ave[roi1[0]:roi1[1],roi1[0]:roi1[1]]))
        channels.append(channel.stem)
        dsnus1.append(dsnu_1288)
        prnus1.append(prnu_1288)        

        var_50 = np.std(img_1.img_ave[roi2[0]:roi2[1],roi2[0]:roi2[1]])**2
        var_drk = np.std(drk.img_ave[roi2[0]:roi2[1],roi2[0]:roi2[1]])**2
        dsnu_1288 = np.sqrt(var_drk)
        prnu_1288 = 100.0 * np.sqrt(var_50 - var_drk) / (np.mean(img_1.img_ave[roi2[0]:roi2[1],roi2[0]:roi2[1]]) - np.mean(drk.img_ave[roi2[0]:roi2[1],roi2[0]:roi2[1]]))        
        dsnus2.append(dsnu_1288)
        prnus2.append(prnu_1288)    

results = pd.DataFrame({'channel':channels, 'dsnu1288 (DN) ROI1':dsnus1, 'prnu1288 (%) ROI1':prnus1, 'dsnu1288 (DN) ROI2':dsnus2, 'prnu1288 (%) ROI2':prnus2})
# Out:
# ../data/flat_field_dark_11072023/0_850
# Loaded 36 images (ave) for: 0 (850 nm)
# Loaded 1 images (ave) for: 0 (850 nm)
# ../data/flat_field_dark_11072023/1_475
# Loaded 36 images (ave) for: 1 (475 nm)
# Loaded 1 images (ave) for: 1 (475 nm)
# ../data/flat_field_dark_11072023/2_400
# Loaded 36 images (ave) for: 2 (400 nm)
# Loaded 1 images (ave) for: 2 (400 nm)
# ../data/flat_field_dark_11072023/3_550
# Loaded 36 images (ave) for: 3 (550 nm)
# Loaded 1 images (ave) for: 3 (550 nm)
# ../data/flat_field_dark_11072023/4_725
# Loaded 36 images (ave) for: 4 (725 nm)
# Loaded 1 images (ave) for: 4 (725 nm)
# ../data/flat_field_dark_11072023/5_950
# Loaded 36 images (ave) for: 5 (950 nm)
# Loaded 1 images (ave) for: 5 (950 nm)
# ../data/flat_field_dark_11072023/6_650
# Loaded 36 images (ave) for: 6 (650 nm)
# Loaded 1 images (ave) for: 6 (650 nm)
# ../data/flat_field_dark_11072023/7_550
# Loaded 36 images (ave) for: 7 (550 nm)
# Loaded 1 images (ave) for: 7 (550 nm)

# %%
results
# Out:
#   channel  dsnu1288 (DN) ROI1  prnu1288 (%) ROI1  dsnu1288 (DN) ROI2  \
# 0   0_850            0.252764           2.887667            0.243658
# 1   1_475            0.233720           1.836669            0.233848
# 2   2_400            0.228803           1.721819            0.241635
# 3   3_550            0.244827           2.027448            0.244881
# 4   4_725            0.241311           2.918592            0.241415
# 5   5_950            0.183946           2.265735            0.195272
# 6   6_650            0.229432           2.207799            0.234077
# 7   7_550            0.318726           2.012125            0.377721
#
#    prnu1288 (%) ROI2
# 0           4.858082
# 1           2.690079
# 2           4.140879
# 3           2.873724
# 4           3.878976
# 5           4.236578
# 6           3.267599
# 7           2.798722
